# %% [markdown]
# # DeepTok — DIII-D Fusion Data Analysis
#
# This notebook demonstrates AI-assisted analysis of DIII-D tokamak experimental data using DeepTok. It covers plasma shape characterization, current and energy evolution, and multi-shot statistical comparison — all driven by natural language requests.
#
# DeepTok combines TokSearch (parallel fusion data retrieval) with a natural language agent interface. Use `%%ask` in any cell to request data fetching, analysis, or visualization in plain English. The agent has access to DIII-D shot data via Pelican, including equilibrium reconstruction signals from the `efit01` tree.
#
# **Analyses in this notebook**:
#   1. Plasma shape data (elongation `\kappa` and poloidal flux `\psirz`) for shots 188702 and 191744
#   2. Plasma current (`\ipmhd`) and stored energy (`\wmhd`) time evolution comparison
#   3. Peak elongation survey across 10 randomly sampled shots
#
# Available signals (`efit01` tree): plasma elongation (`\kappa`), poloidal flux (`\psirz`), plasma current (`\ipmhd`), poloidal beta (`\betap`), safety factor (`\q95`), stored energy (`\wmhd`), and more.
#
# **Requirements**: A valid Pelican token must be saved at ~/.fdp/token before running data cells.

# %%
# %reset
# Out:
# **Sage reset.**
# - Output folder cleared: `/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_fusion_study_sage_` (17 items removed)
# - Conversation history cleared

# %%
# %%ask
# Fetch plasma shape data (elongation kappa and poloidal flux psirz) for shots [188702, 191744].
# Generate visualizations for the two shots
# Out:
# I'll help you fetch plasma shape data for those DIII-D shots and generate visualizations. Let me start by checking the available skills for fetching DIII-D shot data.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/d3d-shot-fetcher/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/d3d-shot-fetcher/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a script to fetch the plasma shape data (elongation kappa and poloidal flux psirz) for shots 188702 and 191744, and generate visualizations.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
# ...

# %%
# %%ask
# For the both shots, retrieve the plasma current (ipmhd) and stored energy (wp) from efit01.
# Analyze and compare their time evolution, and provide a summary of any notable differences
# and visulaization.
# Out:
# I'll fetch plasma current (ipmhd) and stored energy (wp) data for both shots, analyze their time evolution, and create visualizations. Let me start by checking the toksearch skills for the data fetching approach.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/toksearch-backends/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/toksearch-backends/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
# ...

# %%
# %%ask
# Sample 10 random shots between 180000 and 195000.
# Fetch elongation (kappa) from efit01 and report the peak kappa value for each shot.
# Which shot has the highest elongation?
# Out:
# I'll help you sample 10 random shots, fetch their elongation data, and find which has the highest peak value. Let me start by generating the random shot numbers and fetching the data.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python -c "
# import numpy as np
#
# # Set random seed for reproduc...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python -c "
# import numpy as np
#
# # Set random seed for reproducibility
# np.random.seed(42)
#
# # Generate 10 random shots between 180000 and 195000
# shots = np.random.randint(180000, 195000, 10)
# print('Random shots:', shots)
# "</pre>
#     </div>
#   </details>
# </div>
# ...
