# %% [markdown]
# # Exoplanet Transit Explorer
#
# When a planet passes in front of its star, it blocks a tiny fraction of the starlight —                 causing a brief, regular dip in the star's measured brightness. This tiny dip, called a
# **transit**, is how astronomers discover and study planets orbiting distant stars.
# This notebook lets you explore real transit data from NASA's TESS and Kepler space telescopes:
#   1. **Pick a planet** — choose from a list of known transiting exoplanets
#   2. **Download light curve** — fetch the star's actual brightness measurements over time
#   3. **See the transit** — fold the data to reveal the repeating dip as the planet orbits
#   4. **Summary card** — read off the transit depth, duration, and estimated planet size
#
# No coding needed — just run each cell and follow the prompts.

# %%
# %reset

# %%
# %%skill
# https://github.com/klinucsd/sage_skills/tree/main/astronomy/exoplanet-transits
# Out:
# <hr style='margin:8px 0'/><div style='line-height:1.35'><b>Skills install summary</b><div style='margin-top:4px'>✅ <b>Installed (1)</b> — available in the next <code>%%ask</code> cell:</div><ul style='margin:2px 0 0 0; padding-left:1.5em'><li><b>exoplanet-transits</b> ← <code>klinucsd/sage_skills@main/astronomy/exoplanet-transits</code></li></ul><div style='margin-top:4px;color:#64748B;font-size:0.9em'>Note: one or more skills are pinned to a branch. If a future rerun gives different results, check the skill repo for recent changes.</div></div>

# %%
# %%ask
# Show transiting exoplanets and let me pick one
# Out:
# Let me read the exoplanet-transits skill to understand the workflow.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/exoplanet-transits/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/exoplanet-transits/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# Let me check the sage-dropdown skill for building an interactive picker.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
# ...

# %%
# %%ask
# Download the TESS light curve
# Out:
# Reading the exoplanet-transits skill for the correct workflow.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/exoplanet-transits/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/exoplanet-transits/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# You've selected **HD 1397 b** (P = 11.54 days). I'll follow the exoplanet-transits skill Step 2 to download the TESS light curve.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 3 todo(s)
# ...

# %%
# %%ask
# Phase-fold the light curve to show the transit dip
# Out:
# Reading the exoplanet-transits skill to check for phase-folding conventions.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/exoplanet-transits/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/exoplanet-transits/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll write and run the phase-fold script following the skill's Step 3 exactly.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
# ...

# %%
# %%ask
# Generate a transit summary card
