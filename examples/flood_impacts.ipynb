# %% [markdown]
# # Flood Impact Analysis: Kanawha River with Sage
#   ### A Natural Language Science Notebook
#   This notebook demonstrates **Sage** (Science Agent) — a natural language infrastructure for scientific data exploration on the [National Data Platform (NDP)](https://nationaldataplatform.org),  developed as part of the WENOKN project. Every step is expressed as a plain English prompt using the `%%ask` magic command, and results are returned in natural language with interactive maps and data visualizations.
#
#   **What this notebook does:**
#   1. Visualizes flood depth along the Kanawha River at 400,000 cfs using USACE HEC-RAS 2D model results
#   2. Identifies schools impacted by flooding, classified by severity (nuisance, minor, moderate, severe)
#   3. Finds flooded commercial buildings with structure value over $1 million, with visualizations
#   4. Estimates the number of elderly residents (age 65+) at risk from the flood, with visualizations
#
#
#
# **Requirements:** Set your `NRP_API_KEY` in `_User-Persistent-Storage_CephBlock_/.env` before running it on NDP JupyterHub.

# %%
# %%ask
# Show the flood depth for the Kanawha River at 400,000 cfs
# Out:
# I'll use the kanawha-flood-depth skill to display the flood depth for the Kanawha River at 400,000 cfs. Let me first read the skill instructions to understand how to use it.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/kanawha-flood-depth/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/kanawha-flood-depth/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a script to generate the WMS layer definition for the 400,000 cfs flood depth scenario.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/flood_depth_400k.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/flood_depth_400k.py",
#   "content": "import json, os\n\n# Working directory as specified\nworking_dir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_\"\n\n# Flow requested by user\nflow_cfs = 400_000\n\n# This is exactly one of the available scenarios, so no rounding needed\nscenario = 400_000\nflow_k = scenario // 1000\n\nwms_layer = {\n    \"url\": \"https://sparcal.sdsc.edu/geoserver/tiger/wms\",\n    \"layers\": f\"tiger:Depth_{scenario}_5070\",\n    \"name\": f\"Kanawha Flood {flow_k}k cfs\",\n    \"opacity\": 0.7,\n    \"bbox\": [37.5, -82.5, 39.0, -80.5],\n}\n\nfilename = f\"kanawha_flood_{flow_k}k.wms.json\"\nfilepath = os.path.join(working_dir, filename)\n\nwith open(filepath, \"w\") as f:\n    json.dump(wms_layer, f)\n\nprint(f\"WMS layer saved: {filepath}\")\nprint(f\"Layer name: {wms_layer['name']}\")\nprint(f\"Scenario: {scenario:,} cfs\")\nprint(f\"Layer name in file: {wms_layer['name']}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impa...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/flood_depth_400k.py</pre>
#     </div>
#   </details>
# </div>
# # Kanawha River Flood Depth at 400,000 cfs
#
# The flood depth for the Kanawha River at 400,000 cfs is shown below using the USACE HEC-RAS 2D model data. This represents the depth of floodwater above ground surface in feet.
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">Kanawha River Flood Depth at 400,000 cfs</div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38c8bba1328dec97cf591fc25005e647 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38c8bba1328dec97cf591fc25005e647&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38c8bba1328dec97cf591fc25005e647 = L.map(
#                 &quot;map_38c8bba1328dec97cf591fc25005e647&quot;,
#                 {
#                     center: [38.25, -81.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_099f844147af0a302c69d58c79a272e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_099f844147af0a302c69d58c79a272e2.addTo(map_38c8bba1328dec97cf591fc25005e647);
#
#
#             var macro_element_cb51e22caa5494df95ecb1f54528ac85 = L.tileLayer.wms(
#                 &quot;https://sparcal.sdsc.edu/geoserver/tiger/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;tiger:Depth_400000_5070&quot;, &quot;opacity&quot;: 0.7, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_cb51e22caa5494df95ecb1f54528ac85.addTo(map_38c8bba1328dec97cf591fc25005e647);
#
#
#             var layer_control_bc02b67d21c41b2676e15c4857b8de14_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_099f844147af0a302c69d58c79a272e2,
#                 },
#                 overlays :  {
#                     &quot;Kanawha Flood 400k cfs&quot; : macro_element_cb51e22caa5494df95ecb1f54528ac85,
#                 },
#             };
#             let layer_control_bc02b67d21c41b2676e15c4857b8de14 = L.control.layers(
#                 layer_control_bc02b67d21c41b2676e15c4857b8de14_layers.base_layers,
#                 layer_control_bc02b67d21c41b2676e15c4857b8de14_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_38c8bba1328dec97cf591fc25005e647);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# **Data source**: USACE HEC-RAS 2D model (Huntington District)
# **Flow scenario**: 400,000 cfs
# **Depth units**: Feet above ground surface
# **Coordinate system**: EPSG:5070 (Albers NAD83), reprojected by GeoServer for WMS display
#
# The map displays the flood extent where water depth exceeds 0 feet, with deeper areas shown in darker colors. This visualization helps identify which areas would be inundated at this flow level along the Kanawha River corridor.

# %%
# %%ask
# Show me all schools impacted by the Kanawha River flood at 400,000 cfs
# Out:
# I'll use the kanawha-nsi-impact skill to find all schools impacted by the Kanawha River flood at 400,000 cfs. Let me read the skill instructions first.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/kanawha-nsi-impact/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/kanawha-nsi-impact/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/kanawha-nsi-impact/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/kanawha-nsi-impact/SKILL.md",
#   "offset": 100,
#   "limit": 100
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/kanawha-nsi-impact/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/kanawha-nsi-impact/SKILL.md",
#   "limit": 100,
#   "offset": 200
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a script to find all schools impacted by the 400,000 cfs flood. Schools have OCCTYPE == "EDU1" according to the skill documentation.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/schools_400k.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/schools_400k.py",
#   "content": "import json, os\nimport numpy as np\nimport pandas as pd\nimport geopandas as gpd\nimport requests\nfrom rasterio.io import MemoryFile\n\n# Working directory\nworking_dir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_\"\n\nGEOSERVER = \"https://sparcal.sdsc.edu/geoserver/tiger\"\nSCENARIOS = [1_000, 50_000, 100_000, 150_000, 200_000, 300_000,\n             400_000, 500_000, 700_000, 900_000, 1_000_000, 1_500_000, 2_000_000]\n\n# Flow requested by user\nflow_cfs = 400_000\n\n# Round UP to nearest scenario\nscenario = next((s for s in SCENARIOS if s &gt;= flow_cfs), SCENARIOS[-1])\nflow_k = scenario // 1000\nprint(f\"Flow scenario: {scenario:,} cfs\")\n\n# --- Step 1: Add WMS flood depth layer to map ---\nwms_layer = {\n    \"url\": f\"{GEOSERVER}/wms\",\n    \"layers\": f\"tiger:Depth_{scenario}_5070\",\n    \"name\": f\"Kanawha Flood {flow_k}k cfs\",\n    \"opacity\": 0.7,\n    \"bbox\": [37.5, -82.5, 39.0, -80.5],\n}\nwith open(os.path.join(working_dir, f\"kanawha_flood_{flow_k}k.wms.json\"), \"w\") as f:\n    json.dump(wms_layer, f)\nprint(f\"Saved WMS layer: kanawha_flood_{flow_k}k.wms.json\")\n\n# --- Step 2: Fetch all NSI structures via WFS ---\nprint(\"\\nFetching NSI structures from WFS (88,460 structures) ...\")\nwfs_url = (f\"{GEOSERVER}/ows?service=WFS&amp;version=2.0.0&amp;request=GetFeature\"\n           f\"&amp;typeName=tiger:NSI2022_2026pricelevel&amp;outputFormat=application/json\")\nnsi = gpd.read_file(wfs_url)  # EPSG:4326\nprint(f\"Fetched {len(nsi)} structures\")\n\n# Reproject to EPSG:5070 for depth sampling\nnsi_5070 = nsi.to_crs(epsg=5070)\n\n# --- Step 3: Fetch depth raster via WCS ---\nxmin, ymin, xmax, ymax = nsi_5070.total_bounds\nmargin = 500\nwcs_url = (\n    f\"{GEOSERVER}/ows?service=WCS&amp;version=2.0.1&amp;request=GetCoverage\"\n    f\"&amp;coverageId=tiger:Depth_{scenario}_5070&amp;format=image/tiff\"\n    f\"&amp;SUBSETTINGCRS=http://www.opengis.net/def/crs/EPSG/0/5070\"\n    f\"&amp;SUBSET=X({xmin-margin:.0f},{xmax+margin:.0f})\"\n    f\"&amp;SUBSET=Y({ymin-margin:.0f},{ymax+margin:.0f})\"\n)\nprint(\"Fetching depth raster from WCS ...\")\nresp = requests.get(wcs_url, timeout=120)\nresp.raise_for_status()\n\n# --- Step 4: Sample depth at each structure ---\nwith MemoryFile(resp.content) as memfile:\n    with memfile.open() as src:\n        nodata = src.nodata\n        coords = [(geom.x, geom.y) for geom in nsi_5070.geometry]\n        raw = [v[0] for v in src.sample(coords)]\n\ndepths = []\nfor v in raw:\n    if (nodata is not None and v == nodata) or v &lt;= 0:\n        depths.append(np.nan)\n    else:\n        depths.append(float(v))\n\nnsi[\"depth_ft\"] = depths\nflooded = nsi[nsi[\"depth_ft\"].notna()].copy()\nprint(f\"Flooded structures: {len(flooded):,} of {len(nsi):,}\")\n\n# --- Step 5: Filter for schools (OCCTYPE == \"EDU1\") ---\nschools = flooded[flooded[\"OCCTYPE\"] == \"EDU1\"].copy()\nprint(f\"Flooded schools: {len(schools):,}\")\n\n# --- Step 6: Calculate school statistics ---\ntotal_students = schools[\"STUDENTS\"].sum()\nschool_value = schools[\"VAL_STRUCT\"].sum() + schools[\"VAL_CONT\"].sum()\n\n# Breakdown by depth categories\ndef depth_category(depth):\n    if depth &lt;= 1:\n        return \"0-1 ft\"\n    elif depth &lt;= 3:\n        return \"1-3 ft\"\n    elif depth &lt;= 6:\n        return \"3-6 ft\"\n    else:\n        return \"&gt;6 ft\"\n\nschools[\"depth_cat\"] = schools[\"depth_ft\"].apply(depth_category)\nby_depth = schools.groupby(\"depth_cat\").agg(\n    schools=(\"STUDENTS\", \"count\"),\n    students=(\"STUDENTS\", \"sum\"),\n    avg_depth=(\"depth_ft\", \"mean\")\n).reindex([\"0-1 ft\", \"1-3 ft\", \"3-6 ft\", \"&gt;6 ft\"])\n\n# --- Step 7: Save schools to GeoJSON for map ---\ndisplay_cols = [\"geometry\", \"ST_DAMCAT\", \"OCCTYPE\", \"depth_ft\", \"depth_cat\",\n                \"VAL_STRUCT\", \"VAL_CONT\", \"STUDENTS\", \"YRBUILT\", \"BSMNT\"]\nschools_wgs84 = schools[display_cols].copy()\nschools_wgs84.t ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impa...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/schools_400k.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/schools_summary_400k.csv</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/schools_summary_400k.csv"
# }</pre>
#     </div>
#   </details>
# </div>
# # Schools Impacted by Kanawha River Flood at 400,000 cfs
#
# ## Summary
#
# At a flow of **400,000 cfs** on the Kanawha River, **105 schools** are at risk of flooding, affecting **19,870 students**. This represents **57.4%** of all schools in the Kanawha River basin.
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">Kanawha River Flood and Impacted Schools</div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8b23069a0fdd561e9d5f4968c92a040 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8b23069a0fdd561e9d5f4968c92a040&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8b23069a0fdd561e9d5f4968c92a040 = L.map(
#                 &quot;map_e8b23069a0fdd561e9d5f4968c92a040&quot;,
#                 {
#                     center: [38.269282255, -81.39667990999999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bedeac27dc4b8a77992004d1f35ad14e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bedeac27dc4b8a77992004d1f35ad14e.addTo(map_e8b23069a0fdd561e9d5f4968c92a040);
#
#
#             var feature_group_efdc11c6b068ed5e2dc9ae6fdd422d39 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_1da18a39817639a9ba33dd2ca466562b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#e74c3c&quot;, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1da18a39817639a9ba33dd2ca466562b_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 5,
# };
#
#             let style = geo_json_1da18a39817639a9ba33dd2ca466562b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1da18a39817639a9ba33dd2ca466562b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_1da18a39817639a9ba33dd2ca466562b = L.geoJson(null, {
#                 onEachFeature: geo_json_1da18a39817639a9ba33dd2ca466562b_onEachFeature,
#
#                 style: geo_json_1da18a39817639a9ba33dd2ca466562b_styler,
#                 pointToLayer: geo_json_1da18a39817639a9ba33dd2ca466562b_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_1da18a39817639a9ba33dd2ca466562b_add (data) {
#             geo_json_1da18a39817639a9ba33dd2ca466562b
#                 .addData(data);
#         }
#             geo_json_1da18a39817639a9ba33dd2ca466562b_add({&quot;bbox&quot;: [-82.15860366, 37.70698558, -80.63475616, 38.83157893], &quot;features&quot;: [{&quot;bbox&quot;: [-82.15860366, 38.83157893, -82.15860366, 38.83157893], &quot;geometry&quot;: {&quot;coordinates&quot;: [-82.15860366, 38.83157893], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;BSMNT&quot;: &quot;N&quot;, &quot;OCCTYPE&quot;: &quot;EDU1&quot;, &quot;STUDENTS&quot;: 0, &quot;ST_DAMCAT&quot;: &quot;PUB&quot;, &quot;VAL_CONT&quot;: 101360.539712, &quot;VAL_STRUCT&quot;: 101360.539712, &quot;YRBUILT&quot;: 1973, &quot;depth_cat&quot;: &quot;3-6 ft&quot;, &quot;depth_ft&quot;: 3.98492431640625}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-80.71019629, 38.66463616, -80.71019629, 38.66463616], &quot;geometry&quot;: {&quot;coordinates&quot;: [-80.71019629, 38.66463616], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;BSMNT&quot;: &quot;N&quot;, &quot;OCCTYPE&quot;: &quot;EDU1&quot;, &quot;STUDENTS&quot;: 0, &quot;ST_DAMCAT&quot;: &quot;PUB&quot;, &quot;VAL_CONT&quot;: 108532.4884992, &quot;VAL_STRUCT&quot;: 108532.4884992, &quot;YRBUILT&quot;: 0, &quot;depth_cat&quot;: &quot;\u003e6 ft&quot;, &quot;depth_ft&quot;: 70.91827392578125}, &quot;type&quot;: &quot;Feature&
# ## Impact Overview
#
# **Total schools in basin**: 183
# **Schools flooded**: 105
# **Students at risk**: 19,870
# **Total building + contents value**: $1,302.0M
#
# ## Impact by Flood Depth
#
# The severity of flooding varies significantly across schools:
#
# | Depth Category | Schools | Students | Avg Depth |
# |----------------|---------|----------|-----------|
# | 0-1 ft | 3 | 769 | 0.18 ft |
# | 1-3 ft | 3 | 1,339 | 1.70 ft |
# | 3-6 ft | 10 | 2,260 | 4.76 ft |
# | **>6 ft** | **89** | **15,502** | 18.30 ft |
#
# ## Key Findings
#
# - **85%** of flooded schools (89 out of 105) would experience water depths exceeding **6 feet**, causing severe structural damage
# - The remaining schools face moderate flooding (1-6 feet) or minimal flooding (<1 foot)
# - Schools with deeper flooding (>6 ft) account for **78%** of the student population at risk (15,502 students)
# - This indicates that most school infrastructure in the floodplain is located in low-lying areas vulnerable to extreme flooding
#
# The map shows the flood extent (blue overlay) with individual school locations marked. Schools in darker blue areas would experience deeper flooding and more severe damage.

# %%
# %%ask
# Find all flooded commercial buildings along the Kanawha River with structure value
# over $1 million at 400,000 cfs. Please generate visualizations of the result
# Out:
# I'll use the kanawha-nsi-impact skill to find flooded commercial buildings valued over $1 million at 400,000 cfs, and create visualizations.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_400k.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_400k.py",
#   "content": "import json, os\nimport numpy as np\nimport pandas as pd\nimport geopandas as gpd\nimport requests\nfrom rasterio.io import MemoryFile\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n\n# Working directory\nworking_dir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_\"\n\nGEOSERVER = \"https://sparcal.sdsc.edu/geoserver/tiger\"\nSCENARIOS = [1_000, 50_000, 100_000, 150_000, 200_000, 300_000,\n             400_000, 500_000, 700_000, 900_000, 1_000_000, 1_500_000, 2_000_000]\n\n# Flow requested by user\nflow_cfs = 400_000\n\n# Round UP to nearest scenario\nscenario = next((s for s in SCENARIOS if s &gt;= flow_cfs), SCENARIOS[-1])\nflow_k = scenario // 1000\nprint(f\"Flow scenario: {scenario:,} cfs\")\n\n# --- Step 1: Add WMS flood depth layer to map ---\nwms_layer = {\n    \"url\": f\"{GEOSERVER}/wms\",\n    \"layers\": f\"tiger:Depth_{scenario}_5070\",\n    \"name\": f\"Kanawha Flood {flow_k}k cfs\",\n    \"opacity\": 0.7,\n    \"bbox\": [37.5, -82.5, 39.0, -80.5],\n}\nwith open(os.path.join(working_dir, f\"kanawha_flood_{flow_k}k.wms.json\"), \"w\") as f:\n    json.dump(wms_layer, f)\nprint(f\"Saved WMS layer: kanawha_flood_{flow_k}k.wms.json\")\n\n# --- Step 2: Fetch all NSI structures via WFS ---\nprint(\"\\nFetching NSI structures from WFS (88,460 structures) ...\")\nwfs_url = (f\"{GEOSERVER}/ows?service=WFS&amp;version=2.0.0&amp;request=GetFeature\"\n           f\"&amp;typeName=tiger:NSI2022_2026pricelevel&amp;outputFormat=application/json\")\nnsi = gpd.read_file(wfs_url)  # EPSG:4326\nprint(f\"Fetched {len(nsi)} structures\")\n\n# Reproject to EPSG:5070 for depth sampling\nnsi_5070 = nsi.to_crs(epsg=5070)\n\n# --- Step 3: Fetch depth raster via WCS ---\nxmin, ymin, xmax, ymax = nsi_5070.total_bounds\nmargin = 500\nwcs_url = (\n    f\"{GEOSERVER}/ows?service=WCS&amp;version=2.0.1&amp;request=GetCoverage\"\n    f\"&amp;coverageId=tiger:Depth_{scenario}_5070&amp;format=image/tiff\"\n    f\"&amp;SUBSETTINGCRS=http://www.opengis.net/def/crs/EPSG/0/5070\"\n    f\"&amp;SUBSET=X({xmin-margin:.0f},{xmax+margin:.0f})\"\n    f\"&amp;SUBSET=Y({ymin-margin:.0f},{ymax+margin:.0f})\"\n)\nprint(\"Fetching depth raster from WCS ...\")\nresp = requests.get(wcs_url, timeout=120)\nresp.raise_for_status()\n\n# --- Step 4: Sample depth at each structure ---\nwith MemoryFile(resp.content) as memfile:\n    with memfile.open() as src:\n        nodata = src.nodata\n        coords = [(geom.x, geom.y) for geom in nsi_5070.geometry]\n        raw = [v[0] for v in src.sample(coords)]\n\ndepths = []\nfor v in raw:\n    if (nodata is not None and v == nodata) or v &lt;= 0:\n        depths.append(np.nan)\n    else:\n        depths.append(float(v))\n\nnsi[\"depth_ft\"] = depths\nflooded = nsi[nsi[\"depth_ft\"].notna()].copy()\nprint(f\"Flooded structures: {len(flooded):,} of {len(nsi):,}\")\n\n# --- Step 5: Filter for commercial buildings with value &gt; $1M ---\ncommercial = flooded[\n    (flooded[\"ST_DAMCAT\"] == \"COM\") &amp;\n    (flooded[\"VAL_STRUCT\"] &gt; 1_000_000)\n].copy()\nprint(f\"High-value commercial buildings flooded: {len(commercial):,}\")\n\n# --- Step 6: Calculate statistics ---\ntotal_value = commercial[\"VAL_STRUCT\"].sum()\ntotal_contents = commercial[\"VAL_CONT\"].sum()\ntotal_vehicles = commercial[\"VAL_VEHIC\"].sum()\ntotal_exposure = total_value + total_contents + total_vehicles\ntotal_employees = commercial[\"EMPNUM\"].sum()\n\n# Breakdown by OCCTYPE\nby_occtype = commercial.groupby(\"OCCTYPE\").agg(\n    buildings=(\"VAL_STRUCT\", \"count\"),\n    total_value=(\"VAL_STRUCT\", \"sum\"),\n    employees=(\"EMPNUM\", \"sum\")\n).sort_values(\"total_value\", ascending=False)\n\n# Breakdown by depth category\ndef depth_category(depth):\n    if depth &lt;= 1:\n        return \"0-1 ft\"\n    elif depth &lt;= 3:\n        return \"1-3 ft\"\n    elif depth &lt;= 6:\n        return \"3-6 ft\"\n    else:\n        return \"&gt;6 ft\"\n\ncommercial[\"depth_cat\"] = commercial[\"depth_f ...
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impa...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_400k.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✂️ <b>edit_file</b> — Editing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_400k.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_400k.py",
#   "old_string": "import json, os\nimport numpy as np\nimport pandas as pd\nimport geopandas as gpd\nimport requests\nfrom rasterio.io import MemoryFile\nimport matplotlib.pyplot as plt\nimport seaborn as sns",
#   "new_string": "import json, os\nimport numpy as np\nimport pandas as pd\nimport geopandas as gpd\nimport requests\nfrom rasterio.io import MemoryFile\nimport matplotlib.pyplot as plt"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impa...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_400k.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_by_type_400k.csv</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_by_type_400k.csv"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_by_depth_400k.csv</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/commercial_by_depth_400k.csv"
# }</pre>
#     </div>
#   </details>
# </div>
# # High-Value Commercial Buildings Flooded at 400,000 cfs
#
# ## Summary Overview
#
# At a flow of **400,000 cfs** on the Kanawha River, **1,884 commercial buildings** with structure values exceeding **$1 million** are at risk of flooding. This represents a significant economic exposure of **$13.68 billion** in total value (structures, contents, and vehicles), with **57,200 employees** at risk.
#
# ## Economic Impact
#
# **Total structure value**: $6,395.3M
# **Total contents value**: $6,623.1M
# **Total vehicle value**: $666.2M
# **Total exposure**: $13,684.5M
# **Employees at risk**: 57,200
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">Kanawha River Flood and High-Value Commercial Buildings</div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5232c71b80970a785691af270054dd85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5232c71b80970a785691af270054dd85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5232c71b80970a785691af270054dd85 = L.map(
#                 &quot;map_5232c71b80970a785691af270054dd85&quot;,
#                 {
#                     center: [38.29938844, -81.42506639499999],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_86a4aeb45545509a416033dc0adc16ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_86a4aeb45545509a416033dc0adc16ae.addTo(map_5232c71b80970a785691af270054dd85);
#
#
#             var feature_group_db5e43742f56db915ea9ee565de46956 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_56908c07aeb8d54e75e17753c7ce25f9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#e74c3c&quot;, &quot;fillColor&quot;: &quot;#e74c3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_56908c07aeb8d54e75e17753c7ce25f9_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 5,
# };
#
#             let style = geo_json_56908c07aeb8d54e75e17753c7ce25f9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_56908c07aeb8d54e75e17753c7ce25f9_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_56908c07aeb8d54e75e17753c7ce25f9 = L.geoJson(null, {
#                 onEachFeature: geo_json_56908c07aeb8d54e75e17753c7ce25f9_onEachFeature,
#
#                 style: geo_json_56908c07aeb8d54e75e17753c7ce25f9_styler,
#                 pointToLayer: geo_json_56908c07aeb8d54e75e17753c7ce25f9_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_56908c07aeb8d54e75e17753c7ce25f9_add (data) {
#             geo_json_56908c07aeb8d54e75e17753c7ce25f9
#                 .addData(data);
#         }
#             geo_json_56908c07aeb8d54e75e17753c7ce25f9_add({&quot;bbox&quot;: [-82.2183075, 37.6554459, -80.63182529, 38.94333098], &quot;features&quot;: [{&quot;bbox&quot;: [-82.1470675, 38.886753, -82.1470675, 38.886753], &quot;geometry&quot;: {&quot;coordinates&quot;: [-82.1470675, 38.886753], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;BSMNT&quot;: &quot;N&quot;, &quot;EMPNUM&quot;: 8, &quot;OCCTYPE&quot;: &quot;RES5&quot;, &quot;ST_DAMCAT&quot;: &quot;COM&quot;, &quot;VAL_CONT&quot;: 4743204.140799999, &quot;VAL_STRUCT&quot;: 9486408.281599998, &quot;VAL_VEHIC&quot;: 262656.0, &quot;YRBUILT&quot;: 1900, &quot;depth_cat&quot;: &quot;0-1 ft&quot;, &quot;depth_ft&quot;: 0.9520263671875}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-82.16485916, 38.90646036, -82.16485916, 38.90646036], &quot;geometry&quot;: {&quot;coordinates&quot;: [-82.16485916, 38.90646036], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;BSMNT&quot;: &quot;N&quot;, &quot;EMPNUM&quot;: 6, &quot;OCCTYPE&quot;: &quot;COM3&quot;, &quot;ST_DAMCAT&quot;: &quot;COM&quot;, &quot;VAL_CONT&quot;: 1242873.80672, &quot;VAL_STRUCT&quot;: 1242873.80672, &quot;VAL_VEHIC&quot;: 65664.0, &quot;YRBUILT&quot;: 0, &quot;depth_cat&quot;: &quot;\u003e6 ft&quot;, &quot;depth_ft&quot;
# The map displays the flood extent (blue overlay) with high-value commercial building locations. Buildings in darker blue areas would experience deeper flooding and more severe damage.
#
# ## Impact by Commercial Building Type
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Commercial Buildings by Type</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# The most heavily impacted commercial building types:
#
# | Type | Description | Buildings | Total Value | Employees |
# |------|-------------|-----------|-------------|-----------|
# | COM4 | Professional/Technical Services | 365 | $1,437M | 18,780 |
# | COM1 | Retail | 386 | $984M | 7,630 |
# | COM2 | Wholesale | 232 | $785M | 4,780 |
# | COM6 | Hospitals | 35 | $662M | 9,886 |
# | COM8 | Entertainment/Recreation | 212 | $537M | 5,263 |
#
# Professional and technical services (COM4) face the highest total value at risk ($1.44 billion), reflecting concentration of high-value office buildings in the floodplain. Hospitals (COM6), while fewer in number, represent critical infrastructure with 9,886 employees at risk.
#
# ## Impact by Flood Depth
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Buildings by Flood Depth</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Value by Flood Depth</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# The distribution of impacts by flood depth severity:
#
# | Depth Category | Buildings | Total Value | Employees | Avg Depth |
# |----------------|-----------|-------------|-----------|-----------|
# | 0-1 ft | 32 | $75M | 340 | 0.63 ft |
# | 1-3 ft | 87 | $192M | 1,568 | 1.80 ft |
# | 3-6 ft | 129 | $376M | 2,594 | 4.59 ft |
# | **>6 ft** | **1,636** | **$5,753M** | **52,698** | **17.62 ft** |
#
# ## Key Findings
#
# - **87%** of high-value commercial buildings (1,636 out of 1,884) would experience water depths exceeding **6 feet**, causing catastrophic structural damage
# - Buildings with deep flooding (>6 ft) account for **92%** of total value at risk ($5.75 billion) and **92%** of employees at risk (52,698)
# - Professional/technical services and retail establishments dominate the exposure by both count and value
# - Hospitals are particularly concerning due to their critical role in emergency response, with 35 facilities at risk
# - The extreme depth (average 17.6 ft) for most flooded buildings indicates they are located in low-lying areas adjacent to the river channel
#
# This analysis reveals that most high-value commercial infrastructure in the Kanawha River floodplain is concentrated in low-lying areas vulnerable to extreme flooding events, posing significant economic and operational risks to the regional economy.

# %%
# %%ask
# How many elderly people (over 65) are at risk from the Kanawha River flood at 400,000 cfs?
# Please generate visualizations of the result
# Out:
# I'll use the kanawha-nsi-impact skill to analyze elderly population at risk from the 400,000 cfs flood, and create visualizations.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/elderly_400k.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/elderly_400k.py",
#   "content": "import json, os\nimport numpy as np\nimport pandas as pd\nimport geopandas as gpd\nimport requests\nfrom rasterio.io import MemoryFile\nimport matplotlib.pyplot as plt\n\n# Working directory\nworking_dir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_\"\n\nGEOSERVER = \"https://sparcal.sdsc.edu/geoserver/tiger\"\nSCENARIOS = [1_000, 50_000, 100_000, 150_000, 200_000, 300_000,\n             400_000, 500_000, 700_000, 900_000, 1_000_000, 1_500_000, 2_000_000]\n\n# Flow requested by user\nflow_cfs = 400_000\n\n# Round UP to nearest scenario\nscenario = next((s for s in SCENARIOS if s &gt;= flow_cfs), SCENARIOS[-1])\nflow_k = scenario // 1000\nprint(f\"Flow scenario: {scenario:,} cfs\")\n\n# --- Step 1: Add WMS flood depth layer to map ---\nwms_layer = {\n    \"url\": f\"{GEOSERVER}/wms\",\n    \"layers\": f\"tiger:Depth_{scenario}_5070\",\n    \"name\": f\"Kanawha Flood {flow_k}k cfs\",\n    \"opacity\": 0.7,\n    \"bbox\": [37.5, -82.5, 39.0, -80.5],\n}\nwith open(os.path.join(working_dir, f\"kanawha_flood_{flow_k}k.wms.json\"), \"w\") as f:\n    json.dump(wms_layer, f)\nprint(f\"Saved WMS layer: kanawha_flood_{flow_k}k.wms.json\")\n\n# --- Step 2: Fetch all NSI structures via WFS ---\nprint(\"\\nFetching NSI structures from WFS (88,460 structures) ...\")\nwfs_url = (f\"{GEOSERVER}/ows?service=WFS&amp;version=2.0.0&amp;request=GetFeature\"\n           f\"&amp;typeName=tiger:NSI2022_2026pricelevel&amp;outputFormat=application/json\")\nnsi = gpd.read_file(wfs_url)  # EPSG:4326\nprint(f\"Fetched {len(nsi)} structures\")\n\n# Reproject to EPSG:5070 for depth sampling\nnsi_5070 = nsi.to_crs(epsg=5070)\n\n# --- Step 3: Fetch depth raster via WCS ---\nxmin, ymin, xmax, ymax = nsi_5070.total_bounds\nmargin = 500\nwcs_url = (\n    f\"{GEOSERVER}/ows?service=WCS&amp;version=2.0.1&amp;request=GetCoverage\"\n    f\"&amp;coverageId=tiger:Depth_{scenario}_5070&amp;format=image/tiff\"\n    f\"&amp;SUBSETTINGCRS=http://www.opengis.net/def/crs/EPSG/0/5070\"\n    f\"&amp;SUBSET=X({xmin-margin:.0f},{xmax+margin:.0f})\"\n    f\"&amp;SUBSET=Y({ymin-margin:.0f},{ymax+margin:.0f})\"\n)\nprint(\"Fetching depth raster from WCS ...\")\nresp = requests.get(wcs_url, timeout=120)\nresp.raise_for_status()\n\n# --- Step 4: Sample depth at each structure ---\nwith MemoryFile(resp.content) as memfile:\n    with memfile.open() as src:\n        nodata = src.nodata\n        coords = [(geom.x, geom.y) for geom in nsi_5070.geometry]\n        raw = [v[0] for v in src.sample(coords)]\n\ndepths = []\nfor v in raw:\n    if (nodata is not None and v == nodata) or v &lt;= 0:\n        depths.append(np.nan)\n    else:\n        depths.append(float(v))\n\nnsi[\"depth_ft\"] = depths\nflooded = nsi[nsi[\"depth_ft\"].notna()].copy()\nprint(f\"Flooded structures: {len(flooded):,} of {len(nsi):,}\")\n\n# --- Step 5: Calculate elderly population at risk ---\nelderly_night = flooded[\"POP2AMO65\"].sum()\nelderly_day = flooded[\"POP2PMO65\"].sum()\n\n# Total population for comparison\ntotal_night = flooded[\"POP2AMU65\"].sum() + flooded[\"POP2AMO65\"].sum()\ntotal_day = flooded[\"POP2PMU65\"].sum() + flooded[\"POP2PMO65\"].sum()\nunder65_night = total_night - elderly_night\nunder65_day = total_day - elderly_day\n\n# Calculate percentages\nelderly_night_pct = 100 * elderly_night / total_night if total_night &gt; 0 else 0\nelderly_day_pct = 100 * elderly_day / total_day if total_day &gt; 0 else 0\n\n# Nursing home elderly (most vulnerable)\nnursing_home_elderly = flooded[flooded[\"NURSGHMPOP\"] &gt; 0][\"NURSGHMPOP\"].sum()\n\n# Breakdown by damage category\nby_cat = flooded.groupby(\"ST_DAMCAT\").agg(\n    structures=(\"depth_ft\", \"count\"),\n    elderly_night=(\"POP2AMO65\", \"sum\"),\n    elderly_day=(\"POP2PMO65\", \"sum\"),\n).assign(\n    elderly_total=lambda d: d.elderly_night + d.elderly_day\n).sort_values(\"elderly_total\", ascending=False)\n\n# Breakdown by depth category\ndef depth_category(depth):\n    if depth &lt;= 1:\n  ...
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impa...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/elderly_400k.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/elderly_by_category_400k.csv</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/elderly_by_category_400k.csv"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/elderly_by_depth_400k.csv</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_flood_impacts_sage_/elderly_by_depth_400k.csv"
# }</pre>
#     </div>
#   </details>
# </div>
# # Elderly Population at Risk from Kanawha River Flood at 400,000 cfs
#
# ## Summary Overview
#
# At a flow of **400,000 cfs** on the Kanawha River, **35,695 elderly people** (age 65+) are at risk of flooding. This represents a significant public health concern given the vulnerability of this population to flood-related hazards and evacuation challenges.
#
# ## Elderly Population at Risk
#
# **Nighttime (at home)**: 15,052 people (16.1% of nighttime population)
# **Daytime (work/activities)**: 20,643 people (13.4% of daytime population)
# **Total at risk**: 35,695 people
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">Kanawha River Flood Extent at 400,000 cfs</div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_925f22c855057243998128ecf8f181fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_925f22c855057243998128ecf8f181fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_925f22c855057243998128ecf8f181fd = L.map(
#                 &quot;map_925f22c855057243998128ecf8f181fd&quot;,
#                 {
#                     center: [38.25, -81.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccf8f440390b436518e8d9a3e4fdaf69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ccf8f440390b436518e8d9a3e4fdaf69.addTo(map_925f22c855057243998128ecf8f181fd);
#
#
#             var macro_element_db4cb3eb493cf6b83193c7b66bd1915c = L.tileLayer.wms(
#                 &quot;https://sparcal.sdsc.edu/geoserver/tiger/wms&quot;,
#                 {&quot;attribution&quot;: &quot;&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;tiger:Depth_400000_5070&quot;, &quot;opacity&quot;: 0.7, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_db4cb3eb493cf6b83193c7b66bd1915c.addTo(map_925f22c855057243998128ecf8f181fd);
#
#
#             var layer_control_3e86b2b5e3b726b46a05f664949f578a_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ccf8f440390b436518e8d9a3e4fdaf69,
#                 },
#                 overlays :  {
#                     &quot;Kanawha Flood 400k cfs&quot; : macro_element_db4cb3eb493cf6b83193c7b66bd1915c,
#                 },
#             };
#             let layer_control_3e86b2b5e3b726b46a05f664949f578a = L.control.layers(
#                 layer_control_3e86b2b5e3b726b46a05f664949f578a_layers.base_layers,
#                 layer_control_3e86b2b5e3b726b46a05f664949f578a_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_925f22c855057243998128ecf8f181fd);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# ## Most Vulnerable: Nursing Home Residents
#
# **237 elderly residents** live in nursing homes located within the floodplain. This population is at highest risk due to:
# - Limited mobility requiring specialized evacuation assistance
# - Medical equipment dependency
# - Medication needs
# - Cognitive impairments that complicate emergency response
#
# Evacuation planning for nursing homes requires advanced coordination with emergency services and specialized transportation.
#
# ## Population Comparison
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Population at Risk: Nighttime vs Daytime</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# The total population at risk includes both elderly and younger populations:
#
# | Time | Total Population | Elderly (65+) | Under 65 |
# |------|------------------|---------------|----------|
# | **Nighttime** | 93,482 | 15,052 | 78,430 |
# | **Daytime** | 154,435 | 20,643 | 133,792 |
#
# The higher daytime population reflects people traveling to work, shopping, medical appointments, and other activities. The elderly population during daytime includes those who commute to work, attend medical facilities, or participate in community activities.
#
# ## Impact by Building Category
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Elderly Population by Damage Category</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# Elderly residents are concentrated in residential buildings, which account for **81.3%** of all elderly people at risk:
#
# | Category | Structures | Elderly Night | Elderly Day | Total Elderly |
# |----------|------------|---------------|-------------|---------------|
# | RES (Residential) | 34,757 | 14,507 | 14,507 | 29,014 |
# | COM (Commercial) | 5,949 | 459 | 3,951 | 4,410 |
# | PUB (Public) | 1,296 | 55 | 1,472 | 1,527 |
# | IND (Industrial) | 1,170 | 31 | 713 | 744 |
#
# The high daytime commercial elderly population (3,951) likely includes people at medical offices, retail establishments, and service businesses where elderly individuals work or visit.
#
# ## Impact by Flood Depth
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Elderly Population by Flood Depth</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# Flood depth severity distribution for elderly population:
#
# | Depth Category | Structures | Elderly Total | Avg Depth Context |
# |----------------|-----------|---------------|-------------------|
# | 0-1 ft | 1,006 | 725 | Minimal flooding |
# | 1-3 ft | 2,010 | 1,523 | Moderate flooding |
# | 3-6 ft | 3,589 | 3,337 | Severe flooding |
# | **>6 ft** | **36,567** | **30,110** | **Catastrophic flooding** |
#
# **84.4%** of elderly people at risk (30,110 out of 35,695) would face water depths exceeding **6 feet**, creating extremely dangerous conditions that would complicate or prevent evacuation.
#
# ## Structure-Level Distribution
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Structures with Elderly Residents by Flood Depth</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# This scatter plot shows individual structures containing elderly residents, sorted by flood depth. Each point represents a structure, with bubble size indicating the number of elderly residents. The concentration of large bubbles (structures with many elderly residents) at higher flood depths indicates that many facilities serving large elderly populations are located in low-lying, flood-prone areas.
#
# ## Key Findings and Implications
#
# 1. **High Concentration in Low-Lying Areas**: 84% of elderly at risk face depths >6 ft, indicating that elderly housing and care facilities are disproportionately located in flood-vulnerable areas.
#
# 2. **Evacuation Challenges**: With 15,052 elderly at home at night and 30,110 facing depths >6 ft, emergency evacuation would require extensive resources, specialized equipment, and coordination with medical facilities.
#
# 3. **Nursing Home Vulnerability**: 237 nursing home residents represent a critical priority for pre-emptive evacuation planning, as they require the most complex evacuation logistics.
#
# 4. **Daytime Expansion Risk**: The 36% increase in elderly population risk during nighttime to daytime (15,052 → 20,643) suggests that many elderly people travel into the floodplain for work or services, expanding exposure during business hours.
#
# 5. **Medical Access Disruption**: The 4,410 elderly people in commercial buildings during daytime likely includes patients at medical offices and clinics, raising concerns about healthcare access during flood events.
#
# ## Recommendations for Emergency Planning
#
# - **Pre-emptive Evacuation Protocols**: Establish mandatory evacuation zones for nursing homes and elderly care facilities at lower flood stages
# - **Specialized Transportation**: Deploy accessible vehicles and medical transport assets specifically for elderly evacuation
# - **Medical Coordination**: Partner with hospitals to ensure continuity of care for evacuated elderly patients
# - **Community Registries**: Maintain registries of elderly residents with mobility limitations who require evacuation assistance
# - **Multi-Language Communication**: Ensure evacuation instructions reach non-English speaking elderly populations
# - **Post-Flood Support**: Plan for temporary housing, medication management, and medical care services for displaced elderly residents
