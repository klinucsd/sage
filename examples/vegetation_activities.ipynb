# %% [markdown]
#  # California Vegetation Treatments Tracking System
#
# California's wildfire risk is shaped not just by ignitions, but by ongoing
# vegetation treatment work — prescribed fire, mechanical fuels reduction,
# targeted grazing, timber harvest, and tree planting — carried out by federal,
# state, tribal, and private organizations across the state. The **Interagency
# Tracking System (ITS): Activity Report** consolidates these activities into a
# single statewide layer, recording who performed each treatment, where, when,
# what type, on what land ownership, and how much area was affected.
# This notebook explores the full ITS V2.0 dataset (~168,000 activity records)
# served as a public ArcGIS Feature Service:
# - **Service:** `https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0`
# - **Coverage:** California, 2021 onward (with planned activities through 2030)
# - **Geometry:** Point per activity; native projection EPSG:3857 (Web Mercator), served as EPSG:4326 (WGS84) on request
#
#
# You can ask for treatments by:
# - **Activity category** — prescribed fire, mechanical fuels reduction,  grazing, timber harvest, tree planting
# - **Administering organization** — CAL FIRE, U.S. Forest Service, BLM,
# National Park Service, CAL TRANS, and ~25 others
# - **County, region, ownership group, vegetation type, status, or year**
# Each query returns a GeoDataFrame and an automatically-rendered map; the
# points can be colored by any categorical field (e.g., `administering_org`,
# `activity_cat`) with a legend on the side.
#
#
# No coding needed — just type a natural-language question into each `%%ask` cell.

# %%
# %reset

# %%
# %%skill
# https://github.com/klinucsd/sage_skills/tree/main/fire/ca-vegetation-treatments
# Out:
# <hr style='margin:8px 0'/><div style='line-height:1.35'><b>Skills install summary</b><div style='margin-top:4px'>✅ <b>Installed (1)</b> — available in the next <code>%%ask</code> cell:</div><ul style='margin:2px 0 0 0; padding-left:1.5em'><li><b>ca-vegetation-treatments</b> ← <code>klinucsd/sage_skills@main/fire/ca-vegetation-treatments</code></li></ul><div style='margin-top:4px;color:#64748B;font-size:0.9em'>Note: one or more skills are pinned to a branch. If a future rerun gives different results, check the skill repo for recent changes.</div></div>

# %%
# %%ask
# Show me all prescribed fire activities in Southern California from 2024,
# colored by vegetation types.
# Out:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 4 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       🔄 Query prescribed fire activities in Southern California from 2024 via ArcGIS Feature Service<br>⏳ Save GeoJSON with vegetation-type colormap for map display<br>⏳ Create bar chart of acres by vegetation type<br>⏳ Write summary report with map and chart
#     </div>
#   </details>
# </div>
# Writing the script to query prescribed fire activities in Southern California for 2024.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/query_prescribed_fire.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/query_prescribed_fire.py",
#   "content": "import geopandas as gpd\nimport pandas as pd\nimport requests\nimport json\nimport os\nimport matplotlib.pyplot as plt\n\n# Working directory\noutdir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_\"\nos.makedirs(outdir, exist_ok=True)\n\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\ndef get_all_features(service_url, where, bbox=None):\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n        all_features.extend(feats)\n        if len(feats) &lt; batch_size:\n            break\n        offset += batch_size\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n# Query: prescribed fire in Southern California, year 2024\nwhere = \"activity_cat = 'PRESCRB_FIRE' AND region = 'SOUTHERN_CA' AND year_txt = '2024'\"\nprint(f\"Querying: {where}\")\ngdf = get_all_features(url, where)\nprint(f\"Found {len(gdf)} prescribed fire activities in Southern California for 2024\")\n\nif len(gdf) == 0:\n    print(\"No results found. Exiting.\")\n    import sys; sys.exit(0)\n\n# Inspect columns\nprint(f\"Columns: {list(gdf.columns)}\")\n\n# Vegetation type breakdown\nveg_counts = gdf['broad_vegetation_type'].value_counts()\nprint(f\"\\nVegetation type breakdown:\")\nprint(veg_counts)\n\n# Vegetation type labels\nveg_names = {\n    'FOREST': 'Forest',\n    'SHRB_CHAP': 'Shrubland/Chaparral',\n    'GRASS_HERB': 'Grass/Herbaceous',\n    'WETLAND': 'Wetland',\n    'SPARSE': 'Sparse',\n    'AGRICULTURE': 'Agriculture',\n    'URBAN': 'Urban',\n    'WATER': 'Water',\n}\n\n# Acres by vegetation type\nacres_df = gdf[gdf['activity_uom'] == 'AC'].copy()\nacres_by_veg = acres_df.groupby('broad_vegetation_type')['activity_quantity'].sum().sort_values(ascending=False)\nprint(f\"\\nAcres treated by vegetation type:\")\nfor veg_code, acres in acres_by_veg.items():\n    print(f\"  {veg_names.get(veg_code, veg_code)}: {acres:,.1f} acres\")\n\ntotal_acres = acres_by_veg.sum()\nprint(f\"\\nTotal acres: {total_acres:,.1f}\")\n\n# Status breakdown\nstatus_counts = gdf['activity_status'].value_counts()\nprint(f\"\\nStatus breakdown:\")\nprint(status_counts)\n\n# Administering org breakdown\norg_counts = gdf['administering_org'].value_counts()\nprint(f\"\\nAdministering org breakdown:\")\nprint(org_counts)\n\n# --- Save GeoJSON ---\ngeojson_path = os.path.join(outdir, \"socal_prescribed_fire_2024.geojson\")\ngdf.to_file(geojson_path, driver=\"GeoJSON\")\nprint(f\"\\nSaved GeoJSON: {geojson_path}\")\n\n# --- Save colormap by vegetation type ---\n# Use a green-family palette for vegetation types\nveg_palette = {\n    'FOREST': '#006837',\n    'SHRB_CHAP': '#a1d99b',\n    'GRASS_HERB': '#d9f0a3',\n    'WETLAND': '#74c476',\n    'SPARSE': '#fdae6b',\n    'AGRICULTURE': '#e6f598',\n    'URBAN': '#bdbdbd',\n    'WATER': '#3182bd',\n}\n\n# Build palette with human-readable labels for the legend\npalette_out = {}\nfor code in gdf['broad_vegetation_type'].unique():\n    label = veg_names.get(code, code)\n   ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/query_prescribed_fire.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/query_prescribed_fire.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 4 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       ✅ Query prescribed fire activities in Southern California from 2024 via ArcGIS Feature Service<br>✅ Save GeoJSON with vegetation-type colormap for map display<br>✅ Create bar chart of acres by vegetation type<br>🔄 Write summary report with map and chart
#     </div>
#   </details>
# </div>
# ---
#
# ## 2024 Prescribed Fire Activities in Southern California — by Vegetation Type
#
# **Total activities** : 164 prescribed fire records across the SOUTHERN_CA region in 2024.
# **Total acres treated** : **8,525.5 acres** (112 completed, 52 active).
#
# ---
#
# ### Map
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">Prescribed Fire Activities — Southern California 2024</div><div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fbba2150b13574fbfe95533a937fc18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed;bottom:30px;left:10px;z-index:9999;background:white;padding:8px 12px;border-radius:6px;box-shadow:0 2px 8px rgba(0,0,0,0.3);font-family:sans-serif;min-width:150px;max-width:200px;max-height:320px;overflow-y:auto&quot;&gt;&lt;div style=&quot;font-weight:700;font-size:12px;margin-bottom:6px;padding-bottom:4px;border-bottom:2px solid #ddd;color:#222&quot;&gt;Legend&lt;/div&gt;&lt;div style=&quot;margin-bottom:8px&quot;&gt;&lt;div style=&quot;font-weight:600;font-size:11px;color:#333;margin-bottom:3px;padding-bottom:3px;border-bottom:1px solid #e8e8e8&quot;&gt;Vegetation Type&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#a1d99b;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;Shrubland/Chaparral&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#d9f0a3;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;Grass/Herbaceous&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#bdbdbd;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;Urban&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#006837;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;Forest&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#e6f598;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;Agriculture&lt;/span&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fbba2150b13574fbfe95533a937fc18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
# (function() {
#     // Scroll-away-and-back corruption:
#     //   JupyterLab&#x27;s cell virtualization scrolls the map offscreen and back
#     //   without changing its container&#x27;s dimensions. Leaflet&#x27;s internal tile
#     //   state gets corrupted (map reverts to a single top-left tile and zoom
#     //   controls stop responding) but invalidateSize() alone cannot recover
#     //   — a fitBounds() is required.
#     //   ResizeObserver doesn&#x27;t fire because the container size never changes,
#     //   so we use IntersectionObserver to detect viewport re-entry. Maps used
#     //   to render inside a Folium iframe, where IntersectionObserver fires
#     //   immediately regardless of parent scroll (v1.0.66 history); now the
#     //   map is rendered directly into the notebook DOM, so it works.
#     function _fit() {
#         if (typeof map_9fbba2150b13574fbfe95533a937fc18 === &#x27;undefined&#x27;) return;
#         try {
#             var _el = document.getElementById(&#x27;map_9fbba2150b13574fbfe95533a937fc18&#x27;);
#             if (!_el || _el.offsetWidth === 0 || _el.offsetHeight === 0) return;
#             map_9fbba2150b13574fbfe95533a937fc18.invalidateSize();
#             map_9fbba2150b13574fbfe95533a937fc18.fitBounds([[32.61482441801357,-118.82108753770227],[35.23632827386145,-115.57335834739011]],{maxZoom:10});
#         } catch (e) { /* ignore */ }
#     }
#     [50, 150, 400, 800, 1500, 3000, 6000, 10000, 15000].forEach(function(ms) {
#         setTimeout(_fit, ms);
#     });
#     if (typeof window !== &#x27;undefined&#x27; &amp;&amp; window.addEventListener) {
#         window.addEventListener(&#x27;load&#x27;, _fit);
#         window.addEventListener(&#x27;resize&#x27;, _fit);
#     }
#     var _el0 = document.getElementById(&#x27;map_9fbba2150b13574fbfe95533a937fc18&#x27;);
#     if (_el0 &amp;&amp; window.IntersectionObserver) {
#         // Re-fit every time the map scrolls back into the viewport. Trade-off:
#         // user&#x27;s pan/zoom is reset on scroll-away-and-back. Acceptable for
#         // narrative notebooks where the fit-to-data view is what the reader
#         // e
# ---
#
# ### Acres by Vegetation Type
#
# | Vegetation Type | Activities | Acres Treated |
# |---|---|---|
# | Forest | 65 | 4,987 |
# | Shrubland/Chaparral | 66 | 2,503 |
# | Grass/Herbaceous | 25 | 677 |
# | Agriculture | 3 | 286 |
# | Urban | 5 | 72 |
#
# Forest and shrubland/chaparral dominate both count and acreage, together accounting for **88%** of treated acres.
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Acres by Vegetation Type</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# ---
#
# ### Acres by County
#
# | County | Acres |
# |---|---|
# | San Diego | 5,290 |
# | Los Angeles | 1,620 |
# | Riverside | 979 |
# | Imperial | 307 |
# | San Bernardino | 251 |
# | Kern | 78 |
#
# San Diego County accounts for **62%** of all prescribed fire acres in the region.
#
# ### Acres by Administering Organization
#
# | Organization | Acres |
# |---|---|
# | USFS (U.S. Forest Service) | 3,499 |
# | SDRC (San Diego RCD) | 3,109 |
# | CAL FIRE | 1,446 |
# | FWS (U.S. Fish & Wildlife) | 280 |
# | DOD (Dept. of Defense) | 71 |
# | CA State Parks | 63 |
# | BLM (Bureau of Land Mgmt.) | 58 |
#
# The U.S. Forest Service and San Diego Resource Conservation District together treat **78%** of the prescribed fire acreage.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 4 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       ✅ Query prescribed fire activities in Southern California from 2024 via ArcGIS Feature Service<br>✅ Save GeoJSON with vegetation-type colormap for map display<br>✅ Create bar chart of acres by vegetation type<br>✅ Write summary report with map and chart
#     </div>
#   </details>
# </div>
# All output files are saved in your working directory:
#
# - **GeoJSON** : `socal_prescribed_fire_2024.geojson`
# - **Colormap** : `socal_prescribed_fire_2024.colormap.json`
# - **Chart** : `socal_prescribed_fire_2024_by_veg.png`

# %%
# %%ask
# How many acres of mechanical fuel reduction treatments were completed in Southern
# California counties in 2023? visualize the result as a pie chart only.
# Out:
# Let me consult the vegetation treatments skill first.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll write a script to query mechanical fuel reduction treatments in Southern California for 2023 and produce a pie chart.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/mech_fuel_reduction_socal_2023.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/mech_fuel_reduction_socal_2023.py",
#   "content": "import geopandas as gpd\nimport pandas as pd\nimport requests\nimport matplotlib.pyplot as plt\nimport json\nimport os\n\noutdir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_\"\nos.makedirs(outdir, exist_ok=True)\n\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\n# ---- Query function with pagination ----\ndef get_all_features(service_url, where, bbox=None):\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n        all_features.extend(feats)\n        if len(feats) &lt; batch_size:\n            break\n        offset += batch_size\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n# County code -&gt; human-readable name map (SoCal counties)\ncounty_names = {\n    'LA': 'Los Angeles', 'SD': 'San Diego', 'ORA': 'Orange',\n    'RIV': 'Riverside', 'SBD': 'San Bernardino', 'VEN': 'Ventura',\n    'SB': 'Santa Barbara', 'SLO': 'San Luis Obispo', 'IMP': 'Imperial',\n    'INY': 'Inyo', 'KER': 'Kern',\n}\n\n# SoCal county codes\nsocal_counties = list(county_names.keys())\n\n# Query: Mechanical fuel reduction, completed, 2023, acre units, SoCal counties\ncounty_list = \"','\".join(socal_counties)\nwhere = (\n    f\"activity_cat = 'MECH_HFR' \"\n    f\"AND region = 'SOUTHERN_CA' \"\n    f\"AND year_txt = '2023' \"\n    f\"AND activity_uom = 'AC' \"\n    f\"AND county IN ('{county_list}')\"\n)\n\nprint(f\"Querying: {where}\")\ndf = get_all_features(url, where)\nprint(f\"Records found: {len(df)}\")\n\nif df.empty:\n    print(\"No records found. Trying broader query without region filter...\")\n    where2 = (\n        f\"activity_cat = 'MECH_HFR' \"\n        f\"AND year_txt = '2023' \"\n        f\"AND activity_uom = 'AC' \"\n        f\"AND county IN ('{county_list}')\"\n    )\n    df = get_all_features(url, where2)\n    print(f\"Records found (broader): {len(df)}\")\n\nif df.empty:\n    print(\"Still no records. Trying all statuses for MECH_HFR in 2023 SoCal...\")\n    where3 = (\n        f\"activity_cat = 'MECH_HFR' \"\n        f\"AND year_txt = '2023' \"\n        f\"AND county IN ('{county_list}')\"\n    )\n    df = get_all_features(url, where3)\n    print(f\"Records found (all statuses, all units): {len(df)}\")\n    if not df.empty:\n        print(f\"Statuses: {df['activity_status'].value_counts().to_dict()}\")\n        print(f\"Units: {df['activity_uom'].value_counts().to_dict()}\")\n\nif df.empty:\n    print(\"No mechanical fuel reduction data found for SoCal 2023.\")\nelse:\n    # Filter to acre units if we got all units\n    df_acres = df[df['activity_uom'] == 'AC'].copy()\n    print(f\"\\nRecords with acre units: {len(df_acres)}\")\n\n    # Group by county\n    by_county = df_acres.groupby('county')['activity_quantity'].sum()\n    # Map to readable names\n    by_county.index = by_county.index.map(lambda c: county_names.get(c, c))\n    by_county = by_county.sort_values(ascending=False)\n\n    total_acres = by_county.sum()\n    print(f\"\\nTotal acres of mecha ...
# }</pre>
#     </div>
#   <
# Running the script to query the ArcGIS feature service and generate the pie chart.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/mech_fuel_reduction_socal_2023.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/mech_fuel_reduction_socal_2023.py</pre>
#     </div>
#   </details>
# </div>
# The data is retrieved and the chart is generated. Here's the summary:
#
# ---
#
# ## Mechanical Fuel Reduction Treatments — Southern California, 2023
#
# **Total acres** : 87,626 across 8 counties and 17,191 individual activity records.
#
# | County | Acres |
# |---|---|
# | **Los Angeles** | 28,166 |
# | **Riverside** | 16,335 |
# | **San Diego** | 16,234 |
# | **San Bernardino** | 14,363 |
# | **Orange** | 7,561 |
# | **Imperial** | 3,138 |
# | **Ventura** | 1,482 |
# | **Kern** | 348 |
#
# Los Angeles County leads with nearly a third (32%) of all mechanical fuel reduction acreage, followed by Riverside (19%) and San Diego (19%). Note: San Luis Obispo and Inyo counties had no mechanical fuel reduction acreage reported in 2023.
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Mechanical Fuel Reduction in Southern California 2023</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>

# %%
# %%ask
# Compare CALFIRE treatment actvities in San Diego county in 2023 and 2024.
# Out:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 5 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       🔄 Read the ca-vegetation-treatments SKILL.md for data fetching guidance<br>⏳ Fetch CALFIRE treatment activities for San Diego county (2023 and 2024)<br>⏳ Build comparison analysis (acres by activity type, year-over-year change)<br>⏳ Generate GeoJSON layers, colormap, and comparison chart<br>⏳ Write final report with map and chart
#     </div>
#   </details>
# </div>
# Reading the vegetation treatments skill to get the correct API endpoint and query parameters.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 5 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       ✅ Read the ca-vegetation-treatments SKILL.md for data fetching guidance<br>🔄 Fetch CALFIRE treatment activities for San Diego county (2023 and 2024)<br>⏳ Build comparison analysis (acres by activity type, year-over-year change)<br>⏳ Generate GeoJSON layers, colormap, and comparison chart<br>⏳ Write final report with map and chart
#     </div>
#   </details>
# </div>
# Now I'll write a script that fetches CALFIRE activities for San Diego county in 2023 and 2024, builds the comparison, and generates the outputs.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/socal_calfire_sd_compare.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/socal_calfire_sd_compare.py",
#   "content": "#!/usr/bin/env python\n\"\"\"\nCompare CALFIRE treatment activities in San Diego County: 2023 vs 2024.\nGenerates:\n  - socal_calfire_sd_2023.geojson (2023 activities)\n  - socal_calfire_sd_2024.geojson (2024 activities)\n  - socal_calfire_sd_compare.geojson (combined with year label)\n  - socal_calfire_sd_compare.colormap.json (color by year)\n  - socal_calfire_sd_compare_chart.png (grouped bar chart by activity category)\n\"\"\"\nimport os\nimport json\nimport requests\nimport geopandas as gpd\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport matplotlib.ticker as mticker\n\nOUTDIR = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_\"\nos.makedirs(OUTDIR, exist_ok=True)\n\nURL = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\n# ---------------------------------------------------------------------------\n# Query helper (paginated)\n# ---------------------------------------------------------------------------\ndef get_all_features(service_url, where, bbox=None):\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n        all_features.extend(feats)\n        if len(feats) &lt; batch_size:\n            break\n        offset += batch_size\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n# ---------------------------------------------------------------------------\n# Fetch data for both years\n# ---------------------------------------------------------------------------\nwhere_2023 = \"administering_org = 'CALFIRE' AND county = 'SD' AND year_txt = '2023'\"\nwhere_2024 = \"administering_org = 'CALFIRE' AND county = 'SD' AND year_txt = '2024'\"\n\nprint(\"Fetching 2023 CALFIRE / San Diego activities …\")\ndf23 = get_all_features(URL, where_2023)\nprint(f\"  → {len(df23)} records\")\n\nprint(\"Fetching 2024 CALFIRE / San Diego activities …\")\ndf24 = get_all_features(URL, where_2024)\nprint(f\"  → {len(df24)} records\")\n\n# Add a year label\ndf23[\"year\"] = \"2023\"\ndf24[\"year\"] = \"2024\"\n\n# ---------------------------------------------------------------------------\n# Save separate GeoJSON layers\n# ---------------------------------------------------------------------------\np23 = os.path.join(OUTDIR, \"socal_calfire_sd_2023.geojson\")\np24 = os.path.join(OUTDIR, \"socal_calfire_sd_2024.geojson\")\ndf23.to_file(p23, driver=\"GeoJSON\")\ndf24.to_file(p24, driver=\"GeoJSON\")\nprint(f\"Saved {p23}\")\nprint(f\"Saved {p24}\")\n\n# Combined GeoJSON with year label for coloring\ncombined = pd.concat([df23, df24], ignore_index=True)\np_comb = os.path.join(OUTDIR, \"socal_calfire_sd_compare.geojson\")\ncombined.to_file(p_comb, driver=\"GeoJSON\")\nprint(f\"Saved combined → {p_comb}\")\n\n# Colormap: color by year\ncolormap = {\n    \"field\": \"year\",\n    \"title\": \"Year\",\n    \"palette\": {\n        \"2023\": \"#3182bd\",  # blue\n        \"2024\": \"#e6550d\",  # orange\n    },\n}\np_cm = os.path.join(OUTDIR, \"socal_calfire_sd_compare.colormap.jso ...
# Running the script to fetch data and generate all outputs.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/socal_calfire_sd_compare.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/socal_calfire_sd_compare.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 5 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       ✅ Read the ca-vegetation-treatments SKILL.md for data fetching guidance<br>✅ Fetch CALFIRE treatment activities for San Diego county (2023 and 2024)<br>✅ Build comparison analysis (acres by activity type, year-over-year change)<br>✅ Generate GeoJSON layers, colormap, and comparison chart<br>🔄 Write final report with map and chart
#     </div>
#   </details>
# </div>
# All data fetched and outputs generated. Here is the full comparison:
#
# ---
#
# ## CALFIRE Treatment Activities — San Diego County: 2023 vs 2024
#
# **Total records** : 144 in 2023, 277 in 2024 (93% more activity records).
# **Total acres** : 3,460 in 2023 vs 2,656 in 2024 — a **23% decline** in treated acreage despite nearly double the number of records.
#
# ### Acres by Activity Category
#
# | Category | 2023 Acres | 2024 Acres | Change |
# |---|---|---|---|
# | **Mech. Fuels Reduction** | 1,917 | 1,790 | −7% |
# | **Prescribed Fire** | 1,190 | 866 | −27% |
# | **Tree Planting** | 353 | 0 | −100% |
#
# ### Key Findings
#
# - **Mechanical Fuels Reduction** remains the dominant activity in both years, but acreage dropped slightly (−7%) while the number of records nearly doubled (131 → 238), suggesting smaller individual treatment units in 2024.
# - **Prescribed Fire** acreage fell 27% year-over-year (1,190 → 866 acres), though the number of prescribed fire events nearly quadrupled (10 → 39).
# - **Tree Planting** had 353 acres in 2023 but no recorded CALFIRE activities in 2024.
# - The overall pattern shows more numerous but smaller treatments in 2024.
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>CALFIRE San Diego 2023 vs 2024</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">CALFIRE San Diego Treatment Activities 2023 vs 2024</div><div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_008d6d941ffb1f4e416762d77be4221f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed;bottom:30px;left:10px;z-index:9999;background:white;padding:8px 12px;border-radius:6px;box-shadow:0 2px 8px rgba(0,0,0,0.3);font-family:sans-serif;min-width:150px;max-width:200px;max-height:320px;overflow-y:auto&quot;&gt;&lt;div style=&quot;font-weight:700;font-size:12px;margin-bottom:6px;padding-bottom:4px;border-bottom:2px solid #ddd;color:#222&quot;&gt;Legend&lt;/div&gt;&lt;div style=&quot;margin-bottom:8px&quot;&gt;&lt;div style=&quot;font-weight:600;font-size:11px;color:#333;margin-bottom:3px;padding-bottom:3px;border-bottom:1px solid #e8e8e8&quot;&gt;Year&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#3182bd;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;2023&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#e6550d;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;2024&lt;/span&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_008d6d941ffb1f4e416762d77be4221f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
# (function() {
#     // Scroll-away-and-back corruption:
#     //   JupyterLab&#x27;s cell virtualization scrolls the map offscreen and back
#     //   without changing its container&#x27;s dimensions. Leaflet&#x27;s internal tile
#     //   state gets corrupted (map reverts to a single top-left tile and zoom
#     //   controls stop responding) but invalidateSize() alone cannot recover
#     //   — a fitBounds() is required.
#     //   ResizeObserver doesn&#x27;t fire because the container size never changes,
#     //   so we use IntersectionObserver to detect viewport re-entry. Maps used
#     //   to render inside a Folium iframe, where IntersectionObserver fires
#     //   immediately regardless of parent scroll (v1.0.66 history); now the
#     //   map is rendered directly into the notebook DOM, so it works.
#     function _fit() {
#         if (typeof map_008d6d941ffb1f4e416762d77be4221f === &#x27;undefined&#x27;) return;
#         try {
#             var _el = document.getElementById(&#x27;map_008d6d941ffb1f4e416762d77be4221f&#x27;);
#             if (!_el || _el.offsetWidth === 0 || _el.offsetHeight === 0) return;
#             map_008d6d941ffb1f4e416762d77be4221f.invalidateSize();
#             map_008d6d941ffb1f4e416762d77be4221f.fitBounds([[32.61482441801357,-117.35910649880019],[33.43234832850988,-116.26760502646913]],{maxZoom:10});
#         } catch (e) { /* ignore */ }
#     }
#     [50, 150, 400, 800, 1500, 3000, 6000, 10000, 15000].forEach(function(ms) {
#         setTimeout(_fit, ms);
#     });
#     if (typeof window !== &#x27;undefined&#x27; &amp;&amp; window.addEventListener) {
#         window.addEventListener(&#x27;load&#x27;, _fit);
#         window.addEventListener(&#x27;resize&#x27;, _fit);
#     }
#     var _el0 = document.getElementById(&#x27;map_008d6d941ffb1f4e416762d77be4221f&#x27;);
#     if (_el0 &amp;&amp; window.IntersectionObserver) {
#         // Re-fit every time the map scrolls back into the viewport. Trade-off:
#         // user&#x27;s pan/zoom is reset on scroll-away-and-back. Acceptable for
#         // narrative notebooks where the fit-to-data view is what the reader
#         // expects; recovery from the corruption is the priority.
#         new IntersectionObserver(function(entries) {
#             entries.forEach(function(e) { if (e.isIntersecting) _fit(); });
#         }, { threshold: 0.01 }).observe(_el0);
#     }
#     if (_el0 &amp;&amp; window.ResizeObserver) {
#         new ResizeObserver(_fit).observe(_el0);
#     }
# })();
#
#             var map_008d6d941ffb1f4e416762d77be4221f = L.map(
#                 &quot;map_008d6d941ffb1f4e416762d77be4221f&quot;,
#                 {
#                     center: [33.02358637326172, -116.81335576263466],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddcefcc82a267f819e9fcd9d31b20ed5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quo
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 5 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       ✅ Read the ca-vegetation-treatments SKILL.md for data fetching guidance<br>✅ Fetch CALFIRE treatment activities for San Diego county (2023 and 2024)<br>✅ Build comparison analysis (acres by activity type, year-over-year change)<br>✅ Generate GeoJSON layers, colormap, and comparison chart<br>✅ Write final report with map and chart
#     </div>
#   </details>
# </div>
# All done. The map shows CALFIRE treatment locations in San Diego County colored by year (blue = 2023, orange = 2024), and the grouped bar chart breaks down treated acres by activity category for easy year-over-year comparison.

# %%
# %%ask
# which top 3 counties have the maximum treatment acres in 2024?
# Please show the county full names and visualize the result.
# Out:
# Reading the vegetation treatments skill for the correct API usage.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll write and run a script to query all 2024 treatment acres by county and visualize the top 3.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/top3_counties_2024.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/top3_counties_2024.py",
#   "content": "import geopandas as gpd\nimport pandas as pd\nimport requests\nimport matplotlib.pyplot as plt\nimport json\nimport os\n\n# --- Working directory ---\noutdir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_\"\nos.makedirs(outdir, exist_ok=True)\n\n# --- Service URL ---\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\n# --- Pagination helper ---\ndef get_all_features(service_url, where, bbox=None):\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n        all_features.extend(feats)\n        if len(feats) &lt; batch_size:\n            break\n        offset += batch_size\n\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n# --- County code to full name mapping ---\ncounty_names = {\n    'LA': 'Los Angeles', 'SD': 'San Diego', 'SF': 'San Francisco',\n    'SAC': 'Sacramento', 'ORA': 'Orange', 'RIV': 'Riverside',\n    'SBD': 'San Bernardino', 'VEN': 'Ventura', 'SCL': 'Santa Clara',\n    'ALA': 'Alameda', 'CC': 'Contra Costa', 'SM': 'San Mateo',\n    'FRE': 'Fresno', 'KER': 'Kern', 'TUL': 'Tulare', 'MON': 'Monterey',\n    'BUT': 'Butte', 'SHA': 'Shasta', 'SIS': 'Siskiyou', 'HUM': 'Humboldt',\n    'MEN': 'Mendocino', 'SON': 'Sonoma', 'NAP': 'Napa', 'LAK': 'Lake',\n    'PLU': 'Plumas', 'LAS': 'Lassen', 'MOD': 'Modoc', 'TEH': 'Tehama',\n    'ED': 'El Dorado', 'PLA': 'Placer', 'NEV': 'Nevada', 'SIE': 'Sierra',\n    'TUO': 'Tuolumne', 'MPA': 'Mariposa', 'MAD': 'Madera', 'MER': 'Merced',\n    'STA': 'Stanislaus', 'SJ': 'San Joaquin', 'SBT': 'San Benito',\n    'SCR': 'Santa Cruz', 'SB': 'Santa Barbara', 'SLO': 'San Luis Obispo',\n    'IMP': 'Imperial', 'INY': 'Inyo', 'MNO': 'Mono', 'ALP': 'Alpine',\n    'AMA': 'Amador', 'CAL': 'Calaveras', 'COL': 'Colusa', 'GLE': 'Glenn',\n    'KIN': 'Kings', 'MRN': 'Marin', 'DN': 'Del Norte', 'SOL': 'Solano',\n    'SUT': 'Sutter', 'TRI': 'Trinity', 'YOL': 'Yolo', 'YUB': 'Yuba',\n    'NON_SPATIAL': 'Non-Spatial',\n}\n\n# --- Query: all 2024 activities measured in acres ---\nwhere = \"year_txt = '2024' AND activity_uom = 'AC'\"\nprint(\"Querying 2024 acreage activities statewide...\")\ndf = get_all_features(url, where)\nprint(f\"Retrieved {len(df)} records\")\n\n# --- Group by county, sum acres ---\nacres_by_county = df.groupby('county')['activity_quantity'].sum().sort_values(ascending=False)\n\n# Map to full names\ntop3 = acres_by_county.head(3)\ntop3_named = top3.rename(index=county_names)\nprint(\"\\nTop 3 counties by treatment acres in 2024:\")\nfor name, acres in top3_named.items():\n    print(f\"  {name}: {acres:,.1f} acres\")\nprint(f\"\\nTotal across all counties: {acres_by_county.sum():,.1f} acres\")\n\n# --- Save top-3 GeoJSON for map ---\ntop3_codes = top3.index.tolist()\ntop3_gdf = df[df['county'].isin(top3_codes)].copy()\ntop3_gdf['county_full'] = top3_gdf['county'].map(county_names)\n\ngeojson_path = os.path.join(outdir, \"top3_counties_2024.geojson\")\ntop3_gdf.to_file(geojson_path, driver=\"GeoJSON\")\nprint(f\"\\n ...
# }</pre>
#     </div>
#   </details>
# </div>
# Running the script to query the 2024 treatment data and generate the visualization.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/top3_counties_2024.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage_demo/_vegetation_activities_sage_/top3_counties_2024.py</pre>
#     </div>
#   </details>
# </div>
# Here are the results:
#
# ## Top 3 California Counties by Treatment Acres in 2024
#
# Across all 45,600 acreage-denominated treatment records in 2024, totaling **886,219 acres** statewide, the top three counties are:
#
# | Rank | County | Acres Treated |
# |------|--------|---------------|
# | 1 | **Siskiyou** | 92,785 |
# | 2 | **Del Norte** | 62,338 |
# | 3 | **Tehama** | 51,773 |
#
# These three Northern California counties alone account for ~23% of the state's total treatment acreage in 2024.
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Top 3 Counties by Treatment Acres 2024</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">Treatment Locations in Top 3 Counties</div><div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5429237826b0a261f2deb24910a69c44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed;bottom:30px;left:10px;z-index:9999;background:white;padding:8px 12px;border-radius:6px;box-shadow:0 2px 8px rgba(0,0,0,0.3);font-family:sans-serif;min-width:150px;max-width:200px;max-height:320px;overflow-y:auto&quot;&gt;&lt;div style=&quot;font-weight:700;font-size:12px;margin-bottom:6px;padding-bottom:4px;border-bottom:2px solid #ddd;color:#222&quot;&gt;Legend&lt;/div&gt;&lt;div style=&quot;margin-bottom:8px&quot;&gt;&lt;div style=&quot;font-weight:600;font-size:11px;color:#333;margin-bottom:3px;padding-bottom:3px;border-bottom:1px solid #e8e8e8&quot;&gt;County&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#de2d26;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;Siskiyou&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#756bb1;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;Del Norte&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#fb6a4a;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;Tehama&lt;/span&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5429237826b0a261f2deb24910a69c44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
# (function() {
#     // Scroll-away-and-back corruption:
#     //   JupyterLab&#x27;s cell virtualization scrolls the map offscreen and back
#     //   without changing its container&#x27;s dimensions. Leaflet&#x27;s internal tile
#     //   state gets corrupted (map reverts to a single top-left tile and zoom
#     //   controls stop responding) but invalidateSize() alone cannot recover
#     //   — a fitBounds() is required.
#     //   ResizeObserver doesn&#x27;t fire because the container size never changes,
#     //   so we use IntersectionObserver to detect viewport re-entry. Maps used
#     //   to render inside a Folium iframe, where IntersectionObserver fires
#     //   immediately regardless of parent scroll (v1.0.66 history); now the
#     //   map is rendered directly into the notebook DOM, so it works.
#     function _fit() {
#         if (typeof map_5429237826b0a261f2deb24910a69c44 === &#x27;undefined&#x27;) return;
#         try {
#             var _el = document.getElementById(&#x27;map_5429237826b0a261f2deb24910a69c44&#x27;);
#             if (!_el || _el.offsetWidth === 0 || _el.offsetHeight === 0) return;
#             map_5429237826b0a261f2deb24910a69c44.invalidateSize();
#             map_5429237826b0a261f2deb24910a69c44.fitBounds([[39.897103770398,-124.22809652697056],[42.00120706201077,-121.36801338222052]],{maxZoom:10});
#         } catch (e) { /* ignore */ }
#     }
#     [50, 150, 400, 800, 1500, 3000, 6000, 10000, 15000].forEach(function(ms) {
#         setTimeout(_fit, ms);
#     });
#     if (typeof window !== &#x27;undefined&#x27; &amp;&amp; window.addEventListener) {
#         window.addEventListener(&#x27;load&#x27;, _fit);
#         window.addEventListener(&#x27;resize&#x27;, _fit);
#     }
#     var _el0 = document.getElementById(&#x27;map_5429237826b0a261f2deb24910a69c44&#x27;);
#     if (_el0 &amp;&amp; window.IntersectionObserver) {
#         // Re-fit every time the map scrolls back into the viewport. Trade-off:
#         // user&#x27;s pan/zoom is reset on scroll-away-and-back. Acceptable for
#         // narrative notebooks where the fit-to-data view is what the reader
#         // expects; recovery from the corruption is the priority.
#         new IntersectionObserver(function(entries) {
#             entries.forEach(function(e) { if (e.isIntersecting) _fit(); });
#         }, { threshold: 0.01 }).observe(_el0);
#     }
#     if (_el0 &amp;&amp; window.ResizeObserver) {
#         new ResizeObserver(_fit).observe(_el0);
#     }
# })();
#
#             var map_5429237826b0a261f2deb24910a69c44 = L.map(
#                 &quot;map_5429237826b0a261f2deb24910a69c44&quot;,
#                 {
#                     center: [40.949155416204384, -122.79805495459554],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quo
