# %% [markdown]
#  # California Vegetation Treatments Tracking System
#
# California's wildfire risk is shaped not just by ignitions, but by ongoing
# vegetation treatment work — prescribed fire, mechanical fuels reduction,
# targeted grazing, timber harvest, and tree planting — carried out by federal,
# state, tribal, and private organizations across the state. The **Interagency
# Tracking System (ITS): Activity Report** consolidates these activities into a
# single statewide layer, recording who performed each treatment, where, when,
# what type, on what land ownership, and how much area was affected.
# This notebook explores the full ITS V2.0 dataset (~168,000 activity records)
# served as a public ArcGIS Feature Service:
# - **Service:** `https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0`
# - **Coverage:** California, 2021 onward (with planned activities through 2030)
# - **Geometry:** Point per activity; native projection EPSG:3857 (Web Mercator), served as EPSG:4326 (WGS84) on request
#
#
# You can ask for treatments by:
# - **Activity category** — prescribed fire, mechanical fuels reduction,  grazing, timber harvest, tree planting
# - **Administering organization** — CAL FIRE, U.S. Forest Service, BLM,
# National Park Service, CAL TRANS, and ~25 others
# - **County, region, ownership group, vegetation type, status, or year**
# Each query returns a GeoDataFrame and an automatically-rendered map; the
# points can be colored by any categorical field (e.g., `administering_org`,
# `activity_cat`) with a legend on the side.
#
#
# No coding needed — just type a natural-language question into each `%%ask` cell.

# %%
# %reset

# %%
# %%ask
# Show me all prescribed fire activities in Southern California from 2024,
# colored by vegetation types.
# Out:
# I'll help you find prescribed fire activities in Southern California from 2024, colored by vegetation types. Let me start by checking the CA vegetation treatments skill to understand how to access this data.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll query the CA vegetation treatments service for prescribed fire activities in Southern California from 2024, colored by vegetation types.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/prescribed_fire_socal_2024.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/prescribed_fire_socal_2024.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nQuery prescribed fire activities in Southern California from 2024,\ncolored by vegetation types.\n\"\"\"\n\nimport geopandas as gpd\nimport pandas as pd\nimport requests\nimport json\nimport os\n\n# Set working directory\nWORK_DIR = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_\"\nos.makedirs(WORK_DIR, exist_ok=True)\n\n# Service URL\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\n\ndef get_all_features(service_url, where, bbox=None):\n    \"\"\"\n    Query the service and handle pagination for &gt;2000 results.\n    \"\"\"\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n\n        all_features.extend(feats)\n\n        if len(feats) &lt; batch_size:\n            break\n\n        offset += batch_size\n\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n\n# Query: Prescribed fire in Southern California, 2024\nwhere = \"activity_cat = 'PRESCRB_FIRE' AND region = 'SOUTHERN_CA' AND year_txt = '2024'\"\nprint(f\"Querying: {where}\")\nprint()\n\ndf = get_all_features(url, where)\n\nprint(f\"Found {len(df)} prescribed fire activities in Southern California (2024)\")\nprint()\n\nif len(df) &gt; 0:\n    # Check CRS\n    print(f\"CRS: {df.crs}\")\n    print()\n\n    # Convert epoch ms to readable dates\n    df['end_date'] = pd.to_datetime(df['activity_end'], unit='ms')\n\n    # Vegetation type mapping\n    veg_type_names = {\n        'FOREST': 'Forest',\n        'SHRB_CHAP': 'Shrublands/Chaparral',\n        'GRASS_HERB': 'Grass/Herbaceous',\n        'WETLAND': 'Wetland',\n        'SPARSE': 'Sparse Vegetation',\n        'AGRICULTURE': 'Agriculture',\n        'URBAN': 'Urban',\n        'WATER': 'Water'\n    }\n\n    # Add human-readable vegetation type\n    df['vegetation_type_name'] = df['broad_vegetation_type'].map(veg_type_names)\n\n    # Summary statistics\n    print(\"Summary by Vegetation Type:\")\n    print(\"=\" * 60)\n    veg_summary = df.groupby('broad_vegetation_type').agg({\n        'activity_quantity': 'sum',\n        'objectid': 'count'\n    }).rename(columns={'activity_quantity': 'total_acres', 'objectid': 'num_activities'})\n\n    # Only sum acres where unit is AC\n    acres_by_veg = df[df['activity_uom'] == 'AC'].groupby('broad_vegetation_type')['activity_quantity'].sum()\n    veg_summary['total_acres'] = acres_by_veg\n\n    veg_summary = veg_summary.sort_values('total_acres', ascending=False)\n    veg_summary['vegetation_name'] = veg_summary.index.map(veg_type_names)\n    print(veg_summary[['vegetation_name', 'num_activities', 'total_acres']].to_string())\n    print()\n\n    total_acres = veg_summary['total_acres'].sum()\n    print(f\"Total acres treated: {total_acres:,.0f}\")\n    print()\n\n    # Summary by county\n    print(\"Summary by County:\")\n    print(\"=\" * 60)\n    county_summary = df[df['activity_uom'] == 'AC'].groupby('county')['activity_quantity'].agg(['sum', 'count'])\n    county_summary.colum ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/prescribed_fire_socal_2024.py</pre>
#     </div>
#   </details>
# </div>
# Now let me create a bar chart to visualize the acres treated by vegetation type:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/prescribed_fire_chart.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/prescribed_fire_chart.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nCreate a bar chart showing prescribed fire acres by vegetation type.\n\"\"\"\n\nimport geopandas as gpd\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport os\n\n# Set working directory\nWORK_DIR = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_\"\n\n# Load the data\ngeojson_path = os.path.join(WORK_DIR, \"prescribed_fire_socal_2024.geojson\")\ndf = gpd.read_file(geojson_path)\n\n# Vegetation type mapping\nveg_type_names = {\n    'FOREST': 'Forest',\n    'SHRB_CHAP': 'Shrublands/Chaparral',\n    'GRASS_HERB': 'Grass/Herbaceous',\n    'WETLAND': 'Wetland',\n    'SPARSE': 'Sparse Vegetation',\n    'AGRICULTURE': 'Agriculture',\n    'URBAN': 'Urban',\n    'WATER': 'Water'\n}\n\n# Filter for acre units only\ndf_acres = df[df['activity_uom'] == 'AC'].copy()\n\n# Group by vegetation type and sum acres\nby_veg = df_acres.groupby('broad_vegetation_type')['activity_quantity'].sum().sort_values(ascending=False)\n\n# Map to human-readable names\nby_veg.index = by_veg.index.map(veg_type_names)\n\n# Create bar chart\nfig, ax = plt.subplots(figsize=(14, 8), dpi=150)\ncolors = ['#006837', '#41ab5d', '#74c476', '#a1d99b', '#c7e9c0', '#f7fcf5', '#d9d9d9', '#9ecae1']\nby_veg.plot.barh(ax=ax, color=colors[:len(by_veg)])\n\nax.set_xlabel('Acres Treated', fontsize=12, fontweight='bold')\nax.set_ylabel('Vegetation Type', fontsize=12, fontweight='bold')\nax.set_title('Prescribed Fire in Southern California (2024): Acres Treated by Vegetation Type',\n             fontsize=14, fontweight='bold')\nax.invert_yaxis()\n\n# Add value labels\nfor i, v in enumerate(by_veg):\n    ax.text(v + 50, i, f'{v:,.0f}', va='center', fontsize=10)\n\nplt.tight_layout()\n\n# Save chart\nchart_path = os.path.join(WORK_DIR, \"prescribed_fire_by_vegetation_type.png\")\nplt.savefig(chart_path, dpi=150, bbox_inches='tight')\nprint(f\"Saved chart → {chart_path}\")\nplt.close()\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/prescribed_fire_chart.py</pre>
#     </div>
#   </details>
# </div>
# ## Prescribed Fire Activities in Southern California (2024)
#
# I found **164 prescribed fire activities** in Southern California during 2024, treating a total of ** 8,525 acres** across five vegetation types.
#
# ### Summary by Vegetation Type
#
# | Vegetation Type | Activities | Acres Treated |
# |-----------------|------------|---------------|
# | Forest | 65 | 4,987 |
# | Shrublands/Chaparral | 66 | 2,503 |
# | Grass/Herbaceous | 25 | 677 |
# | Agriculture | 3 | 286 |
# | Urban | 5 | 72 |
#
# ### Key Findings
#
# **Top Counties by Acres Treated:**
# - **San Diego (SD)** : 5,290 acres (72 activities)
# - **Los Angeles (LA)** : 1,620 acres (45 activities)
# - **Riverside (RIV)** : 979 acres (27 activities)
# - **Imperial (IMP)** : 307 acres (3 activities)
# - **San Bernardino (SBD)** : 251 acres (14 activities)
# - **Kern (KER)** : 78 acres (3 activities)
#
# **Leading Organizations:**
# - **USFS (U.S. Forest Service)** : 3,499 acres (67 activities)
# - **SDRC (San Diego River Conservancy)** : 3,109 acres (5 activities)
# - **CALFIRE** : 1,446 acres (75 activities)
# - **FWS (U.S. Fish & Wildlife Service)** : 280 acres (1 activity)
# - **DOD (Department of Defense)** : 71 acres (4 activities)
# - **PARKS (CA State Parks)** : 63 acres (11 activities)
# - **BLM (Bureau of Land Management)** : 58 acres (1 activity)
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Prescribed Fire by Vegetation Type</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">Prescribed Fire Map</div><div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ff32f7f19591be1c87e3d9d35235b67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed;bottom:30px;left:10px;z-index:9999;background:white;padding:8px 12px;border-radius:6px;box-shadow:0 2px 8px rgba(0,0,0,0.3);font-family:sans-serif;min-width:150px;max-width:200px;max-height:320px;overflow-y:auto&quot;&gt;&lt;div style=&quot;font-weight:700;font-size:12px;margin-bottom:6px;padding-bottom:4px;border-bottom:2px solid #ddd;color:#222&quot;&gt;Legend&lt;/div&gt;&lt;div style=&quot;margin-bottom:8px&quot;&gt;&lt;div style=&quot;font-weight:600;font-size:11px;color:#333;margin-bottom:3px;padding-bottom:3px;border-bottom:1px solid #e8e8e8&quot;&gt;Vegetation Type&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#006837;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;FOREST&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#41ab5d;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;SHRB_CHAP&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#74c476;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;GRASS_HERB&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#f7fcf5;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;AGRICULTURE&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#d9d9d9;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;URBAN&lt;/span&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ff32f7f19591be1c87e3d9d35235b67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
# (function() {
#     // Scroll-away-and-back corruption:
#     //   JupyterLab&#x27;s cell virtualization scrolls the map offscreen and back
#     //   without changing its container&#x27;s dimensions. Leaflet&#x27;s internal tile
#     //   state gets corrupted (map reverts to a single top-left tile and zoom
#     //   controls stop responding) but invalidateSize() alone cannot recover
#     //   — a fitBounds() is required.
#     //   ResizeObserver doesn&#x27;t fire because the container size never changes,
#     //   so we use IntersectionObserver to detect viewport re-entry. Maps used
#     //   to render inside a Folium iframe, where IntersectionObserver fires
#     //   immediately regardless of parent scroll (v1.0.66 history); now the
#     //   map is rendered directly into the notebook DOM, so it works.
#     function _fit() {
#         if (typeof map_1ff32f7f19591be1c87e3d9d35235b67 === &#x27;undefined&#x27;) return;
#         try {
#             var _el = document.getElementById(&#x27;map_1ff32f7f19591be1c87e3d9d35235b67&#x27;);
#             if (!_el || _el.offsetWidth === 0 || _el.offsetHeight === 0) return;
#             map_1ff32f7f19591be1c87e3d9d35235b67.invalidateSize();
#             map_1ff32f7f19591be1c87e3d9d35235b67.fitBounds([[32.61482441801357,-118.82108753770227],[35.23632827386145,-115.57335834739011]],{maxZoom:10});
#         } catch (e) { /* ignore */ }
#     }
#     [50, 150, 400, 800, 1500, 3000, 6000, 10000, 15000].forEach(function(ms) {
#         setTimeout(_fit, ms);
#     });
#     if (typeof window !== &#x27;undefined&#x27; &amp;&amp; window.addEventListener) {
#         window.addEventListener(&#x27;load&#x27;, _fit);
#         window.addEventListener(&#x27;resize&#x27;, _fit);
#     }
#     var _el0 = document.getElementById(&#x27;map_1ff32f7f19591be1c87e3d9d35235b67&#x27;);
#     if (_el0 &amp;&amp; window.IntersectionObserver) {
#         // Re-fit every time the map scrolls back into the viewport. Trade-off:
#         // user&#x27;s pan/zoom is reset on scroll-away-and-back. Acceptable for
#         // narrative notebooks where the fit-to-data view is what the reader
#         // expects; recovery from the corruption is the priori

# %%
# %%ask
# How many acres of mechanical fuel reduction treatments were completed in Southern
# California counties in 2023? visualize the result as a pie chart only.
# Out:
# I'll help you find mechanical fuel reduction treatments in Southern California for 2023 and create a pie chart. Let me start by reading the vegetation treatments skill to understand how to query this data.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll query the vegetation treatments data for mechanical fuel reduction activities in Southern California counties during 2023 and create a pie chart.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/mechanical_treatments_2023.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/mechanical_treatments_2023.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"Query mechanical fuel reduction treatments in Southern California counties for 2023.\"\"\"\n\nimport geopandas as gpd\nimport pandas as pd\nimport requests\nimport matplotlib.pyplot as plt\nimport os\n\n# Set output directory\noutdir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_\"\nos.makedirs(outdir, exist_ok=True)\n\n# Service URL\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\n# Southern California counties\nsocal_counties = ['LA', 'SD', 'ORA', 'RIV', 'SBD', 'VEN', 'SLO', 'SB', 'KER', 'IMP']\n\ndef get_all_features(service_url, where, bbox=None):\n    \"\"\"Query the service and handle pagination for &gt;2000 results.\"\"\"\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n\n        all_features.extend(feats)\n\n        if len(feats) &lt; batch_size:\n            break\n\n        offset += batch_size\n\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n# County name mapping\ncounty_names = {\n    'LA': 'Los Angeles',\n    'SD': 'San Diego',\n    'ORA': 'Orange',\n    'RIV': 'Riverside',\n    'SBD': 'San Bernardino',\n    'VEN': 'Ventura',\n    'SLO': 'San Luis Obispo',\n    'SB': 'Santa Barbara',\n    'KER': 'Kern',\n    'IMP': 'Imperial'\n}\n\n# Build WHERE clause for Southern California counties\ncounties_str = \", \".join([f\"'{c}'\" for c in socal_counties])\nwhere = f\"activity_cat = 'MECH_HFR' AND year_txt = '2023' AND county IN ({counties_str})\"\n\nprint(f\"Querying: {where}\")\ndf = get_all_features(url, where)\n\nprint(f\"\\nFound {len(df)} mechanical fuel reduction activities in Southern California (2023)\")\n\n# Filter for acre measurements only\nacres_df = df[df['activity_uom'] == 'AC'].copy()\nprint(f\"Activities with acre measurements: {len(acres_df)}\")\n\n# Sum acres by county\ncounty_acres = acres_df.groupby('county')['activity_quantity'].sum().sort_values(ascending=False)\n\nprint(\"\\nAcres treated by county:\")\nfor county_code, acres in county_acres.items():\n    county_name = county_names.get(county_code, county_code)\n    print(f\"  {county_name}: {acres:,.0f} acres\")\n\ntotal_acres = county_acres.sum()\nprint(f\"\\nTotal acres treated: {total_acres:,.0f}\")\n\n# Create pie chart\nfig, ax = plt.subplots(figsize=(14, 8), dpi=150)\n\n# Prepare data for pie chart\nlabels = [county_names.get(code, code) for code in county_acres.index]\nsizes = county_acres.values\ncolors = plt.cm.Set3(range(len(labels)))\n\n# Create pie chart with percentage labels\nwedges, texts, autotexts = ax.pie(\n    sizes,\n    labels=labels,\n    autopct='%1.1f%%',\n    startangle=90,\n    colors=colors,\n    textprops={'fontsize': 11}\n)\n\n# Enhance percentage text\nfor autotext in autotexts:\n    autotext.set_color('white')\n    autotext.set_fontweight('bold')\n    autotext.set_fontsize(10)\n\nax.set_title(\n    'Mechanical Fuel Reduction Treatments in Southern California Counties (2023)\\n'\n    f'Total: {total_acr ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/mechanical_treatments_2023.py</pre>
#     </div>
#   </details>
# </div>
# ## Mechanical Fuel Reduction Treatments in Southern California (2023)
#
# I found **20,305 mechanical fuel reduction activities** completed in Southern California counties during 2023, treating a total of ** 111,310 acres**.
#
# ### Summary by County
#
# | County | Acres Treated | Percentage |
# |--------|---------------|------------|
# | Los Angeles | 28,166 | 25.3% |
# | Riverside | 16,335 | 14.7% |
# | San Diego | 16,234 | 14.6% |
# | San Bernardino | 14,363 | 12.9% |
# | Kern | 11,300 | 10.2% |
# | Orange | 7,561 | 6.8% |
# | San Luis Obispo | 5,135 | 4.6% |
# | Santa Barbara | 4,679 | 4.2% |
# | Ventura | 4,400 | 4.0% |
# | Imperial | 3,138 | 2.8% |
#
# ### Key Findings
#
# **Total Treatment Area** : 111,310 acres across 10 Southern California counties
#
# **Leading Counties** :
# - **Los Angeles County** led with 28,166 acres (25.3% of regional total)
# - **Riverside County** followed with 16,335 acres (14.7%)
# - **San Diego County** completed 16,234 acres (14.6%)
#
# **Regional Distribution** : The top three counties (Los Angeles, Riverside, and San Diego) accounted for **54.6%** of all mechanical fuel reduction treatments in the region.
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Mechanical Fuel Reduction by County</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>

# %%
# %%ask
# Compare CALFIRE treatment actvities in San Diego county in 2023 and 2024.
# Out:
# I'll compare CALFIRE treatment activities in San Diego county between 2023 and 2024. Let me start by reading the skill file to understand the API structure, then fetch and analyze the data.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a Python script to fetch and compare CALFIRE treatment activities in San Diego county for 2023 and 2024.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nCompare CALFIRE treatment activities in San Diego county between 2023 and 2024.\n\"\"\"\n\nimport geopandas as gpd\nimport pandas as pd\nimport requests\nimport matplotlib.pyplot as plt\nimport json\nimport os\n\n# Set output directory\noutdir = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_\"\nos.makedirs(outdir, exist_ok=True)\n\n# Service URL\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\n\ndef get_all_features(service_url, where, bbox=None):\n    \"\"\"\n    Query the service and handle pagination for &gt;2000 results.\n    \"\"\"\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n\n        all_features.extend(feats)\n\n        if len(feats) &lt; batch_size:\n            break\n\n        offset += batch_size\n\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n\n# Query CALFIRE activities in San Diego county for 2023 and 2024\nprint(\"Fetching CALFIRE activities in San Diego county for 2023...\")\nwhere_2023 = \"administering_org = 'CALFIRE' AND county = 'SD' AND year_txt = '2023'\"\ncalfire_sd_2023 = get_all_features(url, where_2023)\nprint(f\"Found {len(calfire_sd_2023)} activities in 2023\")\n\nprint(\"\\nFetching CALFIRE activities in San Diego county for 2024...\")\nwhere_2024 = \"administering_org = 'CALFIRE' AND county = 'SD' AND year_txt = '2024'\"\ncalfire_sd_2024 = get_all_features(url, where_2024)\nprint(f\"Found {len(calfire_sd_2024)} activities in 2024\")\n\n# Calculate total acres (only where unit is acres)\nacres_2023 = calfire_sd_2023[calfire_sd_2023['activity_uom'] == 'AC']['activity_quantity'].sum()\nacres_2024 = calfire_sd_2024[calfire_sd_2024['activity_uom'] == 'AC']['activity_quantity'].sum()\n\nprint(f\"\\n{'='*60}\")\nprint(\"CALFIRE TREATMENT ACTIVITIES IN SAN DIEGO COUNTY\")\nprint(f\"{'='*60}\")\nprint(f\"\\n{'Metric':&lt;30} {'2023':&gt;15} {'2024':&gt;15} {'Change':&gt;15}\")\nprint(f\"{'-'*60}\")\nprint(f\"{'Total Activities':&lt;30} {len(calfire_sd_2023):&gt;15,} {len(calfire_sd_2024):&gt;15,} {len(calfire_sd_2024) - len(calfire_sd_2023):&gt;+15,}\")\nprint(f\"{'Total Acres Treated':&lt;30} {acres_2023:&gt;15,.0f} {acres_2024:&gt;15,.0f} {acres_2024 - acres_2023:&gt;+15,.0f}\")\n\n# Activity category breakdown\nprint(f\"\\n{'='*60}\")\nprint(\"ACTIVITY CATEGORY BREAKDOWN\")\nprint(f\"{'='*60}\")\n\ncat_names = {\n    'MECH_HFR': 'Mechanical &amp; Hand Fuels Reduction',\n    'PRESCRB_FIRE': 'Prescribed Fire',\n    'GRAZING': 'Targeted Grazing',\n    'TIMB_HARV': 'Timber Harvest',\n    'TREE_PLNTING': 'Tree Planting',\n}\n\n# Get category breakdown for each year\ncat_2023 = calfire_sd_2023[calfire_sd_2023['activity_uom'] == 'AC'].groupby('activity_cat')['activity_quantity'].agg(['sum', 'count'])\ncat_2024 = calfire_sd_2024[calfire_sd_2024['activity_uom'] == 'AC'].groupby('activity_cat')['activity_quantity'].agg(['sum', 'count'])\n\n# Create comparison table\nall_cats = set(cat_2023.ind ...
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py",
#   "offset": 135,
#   "limit": 20
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py",
#   "limit": 30,
#   "offset": 100
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✂️ <b>edit_file</b> — Editing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py",
#   "old_string": "all_veg = set(veg_2023.index) | set(veg_2024.index)\nprint(f\"\\n{'Vegetation Type':&lt;30} {'2023 Acres':&gt;12} {'2024 Acres':&gt;12} {'Change':&gt;12} {'2023 Count':&gt;12} {'2024 Count':&gt;12}\")\nprint(f\"{'-'*90}\")",
#   "new_string": "all_veg = set(veg_2023.index) | set(veg_2024.index)\nprint(f\"\\n{'Vegetation Type':&lt;30} {'2023 Acres':&gt;12} {'2024 Acres':&gt;12} {'Change':&gt;12} {'2023 Count':&gt;12} {'2024 Count':&gt;12}\")\nprint('-' * 90)"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py",
#   "limit": 10,
#   "offset": 140
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✂️ <b>edit_file</b> — Editing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py",
#   "old_string": "print(f\"{'-'*90})",
#   "new_string": "print(f\"{'-'*90}\")"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/calfire_sd_comparison.py</pre>
#     </div>
#   </details>
# </div>
# ## CALFIRE Treatment Activities in San Diego County: 2023 vs 2024 Comparison
#
# I analyzed CALFIRE vegetation treatment activities in San Diego County for 2023 and 2024. Here are the key findings:
#
# ### Overall Summary
#
# | Metric | 2023 | 2024 | Change |
# |--------|------|------|--------|
# | **Total Activities** | 144 | 277 | +133 (+92.4%) |
# | **Total Acres Treated** | 3,462 | 2,657 | -805 (-23.3%) |
#
# **Key Insight** : CALFIRE significantly increased the number of treatment activities in 2024 (up 92.4%), but the total acreage treated decreased by 23.3%. This indicates a shift toward more targeted, smaller-scale treatments rather than large-area operations.
#
# ### Activity Category Breakdown
#
# | Category | 2023 Acres | 2024 Acres | Change | 2023 Count | 2024 Count |
# |----------|------------|------------|--------|------------|------------|
# | **Mechanical & Hand Fuels Reduction** | 1,918 | 1,791 | -127 (-6.6%) | 131 | 238 |
# | **Prescribed Fire** | 1,191 | 866 | -324 (-27.2%) | 10 | 39 |
# | **Tree Planting** | 353 | 0 | -353 (-100%) | 3 | 0 |
#
# ### Key Findings by Category
#
# **1. Mechanical & Hand Fuels Reduction**
# - Remained the dominant treatment type in both years
# - Activity count nearly doubled (131 → 238, +81.7%)
# - Acreage decreased modestly (-6.6%), indicating smaller, more targeted treatments
# - Average treatment size dropped from 14.6 acres to 7.5 acres per activity
#
# **2. Prescribed Fire**
# - Activity count increased nearly 4x (10 → 39, +290%)
# - Acreage decreased significantly (-27.2%)
# - Average treatment size dropped from 119 acres to 22 acres per activity
# - Suggests a shift toward smaller, more controlled burns
#
# **3. Tree Planting**
# - No tree planting activities recorded in 2024
# - All 353 acres of tree planting occurred in 2023 (3 activities)
# - May reflect completion of major planting projects or reallocation of resources
#
# ### Vegetation Type Breakdown
#
# | Vegetation Type | 2023 Acres | 2024 Acres | Change | 2023 Count | 2024 Count |
# |-----------------|------------|------------|--------|------------|------------|
# | **Shrublands/Chaparral** | 2,309 | 1,978 | -331 (-14.3%) | 120 | 262 |
# | **Forest** | 1,152 | 665 | -487 (-42.3%) | 24 | 11 |
# | **Grass/Herbaceous** | 0 | 14 | +14 | 0 | 4 |
#
# ### Key Findings by Vegetation Type
#
# **1. Shrublands/Chaparral**
# - Primary treatment target in both years (67% of 2023 acres, 74% of 2024 acres)
# - Activity count more than doubled (120 → 262, +118%)
# - Acreage decreased modestly (-14.3%)
# - Average treatment size dropped from 19.2 acres to 7.5 acres per activity
#
# **2. Forest**
# - Significant reduction in both acreage (-42.3%) and activity count (-54.2%)
# - May reflect completion of major forest fuel reduction projects
# - Average treatment size remained similar (48 acres in 2023 vs 60 acres in 2024)
#
# **3. Grass/Herbaceous**
# - New treatment category in 2024 (14 acres across 4 activities)
# - Indicates expansion of treatment scope to include grassy areas
#
# ### Activity Status Breakdown
#
# | Status | 2023 Count | 2024 Count | Change |
# |--------|------------|------------|--------|
# | **ACTIVE** | 66 | 163 | +97 (+147.0%) |
# | **COMPLETE** | 78 | 114 | +36 (+46.2%) |
#
# ### Strategic Insights
#
# **1. Shift to Smaller, More Targeted Treatments**
# - The dramatic increase in activity count (+92.4%) alongside decreased acreage (-23.3%) indicates a strategic shift toward more granular, targeted treatments
# - Average treatment size dropped from 24.0 acres to 9.6 acres per activity
# - This approach may improve precision and reduce environmental impacts
#
# **2. Focus on Shrublands/Chaparral**
# - Shrublands/Chaparral remains the primary treatment focus
# - Activity count more than doubled in this vegetation type
# - Consistent with CALFIRE's emphasis on reducing chaparral fuel loads in Southern California
#
# **3. Reduced Prescribed Fire Acreage**
# - Despite 4x more prescribed fire activities, total acreage decreased
# - Suggests smaller, more controlled burns for safety and precision
# - May reflect weather constraints or air quality regulations
#
# **4. Expansion of Active Projects**
# - Active projects increased by 147% (66 → 163)
# - Indicates significant planning and project initiation for future treatments
# - Suggests continued investment in vegetation management
#
# **5. Completion of Major Projects**
# - The absence of tree planting in 2024 and reduced forest treatments may indicate completion of major multi-year projects
# - Resources may have been reallocated to ongoing maintenance and new chaparral treatments
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>CALFIRE Comparison Chart</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# <div style="font-weight:bold; font-size:0.95em; margin:10px 0 4px 0;">CALFIRE Treatment Locations</div><div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d27f74c484b44c0d019afd42feaeeed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed;bottom:30px;left:10px;z-index:9999;background:white;padding:8px 12px;border-radius:6px;box-shadow:0 2px 8px rgba(0,0,0,0.3);font-family:sans-serif;min-width:150px;max-width:200px;max-height:320px;overflow-y:auto&quot;&gt;&lt;div style=&quot;font-weight:700;font-size:12px;margin-bottom:6px;padding-bottom:4px;border-bottom:2px solid #ddd;color:#222&quot;&gt;Legend&lt;/div&gt;&lt;div style=&quot;margin-bottom:8px&quot;&gt;&lt;div style=&quot;font-weight:600;font-size:11px;color:#333;margin-bottom:3px;padding-bottom:3px;border-bottom:1px solid #e8e8e8&quot;&gt;Year&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#6baed6;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;2023&lt;/span&gt;&lt;/div&gt;&lt;div style=&quot;display:flex;align-items:center;margin:2px 0&quot;&gt;&lt;div style=&quot;width:12px;height:12px;background:#fc9272;border-radius:50%;flex-shrink:0;margin-right:7px;border:1px solid rgba(0,0,0,0.2)&quot;&gt;&lt;/div&gt;&lt;span style=&quot;font-size:11px&quot;&gt;2024&lt;/span&gt;&lt;/div&gt;&lt;/div&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d27f74c484b44c0d019afd42feaeeed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
# (function() {
#     // Scroll-away-and-back corruption:
#     //   JupyterLab&#x27;s cell virtualization scrolls the map offscreen and back
#     //   without changing its container&#x27;s dimensions. Leaflet&#x27;s internal tile
#     //   state gets corrupted (map reverts to a single top-left tile and zoom
#     //   controls stop responding) but invalidateSize() alone cannot recover
#     //   — a fitBounds() is required.
#     //   ResizeObserver doesn&#x27;t fire because the container size never changes,
#     //   so we use IntersectionObserver to detect viewport re-entry. Maps used
#     //   to render inside a Folium iframe, where IntersectionObserver fires
#     //   immediately regardless of parent scroll (v1.0.66 history); now the
#     //   map is rendered directly into the notebook DOM, so it works.
#     function _fit() {
#         if (typeof map_8d27f74c484b44c0d019afd42feaeeed === &#x27;undefined&#x27;) return;
#         try {
#             var _el = document.getElementById(&#x27;map_8d27f74c484b44c0d019afd42feaeeed&#x27;);
#             if (!_el || _el.offsetWidth === 0 || _el.offsetHeight === 0) return;
#             map_8d27f74c484b44c0d019afd42feaeeed.invalidateSize();
#             map_8d27f74c484b44c0d019afd42feaeeed.fitBounds([[32.61482441801357,-117.35910649880019],[33.43234832850988,-116.26760502646913]],{maxZoom:10});
#         } catch (e) { /* ignore */ }
#     }
#     [50, 150, 400, 800, 1500, 3000, 6000, 10000, 15000].forEach(function(ms) {
#         setTimeout(_fit, ms);
#     });
#     if (typeof window !== &#x27;undefined&#x27; &amp;&amp; window.addEventListener) {
#         window.addEventListener(&#x27;load&#x27;, _fit);
#         window.addEventListener(&#x27;resize&#x27;, _fit);
#     }
#     var _el0 = document.getElementById(&#x27;map_8d27f74c484b44c0d019afd42feaeeed&#x27;);
#     if (_el0 &amp;&amp; window.IntersectionObserver) {
#         // Re-fit every time the map scrolls back into the viewport. Trade-off:
#         // user&#x27;s pan/zoom is reset on scroll-away-and-back. Acceptable for
#         // narrative notebooks where the fit-to-data view is what the reader
#         // expects; recovery from the corruption is the priority.
#         new IntersectionObserver(function(entries) {
#             entries.forEach(function(e) { if (e.isIntersecting) _fit(); });
#         }, { threshold: 0.01 }).observe(_el0);
#     }
#     if (_el0 &amp;&amp; window.ResizeObserver) {
#         new ResizeObserver(_fit).observe(_el0);
#     }
# })();
#
#             var map_8d27f74c484b44c0d019afd42feaeeed = L.map(
#                 &quot;map_8d27f74c484b44c0d019afd42feaeeed&quot;,
#                 {
#                     center: [33.02358637326172, -116.81335576263466],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af43831a6e809877e81a25b6cea22221 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &

# %%
# %%ask
# which top 3 counties have the maximum treatment acres in 2024?
# Please show the county full names and break down in ownership.
# Out:
# I'll analyze the 2024 treatment data to find the top 3 counties by acres and break them down by ownership.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"Find top 3 counties by treatment acres in 2024, broken down by ownership.\"\"\"\n\nimport requests\nimport pandas as pd\n\n# Query for 2024 treatments\nquery = \"\"\"\nSELECT\n    county,\n    ownership,\n    SUM(acres_treated) as total_acres,\n    COUNT(*) as activity_count\nFROM \"california-vegetation-treatments\".\"vegetation_treatments\"\nWHERE year = 2024\nGROUP BY county, ownership\nORDER BY county, total_acres DESC\n\"\"\"\n\nresponse = requests.post(\n    \"https://api.canopy.earth/vegetation-treatments/query\",\n    json={\"query\": query}\n)\n\nif response.status_code != 200:\n    print(f\"Error: {response.status_code}\")\n    print(response.text)\n    exit(1)\n\ndata = response.json()\n\n# Convert to DataFrame\ndf = pd.DataFrame(data)\n\n# County name mapping\ncounty_names = {\n    \"SD\": \"San Diego\",\n    \"LA\": \"Los Angeles\",\n    \"RIV\": \"Riverside\",\n    \"SBD\": \"San Bernardino\",\n    \"KER\": \"Kern\",\n    \"IMP\": \"Imperial\",\n    \"SB\": \"Santa Barbara\",\n    \"SLO\": \"San Luis Obispo\",\n    \"VENT\": \"Ventura\",\n    \"OR\": \"Orange\",\n    \"MNT\": \"Monterey\",\n    \"SCL\": \"Santa Clara\",\n    \"SF\": \"San Francisco\",\n    \"SM\": \"San Mateo\",\n    \"MRN\": \"Marin\",\n    \"SON\": \"Sonoma\",\n    \"NAP\": \"Napa\",\n    \"SOL\": \"Solano\",\n    \"YOL\": \"Yolo\",\n    \"SAC\": \"Sacramento\",\n    \"PLA\": \"Placer\",\n    \"ED\": \"El Dorado\",\n    \"AMA\": \"Amador\",\n    \"TUO\": \"Tuolumne\",\n    \"CAL\": \"Calaveras\",\n    \"MAD\": \"Madera\",\n    \"FRE\": \"Fresno\",\n    \"KIN\": \"Kings\",\n    \"TUL\": \"Tulare\",\n    \"SBY\": \"San Benito\",\n    \"MON\": \"Mono\",\n    \"INY\": \"Inyo\",\n    \"ALP\": \"Alpine\",\n    \"COL\": \"Colusa\",\n    \"GLE\": \"Glenn\",\n    \"HUM\": \"Humboldt\",\n    \"DEL\": \"Del Norte\",\n    \"TRI\": \"Trinity\",\n    \"SIS\": \"Siskiyou\",\n    \"MOD\": \"Modoc\",\n    \"LAS\": \"Lassen\",\n    \"PLU\": \"Plumas\",\n    \"SHA\": \"Shasta\",\n    \"TEH\": \"Tehama\",\n    \"BUT\": \"Butte\",\n    \"MEN\": \"Mendocino\",\n    \"LAKE\": \"Lake\",\n    \"NOR\": \"Napa\",\n    \"SJR\": \"San Joaquin\",\n    \"STA\": \"Stanislaus\",\n    \"MER\": \"Merced\",\n    \"MAR\": \"Mariposa\",\n    \"LAK\": \"Lake\"\n}\n\n# Map county codes to full names\ndf['county_full'] = df['county'].map(county_names)\n\n# Calculate total acres per county\ncounty_totals = df.groupby('county_full').agg({\n    'total_acres': 'sum',\n    'activity_count': 'sum'\n}).reset_index()\ncounty_totals = county_totals.sort_values('total_acres', ascending=False)\n\nprint(\"Top 3 Counties by Treatment Acres in 2024\")\nprint(\"=\" * 60)\nprint()\n\nfor i, row in county_totals.head(3).iterrows():\n    county = row['county_full']\n    total_acres = row['total_acres']\n    total_activities = row['activity_count']\n\n    print(f\"#{i+1} {county}\")\n    print(f\"   Total Acres: {total_acres:,.0f}\")\n    print(f\"   Total Activities: {total_activities:,}\")\n    print()\n\n    # Get ownership breakdown for this county\n    county_data = df[df['county_full'] == county].sort_values('total_acres', ascending=False)\n\n    print(\"   Ownership Breakdown:\")\n    for _, owner_row in county_data.iterrows():\n        ownership = owner_row['ownership']\n        acres = owner_row['total_acres']\n        count = owner_row['activity_count']\n        pct = (acres / total_acres) * 100\n        print(f\"      {ownership:20s} {acres:8,.0f} acres ({pct:5.1f}%) - {count:3d} activities\")\n\n    print()\n    print(\"-\" * 60)\n    print()\n\n# Save to CSV\noutput_file = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.csv\"\ncounty_totals.head(3).to_csv(output_file, index=False)\nprint(f\"Data saved to: {output_file}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✂️ <b>edit_file</b> — Editing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py",
#   "old_string": "response = requests.post(\n    \"https://api.canopy.earth/vegetation-treatments/query\",\n    json={\"query\": query}\n)\n\nif response.status_code != 200:\n    print(f\"Error: {response.status_code}\")\n    print(response.text)\n    exit(1)\n\ndata = response.json()",
#   "new_string": "response = requests.post(\n    \"https://api.canopy.earth/vegetation-treatments/query\",\n    json={\"query\": query}\n)\n\nif response.status_code != 200:\n    print(f\"Error: {response.status_code}\")\n    print(response.text)\n    exit(1)\n\n# Check if response is valid JSON\ntry:\n    data = response.json()\nexcept Exception as e:\n    print(f\"Error parsing JSON: {e}\")\n    print(f\"Response text: {response.text[:500]}\")\n    exit(1)"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ca-vegetation-treatments/SKILL.md",
#   "limit": 1000
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"Find top 3 counties by treatment acres in 2024, broken down by ownership.\"\"\"\n\nimport geopandas as gpd\nimport pandas as pd\nimport requests\n\n# ArcGIS Feature Service URL\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\ndef get_all_features(service_url, where, bbox=None):\n    \"\"\"\n    Query the service and handle pagination for &gt;2000 results.\n    \"\"\"\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n\n        all_features.extend(feats)\n\n        if len(feats) &lt; batch_size:\n            break\n\n        offset += batch_size\n\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n# Query for 2024 treatments with acre units\nwhere = \"year_txt = '2024' AND activity_uom = 'AC'\"\ndf = get_all_features(url, where)\n\nprint(f\"Total 2024 treatment activities with acre units: {len(df)}\")\n\n# County name mapping\ncounty_names = {\n    \"SD\": \"San Diego\",\n    \"LA\": \"Los Angeles\",\n    \"RIV\": \"Riverside\",\n    \"SBD\": \"San Bernardino\",\n    \"KER\": \"Kern\",\n    \"IMP\": \"Imperial\",\n    \"SB\": \"Santa Barbara\",\n    \"SLO\": \"San Luis Obispo\",\n    \"VEN\": \"Ventura\",\n    \"ORA\": \"Orange\",\n    \"MNT\": \"Monterey\",\n    \"SCL\": \"Santa Clara\",\n    \"SF\": \"San Francisco\",\n    \"SM\": \"San Mateo\",\n    \"MRN\": \"Marin\",\n    \"SON\": \"Sonoma\",\n    \"NAP\": \"Napa\",\n    \"SOL\": \"Solano\",\n    \"YOL\": \"Yolo\",\n    \"SAC\": \"Sacramento\",\n    \"PLA\": \"Placer\",\n    \"ED\": \"El Dorado\",\n    \"AMA\": \"Amador\",\n    \"TUO\": \"Tuolumne\",\n    \"CAL\": \"Calaveras\",\n    \"MAD\": \"Madera\",\n    \"FRE\": \"Fresno\",\n    \"KIN\": \"Kings\",\n    \"TUL\": \"Tulare\",\n    \"SBT\": \"San Benito\",\n    \"MNO\": \"Mono\",\n    \"INY\": \"Inyo\",\n    \"ALP\": \"Alpine\",\n    \"COL\": \"Colusa\",\n    \"GLE\": \"Glenn\",\n    \"HUM\": \"Humboldt\",\n    \"DN\": \"Del Norte\",\n    \"TRI\": \"Trinity\",\n    \"SIS\": \"Siskiyou\",\n    \"MOD\": \"Modoc\",\n    \"LAS\": \"Lassen\",\n    \"PLU\": \"Plumas\",\n    \"SHA\": \"Shasta\",\n    \"TEH\": \"Tehama\",\n    \"BUT\": \"Butte\",\n    \"MEN\": \"Mendocino\",\n    \"LAK\": \"Lake\",\n    \"SJ\": \"San Joaquin\",\n    \"STA\": \"Stanislaus\",\n    \"MER\": \"Merced\",\n    \"MPA\": \"Mariposa\",\n    \"SCR\": \"Santa Cruz\",\n    \"ALA\": \"Alameda\",\n    \"CC\": \"Contra Costa\",\n    \"NEV\": \"Nevada\",\n    \"SIE\": \"Sierra\",\n    \"SUT\": \"Sutter\",\n    \"YUB\": \"Yuba\"\n}\n\n# Map county codes to full names\ndf['county_full'] = df['county'].map(county_names)\n\n# Calculate total acres per county\ncounty_totals = df.groupby('county_full').agg({\n    'activity_quantity': 'sum',\n    'objectid': 'count'\n}).reset_index()\ncounty_totals.columns = ['county_full', 'total_acres', 'activity_count']\ncounty_totals = county_totals.sort_values('total_acres', ascending=False)\n\nprint(\"\\nTop 3 Counties by Treatment Acres in 2024\")\nprint(\"=\" *  ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✂️ <b>edit_file</b> — Editing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py",
#   "old_string": "#!/usr/bin/env python3\n\"\"\"Find top 3 counties by treatment acres in 2024, broken down by ownership.\"\"\"\n\nimport requests\nimport pandas as pd\n\n# Query for 2024 treatments\nquery = \"\"\"\nSELECT\n    county,\n    ownership,\n    SUM(acres_treated) as total_acres,\n    COUNT(*) as activity_count\nFROM \"california-vegetation-treatments\".\"vegetation_treatments\"\nWHERE year = 2024\nGROUP BY county, ownership\nORDER BY county, total_acres DESC\n\"\"\"\n\nresponse = requests.post(\n    \"https://api.canopy.earth/vegetation-treatments/query\",\n    json={\"query\": query}\n)\n\nif response.status_code != 200:\n    print(f\"Error: {response.status_code}\")\n    print(response.text)\n    exit(1)\n\n# Check if response is valid JSON\ntry:\n    data = response.json()\nexcept Exception as e:\n    print(f\"Error parsing JSON: {e}\")\n    print(f\"Response text: {response.text[:500]}\")\n    exit(1)\n\n# Convert to DataFrame\ndf = pd.DataFrame(data)",
#   "new_string": "#!/usr/bin/env python3\n\"\"\"Find top 3 counties by treatment acres in 2024, broken down by ownership.\"\"\"\n\nimport geopandas as gpd\nimport pandas as pd\nimport requests\n\n# ArcGIS Feature Service URL\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\ndef get_all_features(service_url, where, bbox=None):\n    \"\"\"\n    Query the service and handle pagination for &gt;2000 results.\n    \"\"\"\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n\n        all_features.extend(feats)\n\n        if len(feats) &lt; batch_size:\n            break\n\n        offset += batch_size\n\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n# Query for 2024 treatments with acre units\nwhere = \"year_txt = '2024' AND activity_uom = 'AC'\"\ndf = get_all_features(url, where)\n\nprint(f\"Total 2024 treatment activities with acre units: {len(df)}\")"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✂️ <b>edit_file</b> — Editing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py",
#   "old_string": "# County name mapping\ncounty_names = {\n    \"SD\": \"San Diego\",\n    \"LA\": \"Los Angeles\",\n    \"RIV\": \"Riverside\",\n    \"SBD\": \"San Bernardino\",\n    \"KER\": \"Kern\",\n    \"IMP\": \"Imperial\",\n    \"SB\": \"Santa Barbara\",\n    \"SLO\": \"San Luis Obispo\",\n    \"VENT\": \"Ventura\",\n    \"OR\": \"Orange\",\n    \"MNT\": \"Monterey\",\n    \"SCL\": \"Santa Clara\",\n    \"SF\": \"San Francisco\",\n    \"SM\": \"San Mateo\",\n    \"MRN\": \"Marin\",\n    \"SON\": \"Sonoma\",\n    \"NAP\": \"Napa\",\n    \"SOL\": \"Solano\",\n    \"YOL\": \"Yolo\",\n    \"SAC\": \"Sacramento\",\n    \"PLA\": \"Placer\",\n    \"ED\": \"El Dorado\",\n    \"AMA\": \"Amador\",\n    \"TUO\": \"Tuolumne\",\n    \"CAL\": \"Calaveras\",\n    \"MAD\": \"Madera\",\n    \"FRE\": \"Fresno\",\n    \"KIN\": \"Kings\",\n    \"TUL\": \"Tulare\",\n    \"SBY\": \"San Benito\",\n    \"MON\": \"Mono\",\n    \"INY\": \"Inyo\",\n    \"ALP\": \"Alpine\",\n    \"COL\": \"Colusa\",\n    \"GLE\": \"Glenn\",\n    \"HUM\": \"Humboldt\",\n    \"DEL\": \"Del Norte\",\n    \"TRI\": \"Trinity\",\n    \"SIS\": \"Siskiyou\",\n    \"MOD\": \"Modoc\",\n    \"LAS\": \"Lassen\",\n    \"PLU\": \"Plumas\",\n    \"SHA\": \"Shasta\",\n    \"TEH\": \"Tehama\",\n    \"BUT\": \"Butte\",\n    \"MEN\": \"Mendocino\",\n    \"LAKE\": \"Lake\",\n    \"NOR\": \"Napa\",\n    \"SJR\": \"San Joaquin\",\n    \"STA\": \"Stanislaus\",\n    \"MER\": \"Merced\",\n    \"MAR\": \"Mariposa\",\n    \"LAK\": \"Lake\"\n}\n\n# Map county codes to full names\ndf['county_full'] = df['county'].map(county_names)\n\n# Calculate total acres per county\ncounty_totals = df.groupby('county_full').agg({\n    'total_acres': 'sum',\n    'activity_count': 'sum'\n}).reset_index()\ncounty_totals = county_totals.sort_values('total_acres', ascending=False)",
#   "new_string": "# County name mapping\ncounty_names = {\n    \"SD\": \"San Diego\",\n    \"LA\": \"Los Angeles\",\n    \"RIV\": \"Riverside\",\n    \"SBD\": \"San Bernardino\",\n    \"KER\": \"Kern\",\n    \"IMP\": \"Imperial\",\n    \"SB\": \"Santa Barbara\",\n    \"SLO\": \"San Luis Obispo\",\n    \"VEN\": \"Ventura\",\n    \"ORA\": \"Orange\",\n    \"MNT\": \"Monterey\",\n    \"SCL\": \"Santa Clara\",\n    \"SF\": \"San Francisco\",\n    \"SM\": \"San Mateo\",\n    \"MRN\": \"Marin\",\n    \"SON\": \"Sonoma\",\n    \"NAP\": \"Napa\",\n    \"SOL\": \"Solano\",\n    \"YOL\": \"Yolo\",\n    \"SAC\": \"Sacramento\",\n    \"PLA\": \"Placer\",\n    \"ED\": \"El Dorado\",\n    \"AMA\": \"Amador\",\n    \"TUO\": \"Tuolumne\",\n    \"CAL\": \"Calaveras\",\n    \"MAD\": \"Madera\",\n    \"FRE\": \"Fresno\",\n    \"KIN\": \"Kings\",\n    \"TUL\": \"Tulare\",\n    \"SBT\": \"San Benito\",\n    \"MNO\": \"Mono\",\n    \"INY\": \"Inyo\",\n    \"ALP\": \"Alpine\",\n    \"COL\": \"Colusa\",\n    \"GLE\": \"Glenn\",\n    \"HUM\": \"Humboldt\",\n    \"DN\": \"Del Norte\",\n    \"TRI\": \"Trinity\",\n    \"SIS\": \"Siskiyou\",\n    \"MOD\": \"Modoc\",\n    \"LAS\": \"Lassen\",\n    \"PLU\": \"Plumas\",\n    \"SHA\": \"Shasta\",\n    \"TEH\": \"Tehama\",\n    \"BUT\": \"Butte\",\n    \"MEN\": \"Mendocino\",\n    \"LAK\": \"Lake\",\n    \"SJ\": \"San Joaquin\",\n    \"STA\": \"Stanislaus\",\n    \"MER\": \"Merced\",\n    \"MPA\": \"Mariposa\",\n    \"SCR\": \"Santa Cruz\",\n    \"ALA\": \"Alameda\",\n    \"CC\": \"Contra Costa\",\n    \"NEV\": \"Nevada\",\n    \"SIE\": \"Sierra\",\n    \"SUT\": \"Sutter\",\n    \"YUB\": \"Yuba\"\n}\n\n# Map county codes to full names\ndf['county_full'] = df['county'].map(county_names)\n\n# Calculate total acres per county\ncounty_totals = df.groupby('county_full').agg({\n    'activity_quantity': 'sum',\n    'objectid': 'count'\n}).reset_index()\ncounty_totals.columns = ['county_full', 'total_acres', 'activity_count']\ncounty_totals = county_totals.sort_values('total_acres', ascending=False)"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✂️ <b>edit_file</b> — Editing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py",
#   "old_string": "    # Get ownership breakdown for this county\n    county_data = df[df['county_full'] == county].sort_values('total_acres', ascending=False)\n\n    print(\"   Ownership Breakdown:\")\n    for _, owner_row in county_data.iterrows():\n        ownership = owner_row['ownership']\n        acres = owner_row['total_acres']\n        count = owner_row['activity_count']\n        pct = (acres / total_acres) * 100\n        print(f\"      {ownership:20s} {acres:8,.0f} acres ({pct:5.1f}%) - {count:3d} activities\")",
#   "new_string": "    # Get ownership breakdown for this county\n    county_data = df[df['county_full'] == county].copy()\n    ownership_breakdown = county_data.groupby('primary_ownership_group').agg({\n        'activity_quantity': 'sum',\n        'objectid': 'count'\n    }).reset_index()\n    ownership_breakdown.columns = ['ownership', 'acres', 'count']\n    ownership_breakdown = ownership_breakdown.sort_values('acres', ascending=False)\n\n    print(\"   Ownership Breakdown:\")\n    for _, owner_row in ownership_breakdown.iterrows():\n        ownership = owner_row['ownership']\n        acres = owner_row['acres']\n        count = owner_row['count']\n        pct = (acres / total_acres) * 100\n        print(f\"      {ownership:25s} {acres:10,.0f} acres ({pct:5.1f}%) - {count:4d} activities\")"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.py</pre>
#     </div>
#   </details>
# </div>
# Now let me create a visualization to better display this data:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/visualize_top_counties.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/visualize_top_counties.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"Visualize top 3 counties by treatment acres in 2024 with ownership breakdown.\"\"\"\n\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport numpy as np\n\n# Read the data\ndf = pd.read_csv(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/top_counties_2024.csv\")\n\n# Get the top 3 counties\ntop_counties = df.head(3)['county_full'].tolist()\n\n# Query the full dataset to get ownership breakdown for each county\nimport geopandas as gpd\nimport requests\n\nurl = \"https://sparcal.sdsc.edu/arcgis/rest/services/Hosted/ITS_V2_0_Activity_webmap_gdb/FeatureServer/0\"\n\ndef get_all_features(service_url, where, bbox=None):\n    if bbox is None:\n        bbox = [-124.5, 32.5, -114.0, 42.1]\n\n    minx, miny, maxx, maxy = bbox\n    all_features = []\n    offset = 0\n    batch_size = 2000\n\n    while True:\n        params = {\n            \"where\": where,\n            \"geometry\": f\"{minx},{miny},{maxx},{maxy}\",\n            \"geometryType\": \"esriGeometryEnvelope\",\n            \"spatialRel\": \"esriSpatialRelIntersects\",\n            \"inSR\": \"4326\",\n            \"outFields\": \"*\",\n            \"returnGeometry\": \"true\",\n            \"f\": \"geojson\",\n            \"outSR\": \"4326\",\n            \"resultOffset\": offset,\n            \"resultRecordCount\": batch_size,\n        }\n\n        response = requests.get(service_url + \"/query\", params=params)\n        data = response.json()\n\n        feats = data.get(\"features\") or []\n        if not feats:\n            break\n\n        all_features.extend(feats)\n\n        if len(feats) &lt; batch_size:\n            break\n\n        offset += batch_size\n\n    if all_features:\n        return gpd.GeoDataFrame.from_features(all_features, crs=\"EPSG:4326\")\n    else:\n        return gpd.GeoDataFrame(columns=[\"geometry\"], crs=\"EPSG:4326\")\n\n# Query for 2024 treatments with acre units\nwhere = \"year_txt = '2024' AND activity_uom = 'AC'\"\ndf_full = get_all_features(url, where)\n\n# County name mapping\ncounty_names = {\n    \"SD\": \"San Diego\",\n    \"LA\": \"Los Angeles\",\n    \"RIV\": \"Riverside\",\n    \"SBD\": \"San Bernardino\",\n    \"KER\": \"Kern\",\n    \"IMP\": \"Imperial\",\n    \"SB\": \"Santa Barbara\",\n    \"SLO\": \"San Luis Obispo\",\n    \"VEN\": \"Ventura\",\n    \"ORA\": \"Orange\",\n    \"MNT\": \"Monterey\",\n    \"SCL\": \"Santa Clara\",\n    \"SF\": \"San Francisco\",\n    \"SM\": \"San Mateo\",\n    \"MRN\": \"Marin\",\n    \"SON\": \"Sonoma\",\n    \"NAP\": \"Napa\",\n    \"SOL\": \"Solano\",\n    \"YOL\": \"Yolo\",\n    \"SAC\": \"Sacramento\",\n    \"PLA\": \"Placer\",\n    \"ED\": \"El Dorado\",\n    \"AMA\": \"Amador\",\n    \"TUO\": \"Tuolumne\",\n    \"CAL\": \"Calaveras\",\n    \"MAD\": \"Madera\",\n    \"FRE\": \"Fresno\",\n    \"KIN\": \"Kings\",\n    \"TUL\": \"Tulare\",\n    \"SBT\": \"San Benito\",\n    \"MNO\": \"Mono\",\n    \"INY\": \"Inyo\",\n    \"ALP\": \"Alpine\",\n    \"COL\": \"Colusa\",\n    \"GLE\": \"Glenn\",\n    \"HUM\": \"Humboldt\",\n    \"DN\": \"Del Norte\",\n    \"TRI\": \"Trinity\",\n    \"SIS\": \"Siskiyou\",\n    \"MOD\": \"Modoc\",\n    \"LAS\": \"Lassen\",\n    \"PLU\": \"Plumas\",\n    \"SHA\": \"Shasta\",\n    \"TEH\": \"Tehama\",\n    \"BUT\": \"Butte\",\n    \"MEN\": \"Mendocino\",\n    \"LAK\": \"Lake\",\n    \"SJ\": \"San Joaquin\",\n    \"STA\": \"Stanislaus\",\n    \"MER\": \"Merced\",\n    \"MPA\": \"Mariposa\",\n    \"SCR\": \"Santa Cruz\",\n    \"ALA\": \"Alameda\",\n    \"CC\": \"Contra Costa\",\n    \"NEV\": \"Nevada\",\n    \"SIE\": \"Sierra\",\n    \"SUT\": \"Sutter\",\n    \"YUB\": \"Yuba\"\n}\n\ndf_full['county_full'] = df_full['county'].map(county_names)\n\n# Prepare data for stacked bar chart\nownership_data = []\nfor county in top_counties:\n    county_data = df_full[df_full['county_full'] == county]\n    ownership_breakdown = county_data.groupby('primary_ownership_group')['activity_quanti ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_vegetation_activities_sage_/visualize_top_counties.py</pre>
#     </div>
#   </details>
# </div>
# ## Top 3 Counties by Treatment Acres in 2024
#
# I analyzed 45,600 vegetation treatment activities across California in 2024 to identify the top counties by acres treated. Here are the results:
#
# ### Top 3 Counties Overview
#
# | Rank | County | Total Acres | Total Activities |
# |------|--------|-------------|------------------|
# | **#1** | **Siskiyou** | 92,785 | 1,589 |
# | **#2** | **Del Norte** | 62,338 | 1,044 |
# | **#3** | **Tehama** | 51,773 | 353 |
#
# ### Detailed Breakdown by County
#
# ---
#
# ### **#1 Siskiyou County**
# **Total Acres** : 92,785 | **Total Activities** : 1,589
#
# **Ownership Breakdown** :
# | Ownership | Acres | Percentage | Activities |
# |-----------|-------|------------|------------|
# | **FEDERAL** | 59,103 | 63.7% | 1,257 |
# | **PRIVATE_INDUSTRY** | 20,091 | 21.7% | 96 |
# | **PRIVATE_NON-INDUSTRY** | 9,903 | 10.7% | 127 |
# | **STATE** | 3,680 | 4.0% | 104 |
# | **LOCAL** | 3 | 0.0% | 3 |
# | **NGO** | 2 | 0.0% | 1 |
# | **TRIBAL** | 2 | 0.0% | 1 |
#
# **Key Insights** : Siskiyou County leads with the highest treatment acreage, dominated by federal land (63.7%), primarily managed by the U.S. Forest Service. The county also has significant private industry timber operations (21.7%).
#
# ---
#
# ### **#2 Del Norte County**
# **Total Acres** : 62,338 | **Total Activities** : 1,044
#
# **Ownership Breakdown** :
# | Ownership | Acres | Percentage | Activities |
# |-----------|-------|------------|------------|
# | **FEDERAL** | 60,951 | 97.8% | 224 |
# | **STATE** | 1,354 | 2.2% | 791 |
# | **PRIVATE_NON-INDUSTRY** | 24 | 0.0% | 23 |
# | **PRIVATE_INDUSTRY** | 8 | 0.0% | 6 |
#
# **Key Insights** : Del Norte County has the highest concentration of federal land treatments (97.8%), reflecting the presence of Redwood National and State Parks and extensive U.S. Forest Service lands. Despite fewer federal activities (224), they cover vast acreage.
#
# ---
#
# ### **#3 Tehama County**
# **Total Acres** : 51,773 | **Total Activities** : 353
#
# **Ownership Breakdown** :
# | Ownership | Acres | Percentage | Activities |
# |-----------|-------|------------|------------|
# | **STATE** | 45,948 | 88.7% | 179 |
# | **PRIVATE_NON-INDUSTRY** | 3,519 | 6.8% | 88 |
# | **PRIVATE_INDUSTRY** | 1,206 | 2.3% | 65 |
# | **FEDERAL** | 1,100 | 2.1% | 21 |
#
# **Key Insights** : Tehama County is unique among the top 3, with state land ownership dominating (88.7%). This reflects significant CAL FIRE and California Department of Forestry and Fire Protection treatment activities in the region.
#
# ### Regional Patterns
#
# **North Coast Dominance** : All three top counties are located in Northern California, specifically in the North Coast and Cascade regions. This pattern reflects:
#
# 1. **High Forest Coverage** : These counties contain extensive forested lands requiring active vegetation management
# 2. **Federal Land Presence** : Significant U.S. Forest Service and National Park lands
# 3. **Timber Industry** : Active private timber operations requiring fuel reduction and forest health treatments
# 4. **Fire Risk** : High wildfire risk areas prioritized for vegetation treatments
#
# **Ownership Distribution** :
# - **Federal lands** dominate in Siskiyou (63.7%) and Del Norte (97.8%)
# - **State lands** dominate in Tehama (88.7%)
# - **Private lands** (both industrial and non-industrial) contribute significantly, especially in Siskiyou (32.4% combined)
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Top 3 Counties by Treatment Acres in 2024</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
