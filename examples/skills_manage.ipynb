# %% [markdown]
#  # Skill Manager
#
#   This notebook demonstrates how **Sage** can extend its own capabilities on the fly using the [SkillsMP marketplace](https://skillsmp.com) — a repository of 600,000+ AI
#   agent skills.
#
#   ## What you can do here
#
#   - **Search** the marketplace for skills by topic or keyword
#   - **Browse** skill details and documentation
#   - **Install** a skill with a single natural language request
#   - **Use** a newly installed skill immediately — no kernel restart needed
#
#   ## Workflow
#
#   1. Run `%reset` to clear previous outputs (optional)
#   2. Use `%%ask` to search, install, and invoke skills
#   3. Installed skills are saved to `~/.deepagents/agent/skills/` and persist across sessions

# %%
# %reset
# Out:
# **Sage reset.**
# - Output folder cleared: `/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_` (4 items removed)
# - Conversation history cleared

# %%
# %%ask
# Search SkillsMP marketplace for an expert-level emergency management skill covering disaster
# preparedness, response coordination, and hazard mitigation. Show me the results as a table.
# Out:
# I'll search the SkillsMP marketplace for emergency management skills. Let me first check the NDP-search skill to understand how to perform this search.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ndp-search/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ndp-search/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll search the SkillsMP marketplace for emergency management skills using the AI semantic search feature.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_skills.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_skills.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"Search SkillsMP marketplace for emergency management skills\"\"\"\n\nimport os\nimport requests\nimport json\nfrom pathlib import Path\nfrom dotenv import load_dotenv\n\n# Load API key from environment variables\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\n\nif not API_KEY:\n    print(\"Error: SKILLSMP_API_KEY not found\")\n    exit(1)\n\n# Search SkillsMP for emergency management skills\nsearch_query = \"emergency management disaster preparedness response coordination hazard mitigation\"\nurl = f\"https://skillsmp.com/api/v1/skills/ai-search\"\n\nheaders = {\n    \"Authorization\": f\"Bearer {API_KEY}\",\n    \"Content-Type\": \"application/json\"\n}\n\nparams = {\"q\": search_query}\n\ntry:\n    response = requests.get(url, headers=headers, params=params)\n    response.raise_for_status()\n    data = response.json()\n\n    # Save results\n    output_file = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/emergency_skills_search_results.json\"\n    with open(output_file, \"w\") as f:\n        json.dump(data, f, indent=2)\n\n    print(f\"Search complete. Found {len(data.get('data', {}).get('data', []))} skills\")\n    print(f\"Results saved to: {output_file}\")\n\nexcept Exception as e:\n    print(f\"Error: {e}\")\n    exit(1)\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_skills.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/emergency_skills_search_results.json</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/emergency_skills_search_results.json"
# }</pre>
#     </div>
#   </details>
# </div>
# Perfect! I found 3 relevant emergency management skills in the SkillsMP marketplace. Here are the results:
#
# | Rank | Name | Author | Score | Stars | Description |
# |------|------|--------|-------|-------|-------------|
# | 1 | risk-mitigation-planning | a5c-ai | 87% | 505 | Develop comprehensive risk management plans for collections and cultural venues including disaster preparedness... |
# | 2 | managing-emergency-preparedness | CaseMark | 85% | 8 | Structures public health emergency preparedness with hazard vulnerability and response planning. Use when... |
# | 3 | emergency-manager | theneoai | 76% | 21 | Expert emergency manager specializing in disaster preparedness, response coordination, hazard mitigation, and crisis... |
#
# The **emergency-manager** skill by theneoai appears to be the best match for your requirements — it specifically covers disaster preparedness, response coordination, and hazard mitigation, along with crisis communication and multi-agency response coordination.

# %%
# %%ask
# Could you please show me the details of the skill emergency-manager?
# Out:
# I'll check the SkillsMP skill instructions to understand how to retrieve detailed information about the emergency-manager skill.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md",
#   "offset": 100
# }</pre>
#     </div>
#   </details>
# </div>
# I'll check if the emergency-manager skill is already installed locally, and if not, I'll fetch its details from the marketplace.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/check_emergency_manager.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/check_emergency_manager.py",
#   "content": "from pathlib import Path\n\n# Check if emergency-manager is already installed\nskill_name = \"emergency-manager\"\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\n\nif (skill_dir / \"SKILL.md\").exists():\n    print(f\"Skill '{skill_name}' is already installed at {skill_dir}\")\n    print(\"\\n--- SKILL.md Content ---\")\n    print((skill_dir / \"SKILL.md\").read_text())\nelse:\n    print(f\"Skill '{skill_name}' is NOT installed locally. Will fetch from marketplace.\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/check_emergency_manager.py</pre>
#     </div>
#   </details>
# </div>
# Now I'll search the marketplace for the emergency-manager skill to get its GitHub URL and details.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_manager.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_manager.py",
#   "content": "import requests\nimport os\nfrom pathlib import Path\nfrom dotenv import load_dotenv\n\n# Load API key\nfor env_path in [Path.cwd() / \".env\", Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\")]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"SKILLSMP_API_KEY not found\")\n    exit(1)\n\n# Search for the skill by exact name\nskill_name = \"emergency-manager\"\nurl = f\"https://skillsmp.com/api/v1/skills/search?q={skill_name}\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\n\nprint(f\"Searching for skill: {skill_name}\")\nresp = requests.get(url, headers=headers, timeout=15)\ndata = resp.json()\n\nif data.get(\"success\"):\n    skills = data.get(\"data\", {}).get(\"skills\", [])\n    print(f\"\\nFound {len(skills)} result(s):\\n\")\n\n    for i, skill in enumerate(skills, 1):\n        print(f\"--- Result {i} ---\")\n        print(f\"Name: {skill.get('name')}\")\n        print(f\"Author: {skill.get('author')}\")\n        print(f\"Description: {skill.get('description', '')[:150]}...\")\n        print(f\"GitHub URL: {skill.get('githubUrl')}\")\n        print(f\"Stars: {skill.get('stars')}\")\n        print()\nelse:\n    print(f\"API request failed: {data}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_manager.py</pre>
#     </div>
#   </details>
# </div>
# Now I'll fetch the SKILL.md content from GitHub to show you the full details of the emergency-manager skill.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_details.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_details.py",
#   "content": "import requests\n\ngithub_url = \"https://github.com/theneoai/awesome-skills/tree/main/skills/government/emergency-manager\"\n\n# Convert to raw GitHub URL\nraw_url = github_url.replace(\"https://github.com/\", \"https://raw.githubusercontent.com/\")\nraw_url = raw_url.replace(\"/tree/main/\", \"/main/\")\nraw_url = raw_url + \"/SKILL.md\"\n\nprint(f\"Fetching SKILL.md from:\")\nprint(raw_url)\nprint()\n\nresp = requests.get(raw_url, timeout=15)\n\nif resp.status_code == 200:\n    print(resp.text)\nelse:\n    print(f\"Failed to fetch: HTTP {resp.status_code}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_details.py</pre>
#     </div>
#   </details>
# </div>
# Here are the full details for the **emergency-manager** skill:
#
# ---
#
# ## **emergency-manager** Skill Details
#
# **Name** : emergency-manager
# **Version** : 1.0.0
# **Author** : theNeoAI <lucas_hsueh@hotmail.com>
# **License** : MIT
# **Stars** : 21
# **GitHub** : [theneoai/awesome-skills](https://github.com/theneoai/awesome-skills/tree/main/skills/government/emergency-manager)
#
# **Tags** :
# - Domain: government
# - Subtype: emergency-manager
# - Level: expert
#
# ---
#
# ### **Description**
# Expert emergency manager specializing in disaster preparedness, response coordination, hazard mitigation, and crisis communication. Use when developing emergency plans, coordinating multi-agency response, managing evacuation operations, or leading disaster recovery efforts. Covers all hazards including natural disasters, technological emergencies, and security incidents.
#
# ---
#
# ### **Identity & Core Expertise**
#
# **Role** : Certified Emergency Manager (CEM) with 20+ years of experience in disaster preparedness, response, and recovery.
#
# **Background** :
# - Former emergency management director for major metropolitan area
# - Incident Commander for multiple Type 1 and Type 2 incidents
# - Master Exercise Practitioner (MEP) and exercise designer
# - Hazard mitigation specialist (flood, earthquake, hurricane)
# - Crisis communication and public information expert
#
# **Core Expertise Areas** :
# - **Preparedness** : Planning, training, exercises, public education
# - **Response** : ICS/NIMS, EOC operations, resource coordination
# - **Mitigation** : Risk assessment, project design, grant management
# - **Recovery** : Long-term recovery, disaster assistance, community resilience
# - **Communication** : Crisis communication, public information, warning systems
#
# ---
#
# ### **Emergency Management Priority Hierarchy**
#
# 1. **LIFE SAFETY** (Immediate) — Protect human life above all else
# 2. **INCIDENT STABILIZATION** (Hours to days) — Control situation, prevent escalation
# 3. **PROPERTY AND ENVIRONMENTAL PROTECTION** (Days) — Minimize damage
# 4. **RESTORATION OF SERVICES** (Days to weeks) — Return to normal functioning
# 5. **RECOVERY AND MITIGATION** (Weeks to years) — Rebuild stronger, reduce future risk
#
# ---
#
# ### **Scope**
#
# **✓ In Scope** :
# - Emergency operations planning
# - Incident command and coordination
# - Crisis communication and public warning
# - Resource management and mutual aid
# - Evacuation planning and sheltering
# - Hazard mitigation planning
# - Long-term recovery coordination
# - Exercise design and evaluation
#
# **✗ Out of Scope** :
# - Tactical firefighting (use fire-chief)
# - Law enforcement tactics (use police-chief)
# - Medical treatment protocols (use medical-director)
# - Engineering assessments (use structural-engineer)
#
# ---
#
# ### **References & Standards**
#
# **National Standards** :
# - FEMA: National Incident Management System (NIMS)
# - FEMA: National Response Framework
# - FEMA: Comprehensive Preparedness Guide 101
# - IAEM: Emergency Management Principles
#
# **Professional Certification** :
# - IAEM: Certified Emergency Manager (CEM)
# - EMI: Master Exercise Practitioner
#
# ---
#
# This is a comprehensive, expert-level skill for emergency management operations with a self-assessed quality score of **9.5/10** . It's well-suited for developing emergency plans, coordinating multi-agency responses, and managing the full disaster cycle from preparedness through recovery.

# %%
# %%ask
# Could you please install this skill for me?
# Out:
# I'll install the emergency-manager skill for you. Let me first check the skills directory structure, then download and install the skill from GitHub.
#
# **Intent** : Check the current skills directory structure to understand where and how to install the new skill.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills"
# }</pre>
#     </div>
#   </details>
# </div>
# **Intent** : Create the emergency-manager skill directory and download the skill files from GitHub.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>mkdir -p /home/jovyan/.deepagents/agent/skills/emergency-manager && curl -L "...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>mkdir -p /home/jovyan/.deepagents/agent/skills/emergency-manager &amp;&amp; curl -L "https://raw.githubusercontent.com/theneoai/awesome-skills/main/skills/government/emergency-manager/SKILL.md" -o /home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</pre>
#     </div>
#   </details>
# </div>
# **Intent** : Verify the SKILL.md file was downloaded correctly by reading it.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# **Intent** : Check if there are additional files in the emergency-manager skill directory on GitHub that need to be downloaded.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>curl -s "https://api.github.com/repos/theneoai/awesome-skills/contents/skills...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>curl -s "https://api.github.com/repos/theneoai/awesome-skills/contents/skills/government/emergency-manager" | grep -E '"name":|"download_url":' | head -20</pre>
#     </div>
#   </details>
# </div>
# **Intent** : Download the EVALUATION_REPORT.md file.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>curl -L "https://raw.githubusercontent.com/theneoai/awesome-skills/main/skill...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>curl -L "https://raw.githubusercontent.com/theneoai/awesome-skills/main/skills/government/emergency-manager/EVALUATION_REPORT.md" -o /home/jovyan/.deepagents/agent/skills/emergency-manager/EVALUATION_REPORT.md</pre>
#     </div>
#   </details>
# </div>
# **Intent** : Check for files in the references subdirectory.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>curl -s "https://api.github.com/repos/theneoai/awesome-skills/contents/skills...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>curl -s "https://api.github.com/repos/theneoai/awesome-skills/contents/skills/government/emergency-manager/references" | grep -E '"name":|"download_url":'</pre>
#     </div>
#   </details>
# </div>
# **Intent** : Create the references subdirectory and download all reference files.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>mkdir -p /home/jovyan/.deepagents/agent/skills/emergency-manager/references &...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>mkdir -p /home/jovyan/.deepagents/agent/skills/emergency-manager/references &amp;&amp; cd /home/jovyan/.deepagents/agent/skills/emergency-manager/references &amp;&amp; for file in "2-what-this-skill-does.md" "3-risk-disclaimer.md" "4-core-philosophy.md" "5-professional-toolkit.md" "6-domain-knowledge.md" "7-workflow.md" "8-scenario-examples.md" "9-common-pitfalls-anti-patterns.md"; do curl -L "https://raw.githubusercontent.com/theneoai/awesome-skills/main/skills/government/emergency-manager/references/$file" -o "$file"; done</pre>
#     </div>
#   </details>
# </div>
# **Intent** : Verify the complete skill installation by listing the directory structure.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"
# }</pre>
#     </div>
#   </details>
# </div>
# **Intent** : List the reference files to confirm all were downloaded.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/references"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/references"
# }</pre>
#     </div>
#   </details>
# </div>
# The **emergency-manager** skill has been successfully installed. Here's what was downloaded:
#
# ---
#
# ## Installation Summary
#
# **Installation Location** : `/home/jovyan/.deepagents/agent/skills/emergency-manager/`
#
# **Files Installed** :
# | File | Description |
# |------|-------------|
# | `SKILL.md` | Main skill definition with identity, workflows, and guidelines |
# | `EVALUATION_REPORT.md` | Skill quality assessment and evaluation results |
# | `references/2-what-this-skill-does.md` | Skill scope and use cases |
# | `references/3-risk-disclaimer.md` | Risk management considerations |
# | `references/4-core-philosophy.md` | Emergency management principles and values |
# | `references/5-professional-toolkit.md` | Tools, frameworks, and best practices |
# | `references/6-domain-knowledge.md` | Domain-specific knowledge and standards |
# | `references/7-workflow.md` | Standard workflows and procedures |
# | `references/8-scenario-examples.md` | Example scenarios and applications |
# | `references/9-common-pitfalls-anti-patterns.md` | Common mistakes to avoid |
#
# ---
#
# **Skill Metadata** :
# - **Name** : emergency-manager
# - **Version** : 1.0.0
# - **Author** : theNeoAI <lucas_hsueh@hotmail.com>
# - **License** : MIT
# - **Level** : Expert
# - **Domain** : Government
#
# The skill is now available and ready to use for emergency management tasks including disaster preparedness, response coordination, hazard mitigation, and crisis communication.

# %%
# %%ask
# We have a major hurricane approaching in Florida next week.
# How do we coordinate the response? Please show a timeline plan.
# Out:
# I'll help you develop a comprehensive hurricane response coordination timeline. Let me first consult the emergency-manager skill that was just installed to ensure I follow proper emergency management practices.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/references/7-workflow.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/references/7-workflow.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/references/4-core-philosophy.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/references/4-core-philosophy.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/references/8-scenario-examples.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/references/8-scenario-examples.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/references/5-professional-toolkit.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/references/5-professional-toolkit.md"
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a comprehensive hurricane response coordination timeline based on emergency management best practices. Let me save this as a detailed plan document.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_timeline.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_timeline.md",
#   "content": "# Florida Hurricane Response Coordination Timeline\n\n**Classification**: Category 3-4 Hurricane | **Lead Time**: 5-7 Days | **Location**: Florida Coast\n\n---\n\n## Executive Summary\n\nThis timeline establishes a coordinated response framework for a major hurricane approaching Florida. It follows the National Incident Management System (NIMS) and Incident Command System (ICS) principles, with priorities in the emergency management hierarchy: **LIFE SAFETY → INCIDENT STABILIZATION → PROPERTY PROTECTION → SERVICE RESTORATION → RECOVERY**.\n\n**Response Triggers**:\n- Hurricane Watch issued (48 hours): Partial EOC activation\n- Hurricane Warning issued (36 hours): Full EOC activation\n- Storm surge warning: Mandatory evacuations\n\n---\n\n## Part I: Pre-Landfall Timeline (5 Days to Impact)\n\n### H-120 Hours (5 Days): Initial Preparation Phase\n\n**Actions**:\n| Time | Action | Lead Agency |\n|------|--------|-------------|\n| H-120 | Activate Emergency Operations Center (EOC) at Level 3 (Monitoring) | State Emergency Operations Center |\n| H-120 | Issue initial executive order of emergency | Governor |\n| H-120 | Begin coordination conference calls with county EOCs | State EM Division |\n| H-120 | Review and update Emergency Operations Plan | All Agencies |\n| H-120 | Initiate resource requests through EMAC if needed | State Logistics |\n\n**Deliverables**:\n- Initial Weather Briefing Report\n- State of Emergency Declaration\n- Resource Assessment Inventory\n\n---\n\n### H-96 Hours (4 Days): Mobilization Phase\n\n**Actions**:\n| Time | Action | Lead Agency |\n|------|--------|-------------|\n| H-96 | Brief Governor and cabinet on projected impacts | State EM Director |\n| H-96 | Activate State Emergency Response Team (SERT) | State EM Division |\n| H-96 | Begin fuel reserves verification (power, generators, vehicles) | State Logistics |\n| H-96 | Coordinate with utility companies for storm preparation | Public Service Commission |\n| H-96 | Initiate voluntary evacuation discussions | County Emergency Managers |\n| H-96 | Request FEMA pre-disaster emergency declaration | Governor |\n\n**Deliverables**:\n- SERT Activation Order\n- Utility Coordination Plan\n- FEMA Emergency Declaration Request\n\n---\n\n### H-72 Hours (3 Days): Readiness Phase\n\n**Actions**:\n| Time | Action | Lead Agency |\n|------|--------|-------------|\n| H-72 | Upgrade EOC to Level 2 (Partial Activation) | State EM Director |\n| H-72 | Issue voluntary evacuation orders for high-risk zones | County EM Directors |\n| H-72 | Open registration for shelter availability | Department of Children &amp; Families |\n| H-72 | Activate traffic control plan for evacuation routes | FDOT |\n| H-72 | Position critical supplies in strategic locations | State Logistics |\n| H-72 | Notify hospitals and nursing homes of potential evacuation | Department of Health |\n| H-72 | Coordinate animal sheltering plans | Department of Agriculture |\n| H-72 | Begin counter-flow lane reversals (if applicable) | FHP |\n\n**Deliverables**:\n- Voluntary Evacuation Orders\n- Shelter Activation Matrix\n- Evacuation Traffic Management Plan\n\n---\n\n### H-48 Hours (2 Days): Hurricane Watch Phase\n\n**Actions**:\n| Time | Action | Lead Agency |\n|------|--------|-------------|\n| H-48 | Activate EOC at Level 1 (Full Activation) | State EM Director |\n| H-48 | Issue mandatory evacuation for Zones A and B (surge zones) | County Officials |\n| H-48 | Activate National Guard (500-1,000 troops) | Adjutant General |\n| H-48 | Open general population shelters | DCF/Red Cross |\n| H-48 | Begin contraflow operations on major highways | FHP/FDOT |\n| H-48 | Suspend toll operations on evacuation routes | Turnpike Authority |\n| H-48 | Close public schools and state offices | Governor/Cabinet |\n| H-48 | Activate Urban Search and Rescue teams | State Fire Marshal |\n| H-48 | Pre-position high-water rescue vehicles | Local Fire Departments |\n| H-48 | Coordinate with federal agencies (FEMA, US ...
# Now let me create a visual timeline to make this plan easier to reference during emergency operations.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python << 'PYTHON_EOF'
# import matplotlib.pyplot as plt
# import ...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python &lt;&lt; 'PYTHON_EOF'
# import matplotlib.pyplot as plt
# import matplotlib.patches as mpatches
# from matplotlib.patches import FancyBboxPatch, FancyArrowPatch
# import numpy as np
#
# # Set up the figure
# fig, ax = plt.subplots(figsize=(18, 12), dpi=150)
#
# # Define phases and their time ranges
# phases = [
#     {
#         'name': 'INITIAL PREPARATION\n(H-120 to H-96)',
#         'hours_start': -120,
#         'hours_end': -96,
#         'color': '#2E86AB',
#         'actions': [
#             'EOC Level 3 Activation',
#             'Emergency Declaration',
#             'Weather Briefing',
#             'Resource Assessment'
#         ]
#     },
#     {
#         'name': 'MOBILIZATION\n(H-96 to H-72)',
#         'hours_start': -96,
#         'hours_end': -72,
#         'color': '#A23B72',
#         'actions': [
#             'SERT Activation',
#             'Fuel Reserves Verification',
#             'Utility Coordination',
#             'Voluntary Evacuation Planning'
#         ]
#     },
#     {
#         'name': 'READINESS\n(H-72 to H-48)',
#         'hours_start': -72,
#         'hours_end': -48,
#         'color': '#F18F01',
#         'actions': [
#             'EOC Level 2 Activation',
#             'Voluntary Evacuations',
#             'Shelter Registration',
#             'Evacuation Routes Active'
#         ]
#     },
#     {
#         'name': 'HURRICANE WATCH\n(H-48 to H-24)',
#         'hours_start': -48,
#         'hours_end': -24,
#         'color': '#C73E1D',
#         'actions': [
#             'EOC Level 1 (FULL)',
#             'Mandatory Evacuation Zones A&amp;B',
#             'National Guard Activation',
#             'Contraflow Operations',
#             'All Shelters Open'
#         ]
#     },
#     {
#         'name': 'FINAL PREPARATION\n(H-24 to H-12)',
#         'hours_start': -24,
#         'hours_end': -12,
#         'color': '#D90368',
#         'actions': [
#             'Expand Evacuations',
#             'Last-Resort Shelters',
#             'Transport Suspended',
#             'Ports Closed',
#             'Curfew Orders'
#         ]
#     },
#     {
#         'name': 'SHELTER IN PLACE\n(H-12 to H-0)',
#         'hours_start': -12,
#         'hours_end': 0,
#         'color': '#81171B',
#         'actions': [
#             'Evacuation Routes Closed',
#             'First Responders Secured',
#             'EOC Secure Position',
#             'Final Weather Briefing'
#         ]
#     },
#     {
#         'name': 'IMPACT\n(H-0 to H+12)',
#         'hours_start': 0,
#         'hours_end': 12,
#         'color': '#000000',
#         'actions': [
#             'Landfall',
#             'Weather Reconnaissance',
#             'Initial Damage Assessment',
#             'No Response During Peak Winds'
#         ]
#     },
#     {
#         'name': 'IMMEDIATE RESPONSE\n(H+12 to H+48)',
#         'hours_start': 12,
#         'hours_end': 48,
#         'color': '#06D6A0',
#         'actions': [
#             'Search &amp; Rescue',
#             'Medical Evacuation',
#             'Road Reopening',
#             'Water/Fuel Distribution'
#         ]
#     },
#     {
#         'name': 'SUSTAINED RESPONSE\n(H+48 to H+72)',
#         'hours_start': 48,
#         'hours_end': 72,
#         'color': '#118AB2',
#         'actions': [
#             'Power Restoration',
#             'Infrastructure Assessment',
#             'Damage Assessment Complete',
#             'FEMA PDA Begins'
#         ]
#     }
# ]
#
# # Create the timeline
# total_hours = 192
# ax.set_xlim(-125, 75)
# ax.set_ylim(0, 10)
# ax.set_xlabel('Hours Relative to Landfall', fontsize=14, fontweight='bold')
# ax.set_title('Florida Hurricane Response Coordination Timeline\n(Category 3-4 Hurricane)', fontsize=16, fontweight='bold', pad=20)
#
# # Draw landfall line
# ax.axvline(x=0, color='red', linestyle='--', linewidth=2, alpha=0.7)
# ax.text(1, 9.5, 'LANDFALL', fontsize=12, fontweight='bold', color='red', rotation=90, verticalalignment='center')
#
# # Draw zero axis
# ax.axhline(y=0.5, color='black', linewidth=1)
#
# # Plot each phase as a box
# y_positions = np.linspace(8, 2, len(phases))
# phase_heights = 0.6
#
# for idx, phase in enumerate(phases):
#     y = y_positions[idx]
#     x_start = phase['hours_start']
#     x_end = phase['hours_end']
#     duration = x_end - x_start
#
#     # Draw phase box
#     box = FancyBboxPatch(
#         (x_start, y - phase_heights/2),
#         duration, phase_heights,
#         boxstyle='round,pad=0.1',
#         facecolor=phase['color'],
#         alpha=0.8,
#         edgecolor='black',
#         linewidth=1
#     )
#     ax.add_patch(box)
#
#     # Phase label inside box
#     label_y = y if duration &gt; 20 else y + 0.5
#     ax.text(
#         x_start + duration/2, label_y,
#         phase['name'],
#         fontsize=10, fontweight='bold',
#         color='white' if phase['color'] in ['#000000', '#81171B', '#C73E1D', '#A23B72'] else 'black',
#         ha='center', va='center'
#     )
#
#     # Action labels
#     action_y = y - 1.2
#     for action in phase['actions']:
#         ax.text(
#             x_start + duration/2, action_y,
#             action,
#             fontsize=8,
#             color='black',
#             ha='center', va='center',
#             style='italic'
#         )
#         action_y -= 0.35
#
# # Add critical time markers
# critical_times = [
#     (-120, 'H-120\nInitial Prep', 'blue'),
#     (-72, 'H-72\nVoluntary\nEvacuation', 'orange'),
#     (-48, 'H-48\nMandatory\nEvacuation', 'red'),
#     (-24, 'H-24\nAll Systems\nPrepare', 'darkred'),
#     (-12, 'H-12\nShelter in\nPlace', 'darkred'),
#     (12, 'H+12\nResponse\nBegins', 'green'),
#     (48, 'H+48\nRecovery\nTransition', 'blue')
# ]
#
# for time_val, label, color in critical_times:
#     ax.axvline(x=time_val, color=color, linestyle=':', linewidth=1, alpha=0.5)
#     ax.text(time_val, 9.8, label, fontsize=9, ha='center', va='bottom', color=color, fontweight='bold')
#
# # Add legend
# legend_elements = [
#     mpatches.Patch(color='#2E86AB', label='Preparation Phases'),
#     mpatches.Patch(color='#C73E1D', label='Evacuation Phases'),
#     mpatches.Patch(color='#81171B', label='Shelter Phases'),
#     mpatches.Patch(color='#000000', label='Impact Phase'),
#     mpatches.Patch(color='#06D6A0', label='Response Phases')
# ]
# ax.legend(handles=legend_elements, loc='upper left', fontsize=10, framealpha=0.9)
#
# # Add grid
# ax.grid(True, axis='x', alpha=0.3, linestyle='--')
#
# # Format axes
# ax.set_yticks([])
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# ax.spines['left'].set_visible(False)
#
# plt.tight_layout()
# plt.savefig('/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_timeline_chart.png',
#             dpi=150, bbox_inches='tight', facecolor='white')
# print("Timeline chart saved successfully")
# PYTHON_EOF
# </pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python << 'PYTHON_EOF'
# import matplotlib.pyplot as plt
# import ...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python &lt;&lt; 'PYTHON_EOF'
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Set up the figure
# fig, ax = plt.subplots(figsize=(18, 10), dpi=150)
#
# # Define resource mobilization timeline
# resources = {
#     'EOC Staff': {
#         'H-120': 10,
#         'H-72': 25,
#         'H-48': 100,
#         'H-24': 150,
#         'H-0': 200,
#         'H+24': 200,
#         'H+72': 150
#     },
#     'National Guard': {
#         'H-120': 0,
#         'H-72': 0,
#         'H-48': 500,
#         'H-24': 1000,
#         'H-0': 2000,
#         'H+24': 2500,
#         'H+72': 1500
#     },
#     'Search &amp; Rescue Teams': {
#         'H-120': 0,
#         'H-72': 5,
#         'H-48': 15,
#         'H-24': 20,
#         'H-0': 20,
#         'H+24': 35,
#         'H+72': 25
#     },
#     'Shelter Capacity (per 1000)': {
#         'H-120': 0,
#         'H-72': 50,
#         'H-48': 150,
#         'H-24': 300,
#         'H-0': 350,
#         'H+24': 300,
#         'H+72': 150
#     },
#     'Utility Crews (hundreds)': {
#         'H-120': 5,
#         'H-72': 10,
#         'H-48': 20,
#         'H-24': 20,
#         'H-0': 20,
#         'H+24': 30,
#         'H+72': 25
#     },
#     'Medical Teams': {
#         'H-120': 5,
#         'H-72': 15,
#         'H-48': 30,
#         'H-24': 50,
#         'H-0': 80,
#         'H+24': 100,
#         'H+72': 60
#     }
# }
#
# # Time points
# time_points = [-120, -72, -48, -24, 0, 24, 72]
# time_labels = ['H-120', 'H-72', 'H-48', 'H-24', 'Landfall', 'H+24', 'H+72']
#
# # Plot each resource type
# colors = ['#2E86AB', '#A23B72', '#F18F01', '#C73E1D', '#06D6A0', '#118AB2']
# markers = ['o', 's', '^', 'D', 'v', 'p']
#
# for idx, (resource_name, values) in enumerate(resources.items()):
#     y_values = list(values.values())
#     ax.plot(time_points, y_values, marker=markers[idx], markersize=8,
#             linewidth=2, color=colors[idx], label=resource_name)
#
# # Add landfall line
# ax.axvline(x=0, color='red', linestyle='--', linewidth=2, alpha=0.7)
# ax.text(2, max([max(v.values()) for v in resources.values()]) * 0.95,
#         'LANDFALL', fontsize=12, fontweight='bold', color='red', rotation=90, verticalalignment='top')
#
# # Format x-axis
# ax.set_xticks(time_points)
# ax.set_xticklabels(time_labels, fontsize=11)
# ax.set_xlabel('Timeline (Hours Relative to Landfall)', fontsize=14, fontweight='bold')
# ax.set_ylabel('Number of Personnel / Units', fontsize=14, fontweight='bold')
# ax.set_title('Resource Mobilization Timeline for Florida Hurricane Response',
#              fontsize=16, fontweight='bold', pad=20)
#
# # Add grid
# ax.grid(True, alpha=0.3, linestyle='--')
# ax.set_axisbelow(True)
#
# # Add legend
# ax.legend(loc='upper left', fontsize=11, framealpha=0.9, ncol=2)
#
# # Add phase labels at the top
# ax.text(-96, max([max(v.values()) for v in resources.values()]) * 1.05,
#         'PREPARATION', ha='center', fontsize=11, fontweight='bold', color='#2E86AB')
# ax.text(-12, max([max(v.values()) for v in resources.values()]) * 1.05,
#         'SHELTER', ha='center', fontsize=11, fontweight='bold', color='#81171B')
# ax.text(12, max([max(v.values()) for v in resources.values()]) * 1.05,
#         'IMPACT', ha='center', fontsize=11, fontweight='bold', color='#000000')
# ax.text(48, max([max(v.values()) for v in resources.values()]) * 1.05,
#         'RESPONSE', ha='center', fontsize=11, fontweight='bold', color='#06D6A0')
#
# # Add phase background colors
# ax.axvspan(-120, -72, alpha=0.1, color='#2E86AB', label='Preparation')
# ax.axvspan(-72, -48, alpha=0.1, color='#F18F01', label='Readiness')
# ax.axvspan(-48, 0, alpha=0.1, color='#C73E1D', label='Evacuation')
# ax.axvspan(0, 72, alpha=0.1, color='#06D6A0', label='Response')
#
# plt.tight_layout()
# plt.savefig('/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/resource_mobilization_chart.png',
#             dpi=150, bbox_inches='tight', facecolor='white')
# print("Resource mobilization chart saved successfully")
# PYTHON_EOF
# </pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_quick_reference.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_quick_reference.md",
#   "content": "# Hurricane Response Quick Reference Guide\n\n## Immediate Action Checklist\n\n### By Time-to-Landfall\n\n| Timeframe | Status | Critical Actions | Who |\n|-----------|--------|------------------|-----|\n| **H-120** | 🟢 MONITORING | Activate EOC Level 3 • Issue state of emergency • Begin weather briefings | State EM Director |\n| **H-72** | 🟡 PREPARATION | Upgrade to EOC Level 2 • Voluntary evacuations Zone A • Open shelter registration | County EM Directors |\n| **H-48** | 🟠 WATCH (FULL ACTIVATION) | **EOC Level 1 • Mandatory evacuation Zones A&amp;B • National Guard (500-1,000) • All shelters open • Contraflow operations** | Governor • All Agencies |\n| **H-24** | 🔴 FINAL PREP | Expand to Zone C if needed • Last-resort shelters • Suspend all transport • Close ports • Issue curfew | All Agencies |\n| **H-12** | ⚫ SHELTER IN PLACE | Close evacuation routes • First responders secure • EOC secure • Final briefing | Public Safety |\n| **H-0** | ⚡ IMPACT | Landfall • Initial damage assessment when safe | All Agencies |\n| **H+12** | 🟢 RESPONSE | Deploy Search &amp; Rescue • Reopen routes • Medical evacuation • Begin water/food distribution | All Agencies |\n\n---\n\n## Decision Matrix\n\n### When to Evacuate\n\n| Trigger | Action | Lead Authority |\n|---------|--------|---------------|\n| Hurricane Watch | Begin voluntary evacuations | County EM Director |\n| Cat 3+ + surge zones | Mandatory evacuation Zones A&amp;B | County Judge/Mayor |\n| 36 hours to landfall | Mandatory evacuation if not already done | Governor |\n| Worsening track | Expand evacuation to Zone C | County Judge |\n\n### When to Activate EOC Levels\n\n| Level | Condition | Staffing | Primary Function |\n|-------|-----------|----------|------------------|\n| Level 3 | Monitoring | 10-15 staff | Information gathering, coordination |\n| Level 2 | Partial activation | 25-50 staff | Planning, resource pre-positioning |\n| Level 1 | Full activation | 100-200 staff | 24/7 operations, direct response |\n\n---\n\n## Resource Status by Phase\n\n### Pre-Positioning Timeline (What to Have When)\n\n| Resource | H-120 | H-72 | H-48 | H-24 | H-0 | H+24 |\n|----------|-------|------|------|------|-----|------|\n| EOC Staff | 10 | 25 | 100 | 150 | 200 | 200 |\n| National Guard | 0 | 0 | 500 | 1,000 | 2,000 | 2,500 |\n| Search &amp; Rescue Teams | 0 | 5 | 15 | 20 | 20 | 35 |\n| Shelter Capacity (thousands) | 0 | 50 | 150 | 300 | 350 | 300 |\n| Utility Crews (hundreds) | 5 | 10 | 20 | 20 | 20 | 30 |\n| Medical Teams | 5 | 15 | 30 | 50 | 80 | 100 |\n\n---\n\n## Priority Actions by Response Phase\n\n### Phase 1: LIFE SAFETY (H+0 to H+48)\n\n**Do First**:\n1. ☐ Deploy Search &amp; Rescue to affected areas\n2. ☐ Medical evacuation for critical patients\n3. ☐ Open access roads as conditions permit\n4. ☐ Begin emergency water/food distribution\n\n**Secondary**:\n- Restore 911 and emergency communications\n- Assess critical infrastructure damage\n- Protect vulnerable populations\n\n### Phase 2: INCIDENT STABILIZATION (H+12 to H+72)\n\n**Do First**:\n1. ☐ Restore power to hospitals, shelters, water treatment\n2. ☐ Clear debris from major roads\n3. ☐ Open Points of Distribution (PODs)\n4. ☐ Conduct preliminary damage assessment\n\n**Secondary**:\n- Begin debris removal operations\n- Restore utilities to residential areas\n- Implement curfew enforcement if needed\n\n### Phase 3: RECOVERY (H+48+)\n\n**Do First**:\n1. ☐ FEMA Preliminary Damage Assessment\n2. ☐ Open Disaster Recovery Centers\n3. ☐ Begin disaster assistance registration\n4. ☐ Issue re-entry permits\n\n---\n\n## Communication Quick Reference\n\n### Public Message Frequency\n\n| Phase | How Often | Key Messages |\n|-------|-----------|--------------|\n| Pre-impact (H-48 to H-0) | Every 2 hours | Storm track, evacuation zones, shelter locations |\n| Impact (H-0 to H+12) | Every hour (if possible) | Weather updates, safety instructions |\n| Response (H+12 to H+48) | Every 4 hours | Rescue operations, road conditions, P ...
# }</pre>
#     </div>
#   </details>
# </div>
# # Florida Hurricane Response Coordination Plan
#
# Based on emergency management best practices from the installed emergency-manager skill, I've developed a comprehensive hurricane response coordination timeline and framework for your use.
#
# ---
#
# ## Executive Summary
#
# This plan provides a structured timeline for coordinating a major hurricane response in Florida, following the National Incident Management System (NIMS) and Incident Command System (ICS) principles. The response prioritizes **LIFE SAFETY** above all else, followed by incident stabilization, property protection, service restoration, and recovery.
#
# **Response Philosophy** : Clear, actionable guidance with specific tasks, responsibilities, and timelines to eliminate ambiguity during critical moments.
#
# ---
#
# ## Response Timeline Overview
# <p><em>[Interactive map — open notebook in JupyterHub to view]</em></p>
# The timeline above shows the complete hurricane response coordination from 120 hours before landfall through 72 hours after impact, with color-coded phases and key actions for each stage.
#
# ---
#
# ## Pre-Landfall Coordination Timeline
#
# ### H-120 Hours (5 Days): Initial Preparation
#
# **Status** : Monitoring (EOC Level 3 Activation)
#
# **Critical Actions** :
# | Action | Lead Agency | Priority |
# |--------|-------------|----------|
# | Activate EOC at Level 3 (Monitoring) | State Emergency Management Division | HIGH |
# | Issue executive order of emergency | Governor | HIGH |
# | Begin coordination conference calls with county EOCs | State EM Division | MEDIUM |
# | Review and update Emergency Operations Plan | All Agencies | MEDIUM |
# | Initiate resource requests through EMAC | State Logistics | MEDIUM |
#
# **Deliverables** :
# - Initial Weather Briefing Report
# - State of Emergency Declaration
# - Resource Assessment Inventory
#
# ---
#
# ### H-96 Hours (4 Days): Mobilization
#
# **Status** : Preparation Phase
#
# **Critical Actions** :
# | Action | Lead Agency | Priority |
# |--------|-------------|----------|
# | Brief Governor and cabinet on projected impacts | State EM Director | HIGH |
# | Activate State Emergency Response Team (SERT) | State EM Division | HIGH |
# | Verify fuel reserves (power, generators, vehicles) | State Logistics | HIGH |
# | Coordinate with utility companies for storm preparation | Public Service Commission | HIGH |
# | Begin voluntary evacuation discussions | County Emergency Managers | MEDIUM |
# | Request FEMA pre-disaster emergency declaration | Governor | HIGH |
#
# **Deliverables** :
# - SERT Activation Order
# - Utility Coordination Plan
# - FEMA Emergency Declaration Request
#
# ---
#
# ### H-72 Hours (3 Days): Readiness
#
# **Status** : Partial Activation (EOC Level 2)
#
# **Critical Actions** :
# | Action | Lead Agency | Priority |
# |--------|-------------|----------|
# | Upgrade EOC to Level 2 (Partial Activation) | State EM Director | HIGH |
# | Issue voluntary evacuation orders for Zone A | County EM Directors | HIGH |
# | Open registration for shelter availability | Department of Children & Families | HIGH |
# | Activate traffic control plan for evacuation routes | FDOT | HIGH |
# | Position critical supplies in strategic locations | State Logistics | HIGH |
# | Notify hospitals and nursing homes of potential evacuation | Department of Health | HIGH |
#
# **Deliverables** :
# - Voluntary Evacuation Orders
# - Shelter Activation Matrix
# - Evacuation Traffic Management Plan
#
# ---
#
# ### H-48 Hours (2 Days): Hurricane Watch — FULL ACTIVATION
#
# **Status** : Full EOC Activation (Level 1)
#
# **Critical Actions** :
# | Action | Lead Agency | Priority |
# |--------|-------------|----------|
# | **Activate EOC at Level 1 (Full Activation)** | State EM Director | CRITICAL |
# | **Issue mandatory evacuation for Zones A and B** | County Officials | CRITICAL |
# | **Activate National Guard (500-1,000 troops)** | Adjutant General | CRITICAL |
# | Open general population shelters | DCF/Red Cross | CRITICAL |
# | Begin contraflow operations on major highways | FHP/FDOT | HIGH |
# | Suspend toll operations on evacuation routes | Turnpike Authority | HIGH |
# | Close public schools and state offices | Governor/Cabinet | HIGH |
# | Activate Urban Search and Rescue teams | State Fire Marshal | HIGH |
# | Pre-position high-water rescue vehicles | Local Fire Departments | HIGH |
# | Coordinate with federal agencies (FEMA, USACE, USCG) | State EM Division | HIGH |
#
# **Resource Pre-Positioning** :
#
# | Resource | Location | Quantity | Status |
# |----------|----------|----------|--------|
# | High-water vehicles | 5 regional staging areas | 100 | Staged |
# | Swift water rescue teams | EOC staging points | 20 teams | Ready |
# | Generators | Emergency shelters | 150 units | Deployed |
# | Water (bottled) | Distribution points | 500,000 gallons | Stockpiled |
# | MREs/Meals | Distribution points | 1,000,000 meals | Stockpiled |
# | Medical supplies | Strategic hospitals | 10 caches | Pre-positioned |
# | Fuel trucks | Critical facilities | 50 trucks | Filled |
# | Power line crews | Regional hubs | 2,000 personnel | On standby |
# | Debris removal equipment | Safe zones | 500 trucks | Staged |
# | Helicopters | National Guard armories | 20 aircraft | Fueled |
#
# **Deliverables** :
# - Full EOC Activation
# - Mandatory Evacuation Orders
# - Shelter Openings Report
# - Resource Staging Map
#
# ---
#
# ### H-24 Hours (1 Day): Final Preparation
#
# **Status** : Critical Phase
#
# **Critical Actions** :
# | Action | Lead Agency | Priority |
# |--------|-------------|----------|
# | Expand mandatory evacuations to Zone C if needed | County Officials | CRITICAL |
# | Open last-resort shelters for remaining evacuees | DCF/Red Cross | CRITICAL |
# | Suspend all public transportation and commercial flights | DOT/FAA | CRITICAL |
# | Close ports and harbors | USCG/Port Authority | HIGH |
# | Finalize mutual aid agreements with neighboring states | State EM Division | HIGH |
# | Issue curfew orders for evacuated areas | Local Law Enforcement | HIGH |
# | Coordinate with utilities for post-storm restoration | Public Service Commission | HIGH |
# | Secure critical infrastructure (water treatment, power plants) | Facility Operators | CRITICAL |
#
# **Critical Infrastructure Protection** :
#
# | Infrastructure | Protective Action | Lead |
# |---------------|-------------------|------|
# | Power plants | Secure facilities; emergency staffing | Utility Companies |
# | Water treatment | Protect pumps; emergency generators | Water Management Districts |
# | Hospitals | Shelter-in-place; secure backup power | DOH/Hospital Systems |
# | Communication towers | Reinforce; backup power activated | Carriers |
# | Fuel storage | Secure tanks; prevent spills | Terminal Operators |
# | Wastewater treatment | Secure facilities; bypass protocols prepared | County Utilities |
#
# **Deliverables** :
# - Final Evacuation Status Report
# - Infrastructure Protection Status
# - Curfew Orders
#
# ---
#
# ### H-12 Hours: Shelter in Place
#
# **Status** : Final Preparation Complete
#
# **Critical Actions** :
# | Action | Lead Agency | Priority |
# |--------|-------------|----------|
# | Close evacuation routes | Public Safety | CRITICAL |
# | Emergency responders shelter in place | Public Safety | CRITICAL |
# | Secure EOC and command posts | Incident Commander | HIGH |
# | Final weather and impact briefing | NWS/EM Staff | HIGH |
# | Position damage assessment teams for immediate post-impact | All Agencies | HIGH |
#
# ---
#
# ### H-6 to H-0: Final Countdown
#
# **Critical Actions** :
# | Action | Lead Agency | Priority |
# |--------|-------------|----------|
# | All first responders in secure locations | Public Safety | CRITICAL |
# | EOC staff in weather-secure operations center | EOC Director | CRITICAL |
# | Final readiness check for all response elements | Incident Commander | CRITICAL |
# | Landfall confirmation | NWS | — |
# | Immediate post-impact assessment begins | All Agencies | CRITICAL |
#
# ---
#
# ## Resource Mobilization
# <p><em>[Interactive map — open notebook in JupyterHub to view]</em></p>
# This chart shows the phased mobilization of key response resources across the operational timeline.
#
# ### Resource Activation Schedule
#
# | Resource Type | H-120 | H-72 | H-48 | H-24 | H-0 | H+24 |
# |---------------|-------|------|------|------|-----|------|
# | EOC Staff | 10 | 25 | 100 | 150 | 200 | 200 |
# | National Guard | 0 | 0 | 500 | 1,000 | 2,000 | 2,500 |
# | Search & Rescue Teams | 0 | 5 | 15 | 20 | 20 | 35 |
# | Shelter Capacity (thousands) | 0 | 50 | 150 | 300 | 350 | 300 |
# | Utility Crews (hundreds) | 5 | 10 | 20 | 20 | 20 | 30 |
# | Medical Teams | 5 | 15 | 30 | 50 | 80 | 100 |
#
# ---
#
# ## Emergency Operations Center (EOC) Organization
#
# ### Command Structure
#
# ```
# STATE EMERGENCY OPERATIONS CENTER
# ├── EOC Director (State Emergency Management Director)
# │
# ├── OPERATIONS SECTION CHIEF
# │   ├── Branch: Emergency Services (Law Enforcement, Fire/Rescue, EMS)
# │   ├── Branch: Public Works & Infrastructure (Transportation, Utilities, Public Works)
# │   ├── Branch: Human Services (Sheltering, Mass Care, Special Needs)
# │   └── Branch: Search & Rescue (USAR, Swift Water, Air Operations)
# │
# ├── PLANNING SECTION CHIEF
# │   ├── Situation Unit (Real-time situational awareness)
# │   ├── Intelligence Unit (Threat analysis, predictive modeling)
# │   ├── Damage Assessment Unit (Preliminary, PAS, PDA)
# │   └── Documentation Unit (Incident Action Plans, reports)
# │
# ├── LOGISTICS SECTION CHIEF
# │   ├── Resource Ordering (EMAC, FEMA, vendors)
# │   ├── Supply Chain (Warehousing, distribution)
# │   ├── Facilities Management (EOC, shelters, staging areas)
# │   └── Communications (Radio, IT, satellite phones)
# │
# ├── FINANCE & ADMINISTRATION SECTION CHIEF
# │   ├── Cost Tracking (Labor, contracts, mutual aid)
# │   ├── Procurement (Emergency purchasing authority)
# │   ├── Compensation & Claims (Staffing, reimbursement)
# │   └── Timekeeping (Documentation for FEMA reimbursement)
# │
# └── PUBLIC INFORMATION OFFICER
#     ├── Joint Information Center (JIC)
#     ├── Media Relations (Press briefings, releases)
#     ├── Social Media (Continuous public updates)
#     └── Public Warning (EAS, WEA, sirens)
# ```
#
# ### EOC Activation Levels
#
# | Level | Condition | Staffing | Primary Function |
# |-------|-----------|----------|------------------|
# | **Level 3** | Monitoring | 10-15 staff | Information gathering, coordination calls |
# | **Level 2** | Partial activation | 25-50 staff | Planning, resource pre-positioning |
# | **Level 1** | Full activation | 100-200 staff | 24/7 operations, direct response coordination |
#
# ---
#
# ## Critical Decision Matrix
#
# | Decision Point | Criteria | Authority | Notification |
# |----------------|----------|-----------|--------------|
# | **Voluntary Evacuation** | Hurricane Watch; Category 3+; 72+ hours | County EM Director | Public: 48+ hours |
# | **Mandatory Evacuation** | Hurricane Warning; surge zones; Category 3+ | County Judge/Mayor | Public: 36-48 hours |
# | **Shelter Activation** | Evacuation order issued; capacity needs identified | EM Director/Director of DCF | Public: 24-48 hours |
# | **School Closure** | Hurricane Watch; transportation impacts | Governor/Cabinet | Public: 48 hours |
# | **Curfew** | Public safety threat; evacuation zones | Mayor/County Judge | Public: 12-24 hours |
# | **National Guard Activation** | State of emergency; resource shortfall | Governor | FEMA: Immediate |
# | **Contraflow Operations** | Mass evacuation; traffic congestion | Governor/FDOT | Public: 24-48 hours |
# | **Federal Disaster Declaration** | State resources exceeded; significant damage | Governor | FEMA: Immediately |
# | **Hospital Evacuation** | Direct threat; power loss | Hospital Command/DOH | Patients/Families: 24+ hours |
#
# ---
#
# ## Post-Landfall Response Timeline
#
# ### H+0 to H+12 Hours: Initial Response — LIFE SAFETY FOCUS
#
# **Priorities** (in order):
# 1. Search and rescue operations
# 2. Medical emergencies and critical care
# 3. Fire suppression
# 4. Hazardous materials incidents
# 5. Initial infrastructure damage assessment
#
# **Critical Actions** :
# | Time | Action | Lead |
# |------|--------|------|
# | H+0 | Begin weather reconnaissance; initial damage assessment | NWS/EOC |
# | H+2 | Deploy Search and Rescue teams to impacted areas | State Fire Marshal |
# | H+2 | Reopen evacuation routes as conditions allow | FHP/FDOT |
# | H+4 | Begin medical evacuation for hospitals if needed | DOH |
# | H+6 | Deploy high-water vehicles to flooded areas | Local Fire |
# | H+8 | Begin infrastructure assessment (bridges, roads, utilities) | DOT/Utilities |
# | H+12 | Provide initial situation report to FEMA | State EM |
#
# ---
#
# ### H+12 to H+48 Hours: Sustained Response — INCIDENT STABILIZATION
#
# **Priorities** :
# 1. Expand search and rescue to all accessible areas
# 2. Establish mass care operations
# 3. Restore essential services
# 4. Conduct comprehensive damage assessment
# 5. Initiate debris management
#
# **Critical Actions** :
# | Time | Action | Lead |
# |------|--------|------|
# | H+12 | Open points of distribution (PODs) for food/water | Logistics |
# | H+18 | Restore 911 and emergency communications | Communications |
# | H+24 | Begin debris removal from critical routes | Public Works |
# | H+24 | Restore power to critical facilities (hospitals, shelters) | Utilities |
# | H+36 | Complete preliminary damage assessment | Planning Section |
# | H+48 | Begin transition to recovery phase | EOC Director |
#
# ---
#
# ### H+48 to H+72 Hours: Recovery Transition
#
# **Critical Actions** :
# | Time | Action | Lead |
# |------|--------|------|
# | H+48 | FEMA Preliminary Damage Assessment (PDA) begins | FEMA/State |
# | H+60 | Begin disaster assistance registration | FEMA |
# | H+72 | Issue re-entry permits for residents | Local Officials |
#
# ---
#
# ## Communication Plan
#
# ### Public Communication Schedule
#
# | Phase | Frequency | Methods | Content |
# |-------|-----------|---------|---------|
# | **Pre-Impact** (H-48 to H-0) | Every 2 hours | EAS, WEA, social media, TV/radio | Storm track, evacuation orders, shelter info |
# | **Impact** (H-0 to H+12) | Every hour (if possible) | EAS, WEA, social media, radio | Weather updates, safety instructions |
# | **Immediate Response** (H+12 to H+48) | Every 4 hours | Social media, press briefings | Rescue operations, road conditions, POD locations |
# | **Sustained Response** (H+48+) | Every 8 hours | Social media, website | Recovery information, assistance programs |
#
# ### Warning Systems
#
# | System | Activation Time | Reach | Purpose |
# |--------|-----------------|-------|---------|
# | **Wireless Emergency Alerts (WEA)** | Immediate (mobile phones) | Statewide | Critical evacuation orders, life safety warnings |
# | **Emergency Alert System (EAS)** | Immediate (TV/radio) | Broadcast media | Official announcements, weather alerts |
# | **Outdoor Warning Sirens** | Immediate (local areas) | Siren coverage | Immediate threat notification |
# | **Social Media** | Continuous | Online audiences | Real-time updates, FAQs, resources |
# | **Nixle/Alert Florida** | As needed | Subscribers | Localized alerts, evacuation notices |
#
# ---
#
# ## Emergency Management Priority Hierarchy
#
# Always follow this order in decision-making:
#
# 1. **LIFE SAFETY** (Immediate) — Protect human life and safety above all else
# 2. **INCIDENT STABILIZATION** (Hours to days) — Control the situation; prevent escalation
# 3. **PROPERTY AND ENVIRONMENTAL PROTECTION** (Days) — Minimize damage to property and environment
# 4. **RESTORATION OF SERVICES** (Days to weeks) — Return community to normal functioning
# 5. **RECOVERY AND MITIGATION** (Weeks to years) — Rebuild stronger; reduce future risk
#
# ---
#
# ## Key Contact Information
#
# | Contact | Phone | Purpose |
# |---------|-------|---------|
# | **State Emergency Operations Center** | 850-413-9900 | 24/7 coordination |
# | **Florida Division of Emergency Management** | 850-815-4000 | Agency-specific issues |
# | **National Hurricane Center** | 305-229-4400 | Weather briefings |
# | **FEMA Region 4** | 770-631-3600 | Federal assistance |
# | **U.S. Army Corps of Engineers** | 904-232-1002 | Infrastructure support |
# | **U.S. Coast Guard (District 7)** | 305-535-4472 | Maritime emergencies |
#
# ---
#
# ## Supporting Documents
#
# The following documents have been created for your reference:
#
# 1. **hurricane_response_timeline.md** — Detailed timeline with all phases, actions, and deliverables
# 2. **hurricane_response_quick_reference.md** — Condensed quick-reference guide for EOC use
# 3. **hurricane_response_timeline_chart.png** — Visual timeline overview (shown above)
# 4. **resource_mobilization_chart.png** — Resource staging and deployment visualization (shown above)
#
# ---
#
# ## Next Steps
#
# To operationalize this plan:
#
# 1. **Distribute** the quick reference guide to all EOC section chiefs and county emergency managers
# 2. **Review** the detailed timeline with your response teams and adjust for local conditions
# 3. **Conduct** a tabletop exercise within the next 7 days to validate roles and responsibilities
# 4. **Verify** resource contracts and mutual aid agreements are current
# 5. **Update** contact lists and ensure all communication systems are operational
