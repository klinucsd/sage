# %%
# %reset

# %%
# %%ask
# Search Skillsmp marketplace for skills related to emergency management for diasters.
# show me the results as a table.
# Out:
# I'll search the Skillsmp marketplace for skills related to emergency management for disasters. Let me first read the Skillsmp skill to understand how to search.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# I'll search the Skillsmp marketplace for skills related to emergency management for disasters using the AI semantic search. Let me write a Python script to perform this search.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_skills.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_skills.py",
#   "content": "import os\nimport requests\nimport json\nfrom pathlib import Path\nfrom dotenv import load_dotenv\n\n# Load from .env files (dotenv is already installed)\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"SKILLSMP_API_KEY not found. Set it via export, or add it to .env\")\n    exit(1)\n\n# AI semantic search for emergency management and disaster-related skills\nquery = \"emergency management for disasters\"\nurl = f\"https://skillsmp.com/api/v1/skills/ai-search\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\nparams = {\"q\": query}\n\ntry:\n    response = requests.get(url, headers=headers, params=params)\n    response.raise_for_status()\n    data = response.json()\n\n    if data.get(\"success\"):\n        results = data.get(\"data\", {}).get(\"data\", [])\n\n        print(f\"Found {len(results)} skills related to '{query}'\\n\")\n\n        # Display results as a markdown table\n        print(\"| Rank | Name | Author | Stars | Score | Description |\")\n        print(\"|------|------|--------|-------|-------|-------------|\")\n\n        for idx, item in enumerate(results[:10], 1):\n            skill = item.get(\"skill\", {})\n            name = skill.get(\"name\", \"N/A\")\n            author = skill.get(\"author\", \"N/A\")\n            stars = skill.get(\"stars\", 0)\n            score = item.get(\"score\", 0)\n            description = skill.get(\"description\", \"No description\")[:100]\n\n            print(f\"| {idx} | **{name}** | {author} | {stars} | {score:.0%} | {description}... |\")\n    else:\n        print(\"Search failed:\", data.get(\"message\", \"Unknown error\"))\n\nexcept requests.exceptions.RequestException as e:\n    print(f\"Error making request: {e}\")\nexcept Exception as e:\n    print(f\"Unexpected error: {e}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_skills.py</pre>
#     </div>
#   </details>
# </div>
# Here are the emergency management and disaster-related skills from the Skillsmp marketplace:
#
# | Rank | Name | Author | Stars | Score | Description |
# |------|------|--------|-------|-------|-------------|
# | 1 | **emergency-manager** | theneoai | 15 | 98% | Expert emergency manager specializing in disaster preparedness, response coordination, hazard mitiga... |
# | 2 |**risk-mitigation-planning** | a5c-ai | 500 | 61% | Develop comprehensive risk management plans for collections and cultural venues including disaster p... |
# | 3 |**emergency-response** | majiayu000 | 2 | 59% | 🚨 Critical emergency management protocols for festivals including medical response, evacuation proce... |
# | 4 |**emergency-response** | UffaModey | 1 | 59% | 🚨 Critical emergency management protocols for festivals including medical response, evacuation proce... |
# | 5 |**managing-emergency-preparedness** | CaseMark | 7 | 27% | Structures public health emergency preparedness with hazard vulnerability and response planning. Use... |
# | 6 |**crisis-management** | Kaakati | 1 | 23% | Crisis management and incident response planning engine that builds classification frameworks, decis... |
# | 7 |**emergency-protocol** | Jarang-Mandi | 0 | 23% | Protokol crisis management untuk black swan events, system failures, market manipulation, dan situas... |
# | 8 |**disaster-recovery** | KilimcininKorOglu | 5 | 16% | This skill MUST be invoked when the user says "disaster recovery", "felaket kurtarma", "business con... |
# | 9 |**managing-pandemic-response** | CaseMark | 7 | 15% | Structures pandemic response planning with surge capacity, resource allocation, and communication pr... |
# | 10 |**planning-disaster-recovery** | ancoleman | 318 | 15% | Design and implement disaster recovery strategies with RTO/RPO planning, database backups, Kubernete... |
#
# The search found**10 relevant skills** . The top match is **emergency-manager** with a 98% relevance score, followed by**risk-mitigation-planning** which has the highest star count (500) at 61% relevance. Would you like me to show you more details about any of these skills, or help you install one of them?

# %%
# %%ask
# Could you please show me the details of the skill emergency-manager?
# Out:
# I'll help you get the details of the "emergency-manager" skill. Let me first check the Skillsmp skill to understand how to retrieve detailed information about a specific skill.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md",
#   "offset": 100
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll check if the "emergency-manager" skill is already installed locally, and if not, fetch its details from the Skillsmp marketplace.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_skill_details.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_skill_details.py",
#   "content": "#!/usr/bin/env python3\nimport os\nimport requests\nfrom pathlib import Path\nfrom dotenv import load_dotenv\n\n# Load API key\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\n\n# Check if skill is already installed\nskill_name = \"emergency-manager\"\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nlocal_skill_file = skill_dir / \"SKILL.md\"\n\nif local_skill_file.exists():\n    print(f\"Skill '{skill_name}' is already installed locally.\\n\")\n    print(local_skill_file.read_text())\nelse:\n    print(f\"Skill '{skill_name}' not found locally. Fetching from marketplace...\\n\")\n\n    # Search marketplace for the skill\n    search_url = \"https://skillsmp.com/api/v1/skills/search\"\n    headers = {\"Authorization\": f\"Bearer {API_KEY}\"}\n    params = {\"q\": skill_name}\n\n    resp = requests.get(search_url, headers=headers, params=params, timeout=15)\n    data = resp.json()\n\n    if not data.get(\"success\"):\n        print(f\"Error searching marketplace: {data}\")\n        exit(1)\n\n    skills = data.get(\"data\", {}).get(\"skills\", [])\n    matching_skill = None\n\n    for skill in skills:\n        if skill.get(\"name\", \"\").lower() == skill_name.lower():\n            matching_skill = skill\n            break\n\n    if not matching_skill:\n        print(f\"Could not find skill '{skill_name}' in marketplace.\")\n        exit(1)\n\n    print(f\"Found skill: {matching_skill['name']}\")\n    print(f\"Author: {matching_skill['author']}\")\n    print(f\"Stars: {matching_skill['stars']}\")\n    print(f\"GitHub URL: {matching_skill['githubUrl']}\\n\")\n\n    # Convert GitHub URL to raw URL\n    github_url = matching_skill['githubUrl']\n    raw_url = github_url.replace(\n        \"https://github.com/\",\n        \"https://raw.githubusercontent.com/\"\n    ).replace(\"/tree/main/\", \"/main/\").replace(\"/tree/master/\", \"/master/\")\n\n    raw_url = raw_url.rstrip(\"/\") + \"/SKILL.md\"\n\n    print(f\"Fetching SKILL.md from: {raw_url}\\n\")\n\n    # Fetch SKILL.md content\n    skill_resp = requests.get(raw_url, timeout=15)\n    print(skill_resp.text)\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_skill_details.py</pre>
#     </div>
#   </details>
# </div>
# Here are the full details of the **emergency-manager** skill:
#
# ---
#
# # Emergency Manager Skill Details**Name** : emergency-manager
# **Author** : theneoai
# **License** : MIT
# **Stars** : 15
# **GitHub Repository** : [theneoai/awesome-skills](https://github.com/theneoai/awesome-skills/tree/main/skills/government/emergency-manager)
#
# ## Description
#
# Expert emergency manager specializing in disaster preparedness, response coordination, hazard mitigation, and crisis communication. Use when developing emergency plans, coordinating multi-agency response, managing evacuation operations, or leading disaster recovery efforts. Covers all hazards including natural disasters, technological emergencies, and security incidents.
#
# ---
#
# ## Skill Overview
#
# This skill provides a comprehensive emergency management framework based on 20+ years of experience in disaster preparedness, response, and recovery. The skill is built on:
#
# - **Identity** : Certified Emergency Manager (CEM) with experience as Emergency Management Director for a major metropolitan area
# - **Certifications** : Master Exercise Practitioner (MEP), Homeland Security, Crisis Leadership
# - **Core Standards** : NIMS, ICS, National Response Framework
#
# ---
#
# ## Key Features
#
# ### Emergency Management Priority Hierarchy
#
# | Priority | Phase | Focus |
# |----------|-------|-------|
# | 1 | Life Safety | Protect human life, search & rescue, medical care |
# | 2 | Incident Stabilization | Control situation, prevent escalation |
# | 3 | Property & Environmental Protection | Minimize damage, contain hazards |
# | 4 | Restoration of Services | Return community to normal functioning |
# | 5 | Recovery & Mitigation | Rebuild stronger, reduce future risk |
#
# ### Comprehensive Emergency Management Cycle
#
# ```
#         MITIGATION
#             ▲
#             │
#     RECOVERY ◄────► PREPAREDNESS
#             │
#             ▼
#          RESPONSE
# ```
#
# ### Incident Command System Structure
#
# - **Incident Commander** : Overall command
# - **Operations** : Executes response operations
# - **Planning** : Situation analysis, resource planning
# - **Logistics** : Supply, facilities, communications, medical
# - **Finance/Admin** : Cost tracking, financial management
#
# ---
#
# ## Scope
#
# ### ✓ In Scope
#
# - Emergency operations planning
# - Incident command and coordination
# - Crisis communication and public warning
# - Resource management and mutual aid
# - Evacuation planning and sheltering
# - Hazard mitigation planning
# - Long-term recovery coordination
# - Exercise design and evaluation
#
# ### ✗ Out of Scope
#
# - Tactical firefighting → use fire-chief
# - Law enforcement tactics → use police-chief
# - Medical treatment protocols → use medical-director
# - Engineering assessments → use structural-engineer
#
# ---
#
# ## Workflow
#
# ### Phase 1: Assessment
# - Gather requirements and constraints
# - Analyze current state and gaps
# - Define success criteria
#
# ### Phase 2: Planning
# - Develop solution approach
# - Identify resources and timeline
# - Risk assessment and mitigation plan
#
# ### Phase 3: Execution
# - Implement solution per plan
# - Continuous progress monitoring
# - Adjust based on feedback
#
# ### Phase 4: Review & Validation
# - Validate outcomes against criteria
# - Document lessons learned
# - Handoff to stakeholders
#
# ---
#
# ## Quality Metrics
#
# | Dimension | Score | Justification |
# |-----------|-------|---------------|
# | System Prompt | 9.5/10 | Complete identity, framework, thinking patterns |
# | Domain Knowledge | 9.5/10 | Comprehensive ICS, NIMS, disaster cycle coverage |
# | Workflow | 9.5/10 | Phased response process |
# | Examples | 9.5/10 | 5 diverse scenarios covering key emergency types |
# | Risk Management | 9.5/10 | Comprehensive risk matrix |
#
# ---
#
# ## References
#
# **National Standards:** - FEMA: National Incident Management System (NIMS)
# - FEMA: National Response Framework
# - FEMA: Comprehensive Preparedness Guide 101
# - IAEM: Emergency Management Principles**Professional Certification:**
# - IAEM: Certified Emergency Manager (CEM)
# - EMI: Master Exercise Practitioner
#
# ---
#
# Would you like me to install this skill so you can use it, or would you like to explore any specific aspect of emergency management in more detail?

# %%
# %%ask
# Could you please install this skill for me?
# Out:
# I'll install the emergency-manager skill for you. Let me first check the current skills directory structure, then download and install the skill.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills"
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll download the emergency-manager skill from GitHub and install it to the skills directory.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>curl -L -o /tmp/emergency-manager.zip https://github.com/theneoai/awesome-ski...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>curl -L -o /tmp/emergency-manager.zip https://github.com/theneoai/awesome-skills/archive/refs/heads/main.zip</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>unzip -q /tmp/emergency-manager.zip -d /tmp && mv /tmp/awesome-skills-main/sk...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>unzip -q /tmp/emergency-manager.zip -d /tmp &amp;&amp; mv /tmp/awesome-skills-main/skills/government/emergency-manager /home/jovyan/.deepagents/agent/skills/</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md",
#   "limit": 30
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>rm -rf /tmp/emergency-manager.zip /tmp/awesome-skills-main</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>rm -rf /tmp/emergency-manager.zip /tmp/awesome-skills-main</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills"
# }</pre>
#     </div>
#   </details>
# </div>
# The **emergency-manager** skill has been successfully installed!**Installation Summary:** -**Skill name** : emergency-manager
# - **Location** : `/home/jovyan/.deepagents/agent/skills/emergency-manager/`
# - **Files installed** :
#   - `SKILL.md` - Main skill documentation
#   - `EVALUATION_REPORT.md` - Quality assessment
#   - `references/` - Supporting reference materials
#
# The skill is now available for use and will appear in your skills list. You can now use it for tasks related to:
# - Emergency operations planning
# - Incident command and coordination
# - Crisis communication and public warning
# - Resource management and mutual aid
# - Evacuation planning and sheltering
# - Hazard mitigation planning
# - Long-term recovery coordination
# - Exercise design and evaluation
#
# Would you like me to help you with a specific emergency management task using this skill?

# %%
# %%ask
# We have a major hurricane approaching in Florida next week.
# How do we coordinate the response?
# Out:
# I'll help you coordinate the hurricane response using the emergency-manager skill. Let me first read the skill documentation to apply the proper framework.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md",
#   "offset": 100
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a comprehensive hurricane response coordination plan based on the emergency management framework.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 4 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       🔄 Create comprehensive hurricane response coordination plan<br>⏳ Generate ICS structure visualization<br>⏳ Create response timeline visualization<br>⏳ Create resource tracking template
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_plan.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_plan.md",
#   "content": "# Hurricane Response Coordination Plan\n## Florida - Major Hurricane Approaching\n\n---\n\n## EXECUTIVE SUMMARY\n\n**Situation**: Major hurricane approaching Florida, expected landfall within 7 days\n**Primary Objective**: Preserve life and minimize impacts on affected communities\n**Activation Level**: Partial EOC activation → Full EOC activation (72 hours prior to landfall)\n\n---\n\n## § 1 · THREAT ASSESSMENT\n\n### 1.1 Current Situation\n\n| Factor | Status | Impact Level |\n|--------|--------|--------------|\n| Storm Intensity | Category 3-4 (predicted) | CRITICAL |\n| Time to Landfall | 7 days | HIGH |\n| Landfall Zone | Florida Gulf Coast | HIGH |\n| Population at Risk | 2-5 million | SEVERE |\n| Evacuation Timeline | 72-hour window recommended | CRITICAL |\n\n### 1.2 Risk Factors\n\n- **Primary Hazards**: Storm surge (10-15+ feet), extreme winds (110-140+ mph), torrential rainfall (15-25 inches), tornadoes\n- **Secondary Hazards**: Flooding, power outages (weeks), water supply contamination, communications disruption\n- **Vulnerable Populations**: Coastal communities, elderly, low-income, medical-dependent residents, tourists\n\n---\n\n## § 2 · INCIDENT COMMAND SYSTEM (ICS) STRUCTURE\n\n### 2.1 Command Staff\n\n```\n                    INCIDENT COMMANDER\n                           │\n        ┌──────────────────┼──────────────────┬──────────────────┐\n        │                  │                  │                  │\n   SAFETY OFFICER    LIAISON OFFICER    PUBLIC INFO      DEPUTY IC\n                      OFFICER           OFFICER        (Operations)\n```\n\n**Key Appointments**:\n- **Incident Commander**: State Emergency Management Director\n- **Deputy IC (Operations)**: Florida Division of Emergency Management Operations Chief\n- **Public Information Officer**: State Joint Information Center (JIC) Manager\n- **Liaison Officer**: Federal Coordination Officer (when FEMA activated)\n- **Safety Officer**: State Safety &amp; Health Manager\n\n### 2.2 General Staff\n\n**Operations Section** (Executes response):\n- **Branches**:\n  - Evacuation &amp; Sheltering Branch\n  - Search &amp; Rescue Branch\n  - Emergency Services Branch (Fire, EMS, Law Enforcement)\n  - Public Works &amp; Infrastructure Branch\n  - Mass Care &amp; Human Services Branch\n\n- **Divisions/Groups**:\n  - Coastal Evacuation Divisions (by county)\n  - Shelter Operations Group\n  - Urban Search &amp; Rescue Task Forces\n  - Aerial Operations Branch\n  - Emergency Communications\n\n**Planning Section** (Provides intelligence &amp; planning):\n- Resources Unit\n- Situation Unit\n- Documentation Unit\n- Demobilization Unit\n- Technical Specialists: Meteorology, Flood Modeling, GIS Mapping\n\n**Logistics Section** (Provides support):\n- Supply Unit (food, water, medical supplies, tarps)\n- Facilities Unit (EOC, staging areas, base camps)\n- Ground Support Unit (fueling, vehicle maintenance)\n- Communications Unit (radio networks, satellite, backup systems)\n- Medical Unit (EMS support, medical teams)\n\n**Finance/Administration Section** (Tracks costs):\n- Time Unit\n- Procurement Unit\n- Compensation/Claims Unit\n- Cost Unit\n\n---\n\n## § 3 · PRE-LANDFALL ACTIONS (Days 7-1)\n\n### Day 7-5: Preparedness &amp; Warning\n\n**Actions**:\n- [ ] Activate State EOC at Level 3 (Partial)\n- [ ] Conference call with county EM directors\n- [ ] Review/update Hurricane Operations Plan\n- [ ] Conduct Governor's Hurricane Conference\n- [ ] Issue public advisories: \"Hurricane Watch\" preparation\n- [ ] Pre-position contracts for debris removal, generators, food/water\n- [ ] Coordinate with federal partners (FEMA Region IV, USACE, USCG)\n\n**Key Messages to Public**:\n- Review your emergency plan\n- Build/update emergency supply kit\n- Know your evacuation zone\n- Sign up for local alerts\n- Prepare home (shutters, outdoor items)\n\n---\n\n### Day 4-3: Enhanced Readiness\n\n**Actions**:\n- [ ] Activate State EOC at Level 2 (Enhanced)\n- [ ] Activate Regional ...
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 4 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       ✅ Create comprehensive hurricane response coordination plan<br>🔄 Generate ICS structure visualization<br>⏳ Create response timeline visualization<br>⏳ Create resource tracking template
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/ics_structure.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/ics_structure.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nHurricane Response ICS Structure Visualization\n\"\"\"\n\nimport matplotlib.pyplot as plt\nimport matplotlib.patches as patches\nfrom matplotlib.patches import FancyBboxPatch, FancyArrowPatch\n\nfig, ax = plt.subplots(figsize=(18, 12), dpi=150)\nax.set_xlim(0, 100)\nax.set_ylim(0, 100)\nax.axis('off')\nax.set_title('Incident Command System (ICS) Structure - Hurricane Response', fontsize=20, weight='bold', pad=20)\n\n# Color scheme\nCOLORS = {\n    'command': '#D32F2F',      # Red\n    'command_staff': '#1976D2', # Blue\n    'operations': '#388E3C',    # Green\n    'planning': '#F57C00',     # Orange\n    'logistics': '#7B1FA2',    # Purple\n    'finance': '#616161',      # Gray\n    'text': 'white'\n}\n\ndef add_box(x, y, width, height, text, color, fontsize=10, weight='bold'):\n    \"\"\"Add a labeled box to the diagram\"\"\"\n    box = FancyBboxPatch((x, y), width, height, boxstyle=\"round,pad=0.1\",\n                         facecolor=color, edgecolor='black', linewidth=2)\n    ax.add_patch(box)\n    ax.text(x + width/2, y + height/2, text, ha='center', va='center',\n            color=COLORS['text'], fontsize=fontsize, weight=weight, wrap=True)\n    return box\n\ndef add_arrow(start, end, color='black'):\n    \"\"\"Add an arrow between boxes\"\"\"\n    arrow = FancyArrowPatch(start, end, arrowstyle='-&gt;', mutation_scale=20,\n                           color=color, linewidth=2)\n    ax.add_patch(arrow)\n\n# INCIDENT COMMANDER (Top center)\nic_box = add_box(40, 85, 20, 10, 'INCIDENT\\nCOMMANDER', COLORS['command'], fontsize=12)\n\n# COMMAND STAFF (below IC)\ny_staff = 70\nstaff_positions = [\n    ('SAFETY\\nOFFICER', 10),\n    ('LIAISON\\nOFFICER', 40),\n    ('PUBLIC INFO\\nOFFICER', 70)\n]\nfor text, x_pos in staff_positions:\n    add_box(x_pos, y_staff, 18, 8, text, COLORS['command_staff'], fontsize=10)\n\n# GENERAL STAFF (lower section)\ny_section = 52\nsections = [\n    ('OPERATIONS', 10, COLORS['operations']),\n    ('PLANNING', 30, COLORS['planning']),\n    ('LOGISTICS', 50, COLORS['logistics']),\n    ('FINANCE/\\nADMIN', 70, COLORS['finance'])\n]\nfor text, x_pos, color in sections:\n    add_box(x_pos, y_section, 18, 10, text, color, fontsize=11)\n\n# ARROWS from IC to Command Staff\nfor text, x_pos in staff_positions:\n    add_arrow((50, 85), (x_pos + 9, y_staff + 8))\n\n# ARROWS from IC to General Staff\nfor text, x_pos, color in sections:\n    add_arrow((50, 85), (x_pos + 9, y_section + 10))\n\n# OPERATIONS SECTION BRANCHES (detailed)\ny_branch = 32\nops_branches = [\n    ('EVACUATION &amp;\\nSHELTERING', 2),\n    ('SEARCH &amp;\\nRESCUE', 14),\n    ('EMERGENCY\\nSERVICES', 26)\n]\nfor text, x_pos in ops_branches:\n    add_box(x_pos, y_branch, 10, 6, text, COLORS['operations'], fontsize=8, weight='normal')\n    add_arrow((19, 52), (x_pos + 5, y_branch + 6))\n\nops_branches2 = [\n    ('PUBLIC WORKS\\n&amp; INFRA', 38),\n    ('MASS CARE &amp;\\nHUMAN SERVICES', 50),\n    ('AERIAL\\nOPS', 62)\n]\nfor text, x_pos in ops_branches2:\n    add_box(x_pos, y_branch, 10, 6, text, COLORS['operations'], fontsize=8, weight='normal')\n    add_arrow((19, 52), (x_pos + 5, y_branch + 6))\n\n# PLANNING SECTION UNITS\ny_unit = 32\nplan_units = [\n    ('RESOURCES', 30),\n    ('SITUATION', 40),\n    ('DOCUMENTATION', 50)\n]\nfor text, x_pos in plan_units:\n    add_box(x_pos, y_unit, 8, 6, text, COLORS['planning'], fontsize=8, weight='normal')\n    add_arrow((39, 52), (x_pos + 4, y_unit + 10))\n\n# LOGISTICS SECTION UNITS\ny_log_unit = 32\nlog_units = [\n    ('SUPPLY', 50),\n    ('FACILITIES', 60),\n    ('COMM', 70)\n]\nfor text, x_pos in log_units:\n    add_box(x_pos, y_log_unit, 8, 6, text, COLORS['logistics'], fontsize=8, weight='normal')\n    add_arrow((59, 52), (x_pos + 4, y_log_unit + 10))\n\n# FINANCE SECTION UNITS\ny_fin_unit = 32\nfin_units = [\n    ('TIME', 70),\n    ('PROCUREMENT', 80),\n    ('COST', 90)\n]\nfor text, x_pos in fin_units:\n    add_box(x_pos, y_fin_unit, 8, 6, text,  ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/ics_structure.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📋 <b>write_todos</b> — 4 todo(s)
#   <details open>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       ✅ Create comprehensive hurricane response coordination plan<br>✅ Generate ICS structure visualization<br>🔄 Create response timeline visualization<br>⏳ Create resource tracking template
#     </div>
#   </details>
# </div>
