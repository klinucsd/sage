# %% [markdown]
#  # Skill Manager
#
#   This notebook demonstrates how **Sage** can extend its own capabilities on the fly using the [SkillsMP marketplace](https://skillsmp.com) — a repository of 700,000+ AI
#   agent skills.
#
#   ## What you can do here
#
#   - **Search** the marketplace for skills by topic or keyword
#   - **Browse** skill details and documentation
#   - **Install** a skill with a single natural language request
#   - **Use** a newly installed skill immediately — no kernel restart needed
#
#   ## Workflow
#
#   1. Run `%reset` to clear previous outputs (optional)
#   2. Use `%%ask` to search, install, and invoke skills
#   3. Installed skills are saved to `~/.deepagents/agent/skills/` and persist across sessions

# %%
# %reset
# Out:
# **Sage reset.**
# - Output folder cleared: `/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_` (0 items removed)
# - Conversation history cleared

# %%
# %%ask
# Search SkillsMP marketplace for an expert-level emergency management skill covering disaster
# preparedness, response coordination, and hazard mitigation. Show me the results as a table.
# Out:
# I'll search the SkillsMP marketplace for emergency management skills. Let me first check the Skillsmp skill to understand how to perform the search.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# I'll search the SkillsMP marketplace for emergency management skills using the AI semantic search. Let me create a script to perform this search.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_management.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_management.py",
#   "content": "import os\nimport requests\nimport json\nfrom pathlib import Path\nfrom dotenv import load_dotenv\n\n# Load API key from .env files\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"SKILLSMP_API_KEY not found. Set it via export, or add it to .env\")\n    exit(1)\n\n# Search for emergency management skills using AI semantic search\nquery = \"emergency management disaster preparedness response coordination hazard mitigation\"\nurl = f\"https://skillsmp.com/api/v1/skills/ai-search?q={query}\"\n\nheaders = {\n    \"Authorization\": f\"Bearer {API_KEY}\"\n}\n\nresponse = requests.get(url, headers=headers)\nresult = response.json()\n\n# Save results to JSON file\noutput_file = \"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/emergency_management_search_results.json\"\nwith open(output_file, \"w\") as f:\n    json.dump(result, f, indent=2)\n\nprint(f\"Search completed. Results saved to {output_file}\")\nprint(f\"Found {len(result.get('data', {}).get('data', []))} skills\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_management.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/emergency_management_search_results.json</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/emergency_management_search_results.json"
# }</pre>
#     </div>
#   </details>
# </div>
# ## SkillsMP Search Results: Emergency Management Skills
#
# I found 3 relevant skills in the SkillsMP marketplace. Here are the results:
#
# | Rank | Name | Author | Stars | Score | Description |
# |------|------|--------|-------|-------|-------------|
# | 1 | managing-emergency-preparedness | CaseMark | 8 | 85% | Structures public health emergency preparedness with hazard vulnerability and response planning. Use when planning emergency preparedness, conducting vulnerability assessments, or developing response plans. |
# | 2 | emergency-manager | theneoai | 24 | 76% | Expert emergency manager specializing in disaster preparedness, response coordination, hazard mitigation, and crisis communication. Use when developing emergency plans, coordinating multi-agency response, managing evacuation operations, or leading disaster recovery efforts. Covers all hazards including natural disasters, technological emergencies, and security incidents. |
# | 3 | risk-mitigation-planning | a5c-ai | - | 87% | Risk mitigation planning skill (details limited in search results) |
#
# **Top Recommendation** : The **emergency-manager** skill by theneoai appears to be the best match for your requirements. It specifically covers all three areas you mentioned:
# - **Disaster preparedness**
# - **Response coordination**
# - **Hazard mitigation**
#
# Additionally, it includes crisis communication, multi-agency response coordination, evacuation management, and disaster recovery. It has the highest star count (24) and the most comprehensive description covering all hazard types including natural disasters, technological emergencies, and security incidents.
#
# You can view the skill details at: https://skillsmp.com/skills/theneoai-awesome-skills-skills-government-emergency-manager-skill-md

# %%
# %%ask
# Could you please show me the details of the skill emergency-manager?
# Out:
# I'll retrieve the detailed information about the emergency-manager skill from SkillsMP.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# I'll create a Python script to retrieve the detailed information about the emergency-manager skill from the SkillsMP API.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_skill_details.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_skill_details.py",
#   "content": "import os\nfrom pathlib import Path\nfrom dotenv import load_dotenv\nimport requests\nimport json\n\n# Load API key\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"SKILLSMP_API_KEY not found\")\n    exit(1)\n\n# Search for the emergency-manager skill\nurl = \"https://skillsmp.com/api/v1/skills/search\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\nparams = {\"q\": \"emergency-manager\"}\n\nresponse = requests.get(url, headers=headers, params=params)\nresult = response.json()\n\n# Find the emergency-manager skill by theneoai\nif result.get(\"success\") and result.get(\"data\", {}).get(\"skills\"):\n    for skill in result[\"data\"][\"skills\"]:\n        if skill[\"name\"] == \"emergency-manager\" and skill[\"author\"] == \"theneoai\":\n            print(json.dumps(skill, indent=2))\n            break\nelse:\n    print(\"Skill not found\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_skill_details.py</pre>
#     </div>
#   </details>
# </div>
# I'll fetch the detailed skill content from the GitHub repository to provide you with comprehensive information.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_content.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_content.py",
#   "content": "import requests\n\n# Fetch the SKILL.md file from GitHub\nurl = \"https://raw.githubusercontent.com/theneoai/awesome-skills/main/skills/government/emergency-manager/SKILL.md\"\n\nresponse = requests.get(url)\nif response.status_code == 200:\n    print(response.text)\nelse:\n    print(f\"Failed to fetch skill content: {response.status_code}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_content.py</pre>
#     </div>
#   </details>
# </div>
# # Emergency Manager Skill Details
#
# ## Overview
#
# | Property | Value |
# |----------|-------|
# **Name** : emergency-manager
# **Version** : 1.0.0
# **Author** : theNeoAI
# **Stars** : 24
# **Level** : Expert
# **License** : MIT
# **Skill URL** : https://skillsmp.com/skills/theneoai-awesome-skills-skills-government-emergency-manager-skill-md
# **GitHub** : https://github.com/theneoai/awesome-skills/tree/main/skills/government/emergency-manager
#
# ## Description
#
# Expert emergency manager specializing in disaster preparedness, response coordination, hazard mitigation, and crisis communication. Use when developing emergency plans, coordinating multi-agency response, managing evacuation operations, or leading disaster recovery efforts. Covers all hazards including natural disasters, technological emergencies, and security incidents.
#
# ## Identity & Expertise
#
# The skill embodies a **Certified Emergency Manager (CEM)** with 20+ years of experience, including:
#
# - Former emergency management director for a major metropolitan area
# - Incident Commander for multiple Type 1 and Type 2 incidents
# - Master Exercise Practitioner (MEP) and exercise designer
# - Hazard mitigation specialist (flood, earthquake, hurricane)
# - Crisis communication and public information expert
#
# ## Core Competencies
#
# ### 1. **Preparedness**
# - Planning, training, exercises, public education
# - Emergency operations planning
# - Exercise design and evaluation
#
# ### 2. **Response**
# - ICS/NIMS (Incident Command System/National Incident Management System)
# - EOC (Emergency Operations Center) operations
# - Resource coordination and mutual aid
#
# ### 3. **Mitigation**
# - Risk assessment and THIRA (Threat-Hazard Identification and Risk Assessment)
# - Project design and grant management
# - Hazard mitigation planning
#
# ### 4. **Recovery**
# - Long-term recovery coordination
# - Disaster assistance
# - Community resilience building
#
# ### 5. **Communication**
# - Crisis communication
# - Public information and warning systems
# - Joint Information Center (JIC) operations
#
# ## Decision Framework
#
# The skill follows the **Emergency Management Priority Hierarchy** :
#
# 1. **LIFE SAFETY** (Immediate) — Protect human life above all else
# 2. **INCIDENT STABILIZATION** (Hours to days) — Control the situation, prevent escalation
# 3. **PROPERTY AND ENVIRONMENTAL PROTECTION** (Days) — Minimize damage
# 4. **RESTORATION OF SERVICES** (Days to weeks) — Return community to normal
# 5. **RECOVERY AND MITIGATION** (Weeks to years) — Rebuild stronger
#
# ## Key Thinking Patterns
#
# ### The Comprehensive Emergency Management Cycle
# ```
# MITIGATION
#     ▲
#     │
# RECOVERY ◄────► PREPAREDNESS
#     │
#     ▼
# RESPONSE
# ```
#
# ### Incident Command System Structure
# - **Operations** — Does the work (Branches, Divisions, Groups, Strike Teams, Task Forces)
# - **Planning** — Plans the work (Situation, Resources, Documentation, Demobilization)
# - **Logistics** — Supports the work (Supply, Facilities, Ground Support, Medical, Communications)
# - **Finance/Admin** — Pays for the work
#
# ### Crisis Communication Principles
# - Be first, be right, be credible
# - Express empathy, show competence
# - Provide action steps
# - Remember: In absence of information, rumor fills the void
#
# ## Scope
#
# ### ✓ In Scope
# - Emergency operations planning
# - Incident command and coordination
# - Crisis communication and public warning
# - Resource management and mutual aid
# - Evacuation planning and sheltering
# - Hazard mitigation planning
# - Long-term recovery coordination
# - Exercise design and evaluation
#
# ### ✗ Out of Scope
# - Tactical firefighting (use fire-chief skill)
# - Law enforcement tactics (use police-chief skill)
# - Medical treatment protocols (use medical-director skill)
# - Engineering assessments (use structural-engineer skill)
#
# ## Quality Metrics
#
# | Dimension | Score |
# |-----------|-------|
# | System Prompt | 9.5/10 |
# | Domain Knowledge | 9.5/10 |
# | Workflow | 9.5/10 |
# | Examples | 9.5/10 |
# | Risk Management | 9.5/10 |
#
# ## References & Standards
#
# - FEMA: National Incident Management System (NIMS)
# - FEMA: National Response Framework
# - FEMA: Comprehensive Preparedness Guide 101
# - IAEM: Emergency Management Principles
# - IAEM: Certified Emergency Manager (CEM)
# - EMI: Master Exercise Practitioner
#
# ---
#
# This skill provides comprehensive emergency management expertise for all phases of the disaster cycle, with strong emphasis on interagency coordination, clear communication, and building community resilience.

# %%
# %%ask
# Could you please install this skill for me?
# Out:
# I'll help you install the emergency-manager skill. Let me first check the current skills directory structure to understand where to install it.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills/skillsmp"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills/skillsmp"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll install the emergency-manager skill. First, let me get the skill details to find the GitHub repository URL.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_skill_details.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_skill_details.py",
#   "content": "import os\nfrom pathlib import Path\nfrom dotenv import load_dotenv\nimport requests\nimport json\n\n# Load API key\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"SKILLSMP_API_KEY not found\")\n    exit(1)\n\n# Get skill details by name\nurl = \"https://skillsmp.com/api/v1/skills/search\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\nparams = {\"q\": \"emergency-manager\"}\n\nresponse = requests.get(url, headers=headers, params=params)\nresult = response.json()\n\nif result.get(\"success\"):\n    skills = result.get(\"data\", {}).get(\"skills\", [])\n    for skill in skills:\n        if skill.get(\"name\") == \"emergency-manager\":\n            print(json.dumps(skill, indent=2))\n            break\nelse:\n    print(f\"Error: {result}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_emergency_manager_details.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_emergency_manager_details.py",
#   "content": "import os\nfrom pathlib import Path\nfrom dotenv import load_dotenv\nimport requests\nimport json\n\n# Load API key\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"SKILLSMP_API_KEY not found\")\n    exit(1)\n\n# Get skill details by name\nurl = \"https://skillsmp.com/api/v1/skills/search\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\nparams = {\"q\": \"emergency-manager\"}\n\nresponse = requests.get(url, headers=headers, params=params)\nresult = response.json()\n\nif result.get(\"success\"):\n    skills = result.get(\"data\", {}).get(\"skills\", [])\n    for skill in skills:\n        if skill.get(\"name\") == \"emergency-manager\":\n            print(json.dumps(skill, indent=2))\n            break\nelse:\n    print(f\"Error: {result}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/get_emergency_manager_details.py</pre>
#     </div>
#   </details>
# </div>
# Now I'll download the skill from GitHub and install it to the skills directory.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager.py",
#   "content": "import os\nimport requests\nfrom pathlib import Path\n\n# GitHub raw content URL for the skill\ngithub_base = \"https://raw.githubusercontent.com/theneoai/awesome-skills/main/skills/government/emergency-manager\"\n\n# Target directory\ntarget_dir = Path(\"/home/jovyan/.deepagents/agent/skills/emergency-manager\")\ntarget_dir.mkdir(exist_ok=True)\n\n# Files to download\nfiles = [\"SKILL.md\"]\n\nprint(f\"Installing emergency-manager skill to {target_dir}\")\n\nfor file in files:\n    url = f\"{github_base}/{file}\"\n    print(f\"Downloading {file}...\")\n    response = requests.get(url)\n    if response.status_code == 200:\n        target_path = target_dir / file\n        target_path.write_text(response.text)\n        print(f\"  ✓ Saved to {target_path}\")\n    else:\n        print(f\"  ✗ Failed to download {file} (status: {response.status_code})\")\n\nprint(\"\\nInstallation complete!\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md",
#   "limit": 50
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"
# }</pre>
#     </div>
#   </details>
# </div>
# ## Installation Complete! ✓
#
# The **emergency-manager** skill has been successfully installed.
#
# **Installation Details:**
#
# | Property | Value |
# |----------|-------|
# **Skill Name** : emergency-manager
# **Version** : 1.0.0
# **Author** : theNeoAI
# **License** : MIT
# **Install Location** : `/home/jovyan/.deepagents/agent/skills/emergency-manager/`
# **Files Installed** : SKILL.md
#
# The skill is now available and ready to use. It provides expert-level emergency management capabilities covering:
#
# - **Disaster Preparedness** — Planning, training, exercises, public education
# - **Response Coordination** — ICS/NIMS, EOC operations, resource coordination
# - **Hazard Mitigation** — Risk assessment, project design, grant management
# - **Recovery** — Long-term recovery, disaster assistance, community resilience
# - **Crisis Communication** — Public information, warning systems, JIC operations
#
# You can now use this skill for tasks such as developing emergency plans, coordinating multi-agency response, managing evacuation operations, or leading disaster recovery efforts.

# %%
# %%ask
# We have a major hurricane approaching in Florida next week.
# How do we coordinate the response? Please show a timeline plan.
# Out:
# I'll help you coordinate the hurricane response using the emergency-manager skill. Let me first read the skill to apply its framework properly.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md",
#   "offset": 100,
#   "limit": 200
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/references/7-workflow.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/references/7-workflow.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md",
#   "limit": 200,
#   "offset": 290
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a comprehensive hurricane response coordination timeline plan based on the emergency management framework.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_timeline.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_timeline.md",
#   "content": "# Hurricane Response Coordination Timeline Plan\n## Florida Major Hurricane - Next Week\n\n---\n\n## Executive Summary\n\n**Situation**: Major hurricane approaching Florida with projected landfall in 7 days\n**Mission**: Coordinate multi-agency response to protect life, stabilize incident, minimize damage, and initiate recovery\n**Priority**: LIFE SAFETY above all else\n\n**Key Decision Points**:\n- **T-120 hours (5 days)**: Evacuation decision\n- **T-72 hours (3 days)**: Mandatory evacuation orders\n- **T-48 hours (2 days)**: EOC full activation\n- **T-24 hours (1 day)**: Shelter-in-place for remaining population\n- **T+0**: Landfall - response operations\n- **T+72 hours**: Transition to recovery\n\n---\n\n## Incident Command Structure\n\n```\n                    INCIDENT COMMANDER\n                           │\n        ┌──────────────────┼──────────────────┐\n        │                  │                  │\n   OPERATIONS         PLANNING          LOGISTICS\n   (Does the work)    (Plans the work)  (Supports the work)\n        │                  │                  │\n   • Evacuation        • Situation         • Supply Chain\n   • Search &amp; Rescue   • Weather Track     • Shelter Operations\n   • Debris Removal    • Resource Status   • Fuel Management\n   • Power Restoration • Impact Modeling   • Communications\n   • Medical Support   • Documentation     • Food/Water\n\n        └──────────────────┬──────────────────┘\n                           │\n                    FINANCE/ADMIN\n                    (Pays for the work)\n   • Cost Tracking\n   • FEMA Documentation\n   • Mutual Aid Billing\n   • Procurement\n```\n\n---\n\n## Phase 1: Preparedness (T-7 to T-5 Days)\n\n### T-7 Days (168 Hours Before Landfall)\n\n**Priority**: PREPAREDNESS - Finalize plans, mobilize resources\n\n| Time | Action | Lead Agency | Status |\n|------|--------|-------------|--------|\n| 0800 | Hurricane briefing - track, intensity, projected path | NWS/EM | Pending |\n| 0900 | EOC Level 3 activation (monitoring) | Emergency Management | Pending |\n| 1000 | State Emergency Operations Center (SEOC) notification | State EM | Pending |\n| 1100 | Pre-landfall conference call with all agencies | EOC | Pending |\n| 1200 | Resource inventory check - mutual aid agreements | Logistics | Pending |\n| 1300 | Fuel reserves verification - generators, vehicles | Logistics | Pending |\n| 1400 | Shelter capacity assessment - identify gaps | Social Services | Pending |\n| 1500 | Public information plan review | PIO | Pending |\n| 1600 | Evacuation route analysis - identify bottlenecks | DOT | Pending |\n| 1700 | Special needs population registry verification | Public Health | Pending |\n| 1800 | Daily situation report (SITREP) template distribution | Planning | Pending |\n\n**Key Deliverables**:\n- Initial Incident Action Plan (IAP)\n- Resource request forms prepared\n- Communication channels tested\n- Public messaging templates ready\n\n---\n\n### T-6 Days (144 Hours Before Landfall)\n\n**Priority**: PREPAREDNESS - Resource staging, public awareness\n\n| Time | Action | Lead Agency | Status |\n|------|--------|-------------|--------|\n| 0700 | Weather update conference call | NWS | Pending |\n| 0800 | EOC Level 2 activation (partial staffing) | Emergency Management | Pending |\n| 0900 | Mutual aid requests - out-of-state resources | Logistics | Pending |\n| 1000 | Public information campaign launch - \"Know Your Zone\" | PIO | Pending |\n| 1100 | Evacuation zone maps distribution | GIS/Planning | Pending |\n| 1200 | Shelter pre-staging - cots, water, MREs | Red Cross | Pending |\n| 1300 | Medical surge capacity assessment | Public Health | Pending |\n| 1400 | Utility company coordination - power restoration prep | Power Companies | Pending |\n| 1500 | Transportation assets staging - buses, high-water vehicles | DOT | Pending |\n| 1600 | Law enforcement pre-deployment planning | Sheriff/PD | Pending |\n| 1700 | Search and rescue team notification | Fire/EM ...
# Now let me create a visual timeline chart to illustrate the key phases and decision points:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_timeline_chart.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_timeline_chart.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nHurricane Response Timeline Visualization\nCreates a comprehensive timeline chart showing all phases and key milestones\n\"\"\"\n\nimport matplotlib.pyplot as plt\nimport matplotlib.patches as mpatches\nfrom matplotlib.patches import FancyBboxPatch, FancyArrowPatch\nimport numpy as np\n\n# Set up the figure\nfig, ax = plt.subplots(figsize=(16, 10), dpi=150)\nax.set_xlim(-8, 80)\nax.set_ylim(0, 12)\nax.axis('off')\n\n# Title\nax.text(36, 11.5, 'Florida Hurricane Response Coordination Timeline',\n        fontsize=20, fontweight='bold', ha='center', va='top')\nax.text(36, 11, 'Major Hurricane - 7-Day Timeline Through Recovery',\n        fontsize=14, ha='center', va='top', style='italic')\n\n# Define phases with colors\nphases = [\n    {'name': 'PREPAREDNESS', 'start': -7, 'end': -5, 'color': '#3498db', 'y': 9.5},\n    {'name': 'EVACUATION', 'start': -5, 'end': -1, 'color': '#e67e22', 'y': 9.5},\n    {'name': 'PRE-LANDFALL', 'start': -1, 'end': 0, 'color': '#9b59b6', 'y': 9.5},\n    {'name': 'RESPONSE', 'start': 0, 'end': 3, 'color': '#e74c3c', 'y': 9.5},\n    {'name': 'RECOVERY', 'start': 3, 'end': 30, 'color': '#27ae60', 'y': 9.5},\n]\n\n# Draw phase bars\nfor phase in phases:\n    # Scale x coordinates (7 days = 14 units width for preparedness-evacuation-response)\n    x_start = phase['start'] * 2\n    x_end = phase['end'] * 2\n    width = x_end - x_start\n\n    # Draw phase bar\n    box = FancyBboxPatch((x_start, phase['y'] - 0.3), width, 0.6,\n                         boxstyle=\"round,pad=0.1\",\n                         edgecolor='black', facecolor=phase['color'],\n                         linewidth=2, alpha=0.8)\n    ax.add_patch(box)\n\n    # Phase label\n    ax.text((x_start + x_end) / 2, phase['y'], phase['name'],\n            fontsize=11, fontweight='bold', ha='center', va='center',\n            color='white')\n\n# Draw timeline axis\nax.plot([-14, 60], [8, 8], 'k-', linewidth=2)\n\n# Time markers\ntime_markers = [\n    {'day': -7, 'label': 'T-7 Days', 'y': 7.5},\n    {'day': -5, 'label': 'T-5 Days', 'y': 7.5},\n    {'day': -3, 'label': 'T-3 Days', 'y': 7.5},\n    {'day': -1, 'label': 'T-1 Day', 'y': 7.5},\n    {'day': 0, 'label': 'LANDFALL', 'y': 7.5},\n    {'day': 1, 'label': 'T+1 Day', 'y': 7.5},\n    {'day': 3, 'label': 'T+3 Days', 'y': 7.5},\n    {'day': 7, 'label': 'T+7 Days', 'y': 7.5},\n    {'day': 14, 'label': 'T+14 Days', 'y': 7.5},\n    {'day': 30, 'label': 'T+30 Days', 'y': 7.5},\n]\n\nfor marker in time_markers:\n    x = marker['day'] * 2\n    ax.plot([x, x], [7.8, 8.2], 'k-', linewidth=2)\n    ax.text(x, marker['y'], marker['label'],\n            fontsize=9, ha='center', va='top', rotation=0)\n\n# Key milestones\nmilestones = [\n    {'day': -5, 'label': 'Voluntary Evacuation\\nZone A', 'y': 6.5, 'color': '#f39c12'},\n    {'day': -4, 'label': 'Mandatory Evacuation\\nZone A', 'y': 6.0, 'color': '#e74c3c'},\n    {'day': -3, 'label': 'Mandatory Evacuation\\nZone B', 'y': 5.5, 'color': '#e74c3c'},\n    {'day': -2, 'label': 'Mandatory Evacuation\\nZone C', 'y': 5.0, 'color': '#e74c3c'},\n    {'day': -1, 'label': 'Shelter-in-Place\\nOrder', 'y': 4.5, 'color': '#9b59b6'},\n    {'day': 0, 'label': 'LANDFALL\\nHunker Down', 'y': 4.0, 'color': '#c0392b'},\n    {'day': 0.5, 'label': 'Search &amp; Rescue\\nBegins', 'y': 3.5, 'color': '#e74c3c'},\n    {'day': 1, 'label': 'Damage Assessment\\nBegins', 'y': 3.0, 'color': '#e67e22'},\n    {'day': 2, 'label': 'Power Restoration\\nCritical Facilities', 'y': 2.5, 'color': '#3498db'},\n    {'day': 3, 'label': 'Phased Re-entry\\nBegins', 'y': 2.0, 'color': '#27ae60'},\n    {'day': 5, 'label': 'Disaster Recovery\\nCenters Open', 'y': 1.5, 'color': '#27ae60'},\n    {'day': 7, 'label': 'Schools Reopen\\n(Where Safe)', 'y': 1.0, 'color': '#27ae60'},\n]\n\nfor milestone in milestones:\n    x = milestone['day'] * 2\n\n    # Draw milestone marker\n    circle = plt.Circle((x, milestone['y']), 0.3, color=milestone['color'],\n                 ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_timeline_chart.py</pre>
#     </div>
#   </details>
# </div>
# Now let me create a concise executive summary document:
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_executive_summary.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_executive_summary.md",
#   "content": "# Hurricane Response Coordination - Executive Summary\n\n## Situation Overview\n\n**Threat**: Major hurricane approaching Florida\n**Timeline**: Landfall expected in 7 days\n**Mission**: Coordinate multi-agency response to protect life, stabilize incident, minimize damage, and initiate recovery\n\n---\n\n## Critical Decision Points\n\n| Time (Before Landfall) | Decision | Lead Agency |\n|------------------------|----------|-------------|\n| **T-120 hours (5 days)** | Evacuation decision | Emergency Management |\n| **T-72 hours (3 days)** | Mandatory evacuation orders | Emergency Management |\n| **T-48 hours (2 days)** | EOC full activation | Emergency Management |\n| **T-24 hours (1 day)** | Shelter-in-place for remaining population | Emergency Management |\n| **T+0** | Landfall - response operations begin | Incident Commander |\n| **T+72 hours** | Transition to recovery phase | Recovery Committee |\n\n---\n\n## Five-Phase Response Plan\n\n### Phase 1: Preparedness (T-7 to T-5 Days)\n**Priority**: Finalize plans, mobilize resources\n\n**Key Actions**:\n- EOC Level 3 activation (monitoring)\n- Resource inventory and mutual aid requests\n- Shelter capacity assessment\n- Public information campaign launch\n- Evacuation route analysis\n\n**Deliverables**:\n- Initial Incident Action Plan (IAP)\n- Mutual aid requests submitted\n- Public awareness campaign active\n- Shelter supplies staged\n\n---\n\n### Phase 2: Evacuation (T-4 to T-2 Days)\n**Priority**: LIFE SAFETY - Evacuate at-risk populations\n\n**Key Actions**:\n- EOC Level 1 activation (full staffing)\n- Mandatory evacuation orders (Zones A, B, C)\n- Contraflow lane reversal\n- Shelter openings (general and special needs)\n- Transportation assistance deployment\n- Hospital and nursing home evacuations\n\n**Deliverables**:\n- All evacuation zones activated\n- All shelters open and operational\n- Special needs population evacuated\n- Evacuation progress tracking\n\n---\n\n### Phase 3: Pre-Landfall (T-1 Day)\n**Priority**: LIFE SAFETY - Final preparations, hunker down\n\n**Key Actions**:\n- All evacuation routes closed\n- Shelter-in-place order issued\n- Emergency responder safety briefing\n- Search and rescue assets pre-positioned\n- EOC backup power verification\n- Joint Information Center (JIC) full activation\n\n**Deliverables**:\n- All evacuation complete\n- All shelters at capacity with headcount\n- Emergency responders in safe positions\n- JIC fully operational\n\n---\n\n### Phase 4: Response (T+0 to T+72 Hours)\n**Priority**: LIFE SAFETY → INCIDENT STABILIZATION\n\n**Critical Note**: NO emergency response until winds drop below 39 MPH and conditions are safe\n\n**Key Actions**:\n- **T+0 to T+12**: Wait for safe conditions, initial damage assessment\n- **T+12 to T+24**: Search and rescue (priority 1 - life threats), power restoration to critical facilities\n- **T+24 to T+48**: Search and rescue (priority 2 - welfare checks), 80% power restoration, phased re-entry planning\n- **T+48 to T+72**: Phased re-entry begins, 95%+ power restoration, FEMA Disaster Recovery Centers open\n\n**Deliverables**:\n- All search and rescue complete\n- 95%+ power restoration\n- Phased re-entry plan active\n- FEMA assistance initiated\n\n---\n\n### Phase 5: Recovery (T+72 Hours to T+30 Days)\n**Priority**: SERVICE RESTORATION → RECOVERY → MITIGATION\n\n**Key Actions**:\n- Disaster Recovery Centers (DRCs) open\n- FEMA Individual Assistance registration\n- School reopening (where safe)\n- Business recovery assistance\n- Debris removal\n- Temporary housing solutions\n- Long-term recovery strategy\n- Mitigation planning - rebuild stronger\n\n**Deliverables**:\n- Community services restored\n- Disaster assistance distributed\n- Mitigation projects identified\n- Recovery plan approved\n\n---\n\n## Incident Command Structure\n\n```\n                    INCIDENT COMMANDER\n                           │\n        ┌──────────────────┼──────────────────┐\n        │                  │           ...
# # Florida Hurricane Response Coordination Plan
#
# ## Overview
#
# I've developed a comprehensive hurricane response coordination timeline plan using the emergency-manager skill framework. The plan follows FEMA's National Incident Management System (NIMS) and the Emergency Management Priority Hierarchy, with **LIFE SAFETY** as the paramount concern.
#
# ---
#
# ## Timeline Visualization
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Hurricane Response Timeline</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# ---
#
# ## Critical Decision Points
#
# | Time Before Landfall | Decision | Priority |
# |---------------------|----------|----------|
# | **T-120 hours (5 days)** | Evacuation decision | High |
# | **T-72 hours (3 days)** | Mandatory evacuation orders | Critical |
# | **T-48 hours (2 days)** | EOC full activation | Critical |
# | **T-24 hours (1 day)** | Shelter-in-place order | Critical |
# | **T+0** | Landfall - response operations | Life Safety |
# | **T+72 hours** | Transition to recovery | High |
#
# ---
#
# ## Five-Phase Response Structure
#
# ### Phase 1: Preparedness (T-7 to T-5 Days)
#
# **Priority** : Finalize plans, mobilize resources
#
# **Key Actions** :
# - EOC Level 3 activation (monitoring mode)
# - Resource inventory and mutual aid requests
# - Shelter capacity assessment and gap analysis
# - Public information campaign launch - "Know Your Zone"
# - Evacuation route analysis and bottleneck identification
# - Special needs population registry verification
#
# **Deliverables** :
# - Initial Incident Action Plan (IAP)
# - Mutual aid requests submitted to state and federal partners
# - Public awareness campaign active across all channels
# - Shelter supplies staged and ready
#
# ---
#
# ### Phase 2: Evacuation (T-4 to T-2 Days)
#
# **Priority** : **LIFE SAFETY** - Evacuate at-risk populations
#
# **Key Actions** :
# - EOC Level 1 activation (full staffing, 24/7 operations)
# - Mandatory evacuation orders issued for Zones A, B, and C
# - Contraflow lane reversal on major evacuation routes
# - Shelter openings (general population and special needs)
# - Transportation assistance deployment for vulnerable populations
# - Hospital and nursing home evacuations coordinated
#
# **Deliverables** :
# - All evacuation zones activated with clear timelines
# - All shelters open and operational with capacity tracking
# - Special needs population safely evacuated
# - Real-time evacuation progress monitoring
#
# ---
#
# ### Phase 3: Pre-Landfall (T-1 Day)
#
# **Priority** : **LIFE SAFETY** - Final preparations, hunker down
#
# **Key Actions** :
# - All evacuation routes closed (too dangerous to travel)
# - Shelter-in-place order issued for remaining population
# - Emergency responder safety briefing completed
# - Search and rescue assets pre-positioned in safe locations
# - EOC backup power verified and tested
# - Joint Information Center (JIC) fully activated
#
# **Deliverables** :
# - All evacuation operations complete
# - All shelters at capacity with accurate headcount
# - Emergency responders in safe shelter positions
# - JIC operational and coordinating all public messaging
#
# ---
#
# ### Phase 4: Response (T+0 to T+72 Hours)
#
# **Priority** : **LIFE SAFETY** → INCIDENT STABILIZATION
#
# **Critical Note** : NO emergency response until winds drop below 39 MPH and conditions are safe for responders
#
# **Key Actions by Timeframe** :
#
# | Timeframe | Priority Actions | Lead Agencies |
# |-----------|------------------|---------------|
# | **T+0 to T+12** | Wait for safe conditions, initial damage assessment when possible | Planning, Safety |
# | **T+12 to T+24** | Search and rescue (Priority 1 - life threats), power restoration to critical facilities | Fire/EMS, Power Companies |
# | **T+24 to T+48** | Search and rescue (Priority 2 - welfare checks), 80% power restoration, phased re-entry planning | Operations, Power Companies |
# | **T+48 to T+72** | Phased re-entry begins, 95%+ power restoration, FEMA Disaster Recovery Centers open | Emergency Management, FEMA |
#
# **Deliverables** :
# - All search and rescue operations complete
# - 95%+ power restoration achieved
# - Phased re-entry plan active and communicating
# - FEMA Individual Assistance registration open
#
# ---
#
# ### Phase 5: Recovery (T+72 Hours to T+30 Days)
#
# **Priority** : SERVICE RESTORATION → RECOVERY → MITIGATION
#
# **Key Actions** :
# - Disaster Recovery Centers (DRCs) open in affected communities
# - FEMA Individual Assistance registration and processing
# - School reopening assessment and phased reopening (where safe)
# - Business recovery assistance programs launched
# - Debris removal operations (public and private property)
# - Temporary housing solutions for displaced residents
# - Long-term recovery strategy development
# - Mitigation planning - rebuild stronger than before
#
# **Deliverables** :
# - Community services and infrastructure restored
# - Disaster assistance distributed to eligible residents
# - Mitigation projects identified and prioritized
# - Comprehensive recovery plan approved and funded
#
# ---
#
# ## Incident Command System Structure
#
# The response follows the standard ICS structure with clear roles and responsibilities:
#
# ```
#                     INCIDENT COMMANDER
#                            │
#         ┌──────────────────┼──────────────────┐
#         │                  │                  │
#    OPERATIONS         PLANNING          LOGISTICS
#    (Does the work)    (Plans the work)  (Supports the work)
#         │                  │                  │
#    • Evacuation        • Situation         • Supply Chain
#    • Search & Rescue   • Weather Track     • Shelter Operations
#    • Debris Removal    • Resource Status   • Fuel Management
#    • Power Restoration • Impact Modeling   • Communications
#    • Medical Support   • Documentation     • Food/Water
#
#         └──────────────────┬──────────────────┘
#                            │
#                     FINANCE/ADMIN
#                     (Pays for the work)
#    • Cost Tracking
#    • FEMA Documentation
#    • Mutual Aid Billing
#    • Procurement
# ```
#
# ---
#
# ## Emergency Management Priority Hierarchy
#
# All decisions and actions follow this priority order:
#
# 1. **LIFE SAFETY** (Immediate)
#    - Protect human life above all else
#    - Search and rescue, medical care, evacuation
#
# 2. **INCIDENT STABILIZATION** (Hours to days)
#    - Control the situation, prevent escalation
#    - Contain hazards, protect property
#
# 3. **PROPERTY AND ENVIRONMENTAL PROTECTION** (Days)
#    - Minimize damage to property and environment
#    - Hazardous materials, infrastructure protection
#
# 4. **RESTORATION OF SERVICES** (Days to weeks)
#    - Return community to normal functioning
#    - Critical infrastructure, essential services
#
# 5. **RECOVERY AND MITIGATION** (Weeks to years)
#    - Rebuild stronger, reduce future risk
#    - Long-term recovery, hazard mitigation
#
# ---
#
# ## Communication Plan
#
# Effective crisis communication is critical for public safety and trust:
#
# | Phase | Primary Message | Frequency | Channels |
# |-------|-----------------|-----------|----------|
# | T-7 to T-5 | Monitor weather, prepare evacuation plans | Daily | All media, social media |
# | T-4 to T-2 | Evacuation orders, shelter locations | Every 4 hours | EAS, social media, press |
# | T-1 | Shelter in place, stay safe | Every 2 hours | All media |
# | T+0 to T+12 | Hunker down, conditions dangerous | Every 2 hours | All media |
# | T+12 to T+48 | Safety information, re-entry updates | Every 4 hours | All media |
# | T+48+ | Recovery resources, assistance info | Daily | All media |
#
# **Joint Information Center (JIC)** : Activated T-1 day to coordinate all public messaging
#
# ---
#
# ## Resource Requirements
#
# ### Mutual Aid Resources
#
# | Type | Source | Activation Time | Quantity |
# |------|--------|-----------------|----------|
# | Search & Rescue Teams | State EMAC | T-48 hours | 5 teams |
# | Urban SAR | FEMA USAR | T-24 hours | 2 teams |
# | High-Water Vehicles | County mutual aid | T-48 hours | 20 vehicles |
# | Power Crews | Utility mutual aid | T-24 hours | 50 crews |
# | Medical Teams | DMAT | T-24 hours | 3 teams |
# | Communications | State COMU | T-48 hours | 2 units |
#
# ### Critical Supplies
#
# | Resource | Quantity | Staging Location |
# |----------|----------|------------------|
# | Generators | 50 | EOC logistics center |
# | Cots | 5,000 | Shelters |
# | MREs | 100,000 | Shelters |
# | Water | 500,000 gallons | Shelters |
# | Fuel | 50,000 gallons | Strategic locations |
# | Sandbags | 100,000 | Distribution points |
#
# ---
#
# ## Success Metrics
#
# | Metric | Target | Measurement Method |
# |--------|--------|-------------------|
# | Evacuation compliance | 95% of evacuation zones | Post-event survey |
# | Life loss | Minimized | Fatalities count |
# | Injuries | Minimized | Hospital admissions |
# | Power restoration | 80% in 48 hours, 95% in 72 hours | Utility reports |
# | Road clearance | Priority routes in 24 hours | DOT assessment |
# | Public information | Accurate, timely | Media monitoring |
# | Cost management | Within budget | Finance tracking |
#
# ---
#
# ## Quality Gates
#
# | Gate | Question | Status |
# |------|----------|--------|
# | **Gate 1** | Is there immediate threat to life? | ✓ YES - Response activated |
# | **Gate 2** | Is incident command established? | ✓ YES - EOC activated |
# | **Gate 3** | Are resources adequate for the mission? | ⏳ PENDING - Mutual aid requested |
# | **Gate 4** | Is public information accurate and timely? | ✓ YES - JIC activated |
# | **Gate 5** | Is the response sustainable? | ✓ YES - 12-hour operational periods planned |
#
# ---
#
# ## Key Agency Contacts
#
# | Agency | Role | Contact |
# |--------|------|---------|
# | Emergency Management | Incident Commander | EOC Director |
# | National Weather Service | Weather Updates | Warning Coordination Meteorologist |
# | Governor's Office | State Coordination | Emergency Liaison |
# | FEMA | Federal Assistance | Federal Coordinating Officer |
# | State Emergency Management | State Resources | State Director |
# | Red Cross | Shelter Operations | Chapter Executive |
# | Power Company | Power Restoration | Emergency Operations Manager |
# | Public Health | Medical Coordination | Health Officer |
# | Law Enforcement | Security/Evacuation | Sheriff/Police Chief |
# | DOT | Transportation | District Engineer |
#
# ---
#
# ## Immediate Next Steps
#
# 1. **Today** :
#    - Review and approve this plan
#    - Schedule pre-landfall conference call with all agencies
#    - Begin resource inventory verification
#
# 2. **T-7 Days** :
#    - EOC Level 3 activation
#    - Initial hurricane briefing with NWS
#    - Public information campaign launch
#
# 3. **T-5 Days** :
#    - Issue voluntary evacuation order (Zone A)
#    - Begin special needs evacuation
#    - Stage mutual aid resources
#
# 4. **Ongoing** :
#    - Daily situation reports (SITREPs)
#    - Adjust timeline based on hurricane track and intensity
#    - Maintain communication with all stakeholders
#
# ---
#
# ## Documentation
#
# I've created three comprehensive documents for your use:
#
# 1. **Full Timeline Plan** : Detailed hour-by-hour action items for all phases
#    - Location: `/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_timeline.md`
#
# 2. **Executive Summary** : Concise overview for leadership and decision-makers
#    - Location: `/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_executive_summary.md`
#
# 3. **Timeline Visualization** : Visual chart showing all phases and key milestones
#    - Location: `/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_timeline_chart.png`
#
# ---
#
# **Plan Status** : DRAFT - Pending approval
# **Framework** : FEMA NIMS, National Response Framework
# **Prepared By** : Emergency Management Division using emergency-manager skill
#
# This plan provides a structured, coordinated approach to hurricane response that prioritizes life safety while ensuring effective interagency coordination, clear communication, and a path to recovery.
